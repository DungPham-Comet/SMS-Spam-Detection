# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv')

# %%
df.sample(10)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 3764  spam  Someone U know has asked our dating service 2 ...        NaN
# 3954   ham  I knew it... U slept v late yest? Wake up so l...        NaN
# 4825   ham                      Haha, just what I was thinkin        NaN
# 1292   ham  Da my birthdate in certificate is in april but...        NaN
# 23     ham  Aft i finish my lunch then i go str down lor. ...        NaN
# 2132  spam  Your B4U voucher w/c 27/03 is MARSMS. Log onto...        NaN
# 2306   ham                         Aight that'll work, thanks        NaN
# 2126   ham           You do got a shitload of diamonds though        NaN
# 4172   ham  Ok... But they said i've got wisdom teeth hidd...        NaN
# 3790  spam  Twinks, bears, scallies, skins and jocks are c...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3764        NaN        NaN
# 3954        NaN        NaN
# 4825        NaN        NaN
# 1292        NaN        NaN
# 23          NaN        NaN
# 2132        NaN        NaN
# 2306        NaN        NaN
# 2126        NaN        NaN
# 4172        NaN        NaN
# 3790        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data Cleaning
# 2. EDA
# 3. Text Preprocessing
# 4. Model building
# 5. Evaluation

# %% [markdown]
# ## 1. Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop 3 last columns
df.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace = True)

# %%
df.sample(5)
# Out:
#         v1                                                 v2
# 4990   ham  We made it! Eta at taunton is 12:30 as planned...
# 3865   ham       Theoretically yeah, he could be able to come
# 3309   ham  Oh ho. Is this the first time u use these type...
# 1235   ham  Your opinion about me? 1. Over 2. Jada 3. Kusr...
# 2002  spam  TheMob>Yo yo yo-Here comes a new selection of ...

# %%
# rename columns 
df.rename(columns = {'v1':'target','v2':'text'}, inplace = True)

# %%
df.sample(5)
# Out:
#      target                                               text
# 3999   spam  This is the 2nd time we have tried to contact ...
# 1082    ham                           Send to someone else :-)
# 4444    ham                     2 celebrate my båÕday, y else?
# 1280    ham  Oh ho. Is this the first time u use these type...
# 5290    ham                            Dear where you. Call me

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target']) # Chuyển dữ liệu cột target thành các giá trị số ham = 0, spam = 1

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# giá trị bị thiếu (missing value)
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check duplicate value
df.duplicated().sum()
# Out:
# 403

# %%
# remove duplicates
df = df.drop_duplicates(keep = 'first')
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#       target                                               text
# 2357       0  Okay same with me. Well thanks for the clarifi...
# 4209       0  No da:)he is stupid da..always sending like th...
# 652        0  Wait, do you know if wesleys in town? I bet sh...
# 4975       0  You are gorgeous! keep those pix cumming :) th...
# 4751       0  Well boy am I glad G wasted all night at apple...
# 1021       1  Guess what! Somebody you know secretly fancies...
# 3791       0  Love it! I want to flood that pretty pussy wit...
# 858        0                            Spoons it is then okay?
# 2522       0  Dunno lei... I might b eatin wif my frens... I...
# 882        0  I love to give massages. I use lots of baby oi...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5169 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  5169 non-null   int32
#  1   text    5169 non-null   object
# dtypes: int32(1), object(1)
# memory usage: 101.0+ KB

# %% [markdown]
# ## 2. EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels = ['ham', 'spam'], autopct = '%0.2f')
plt.show()

# %%
# Data is imbalanced

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters'] = df['text'].apply(len)
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
# num of words
df['num_words'] = df['text'].apply(lambda x : len(nltk.word_tokenize(x))) # count number of words 
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
df['num_sentences'] = df['text'].apply(lambda x : len(nltk.sent_tokenize(x))) # count number of words 
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
df[['num_characters','num_words','num_sentences']].describe()  # mô tả thống kê
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    18.455794       1.965564
# std         58.236293    13.324758       1.448541
# min          2.000000     1.000000       1.000000
# 25%         36.000000     9.000000       1.000000
# 50%         60.000000    15.000000       1.000000
# 75%        117.000000    26.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# biểu diễn thông số cơ bản của ham message
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.123782       1.820195
# std         56.358207    13.493970       1.383657
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      38.000000

# %%
# biểu diễn thông số cơ bản của spam message
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.970904
# std         30.137753    7.008418       1.488425
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       9.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'], color = 'red')
# Out:
# <AxesSubplot: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize = (12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'], color = 'red')
# Out:
# <AxesSubplot: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue = 'target')

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5988\3028576344.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)
# <AxesSubplot: >

# %% [markdown]
# # 3. Data preprocessing
# ## 3.1. Lower case
# ## 3.2. Tokenization
# ## 3.3. Removing special characters
# ## 3.4. Removing stop words and punctuation
# ## 3.5. Stemming

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
def transform_text(text): 
    text = text.lower()     
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if i.isalnum():
            y.append(i)
    
    text = y[:] # copy y to text
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
            
    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
            
    return " ".join(y)

# %%
transform_text('I loved the YT lectures on Machine Learning. How about you?')
# Out:
# 'love yt lectur machin learn'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc = WordCloud(width = 500, height = 500, min_font_size = 10, background_color = 'white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize = (15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep = " "))

# %%
plt.figure(figsize = (15,6))
plt.imshow(ham_wc)

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
word_freq = Counter(spam_corpus).most_common(30)
df_word_freq = pd.DataFrame(word_freq, columns=['Spam Word', 'Frequency'])
sns.barplot(x='Spam Word', y='Frequency', data=df_word_freq)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
spam_words_dict = {}  # Khởi tạo từ điển để lưu trữ tần suất xuất hiện của spam words

# Duyệt qua từng từ trong danh sách và tăng tần suất xuất hiện trong từ điển
for word in spam_corpus:
    if word in spam_words_dict:
        spam_words_dict[word] += 1
    else:
        spam_words_dict[word] = 1

spam_words_dict = sorted(spam_words_dict.items(), key=lambda x: x[1], reverse=True)

# In tần suất xuất hiện của từng từ
for word, freq in spam_words_dict:
    print(f"Từ '{word}' xuất hiện {freq} lần")
spam_words_dict = dict(spam_words_dict)
# Out:
# Từ 'call' xuất hiện 320 lần
# Từ 'free' xuất hiện 191 lần
# Từ '2' xuất hiện 155 lần
# Từ 'txt' xuất hiện 141 lần
# Từ 'text' xuất hiện 122 lần
# Từ 'u' xuất hiện 119 lần
# Từ 'ur' xuất hiện 119 lần
# Từ 'mobil' xuất hiện 114 lần
# Từ 'stop' xuất hiện 104 lần
# Từ 'repli' xuất hiện 103 lần
# Từ 'claim' xuất hiện 98 lần
# Từ '4' xuất hiện 97 lần
# Từ 'prize' xuất hiện 82 lần
# Từ 'get' xuất hiện 74 lần
# Từ 'new' xuất hiện 64 lần
# Từ 'servic' xuất hiện 64 lần
# Từ 'tone' xuất hiện 63 lần
# Từ 'send' xuất hiện 60 lần
# Từ 'urgent' xuất hiện 57 lần
# Từ 'nokia' xuất hiện 57 lần
# Từ 'contact' xuất hiện 56 lần
# Từ 'award' xuất hiện 55 lần
# Từ 'phone' xuất hiện 52 lần
# Từ 'cash' xuất hiện 51 lần
# Từ 'pleas' xuất hiện 51 lần
# Từ 'week' xuất hiện 49 lần
# Từ 'win' xuất hiện 48 lần
# Từ 'c' xuất hiện 45 lần
# Từ 'collect' xuất hiện 45 lần
# Từ 'min' xuất hiện 45 lần
# Từ 'custom' xuất hiện 42 lần
# Từ 'messag' xuất hiện 42 lần
# Từ 'guarante' xuất hiện 42 lần
# Từ 'per' xuất hiện 41 lần
# Từ 'chat' xuất hiện 38 lần
# Từ 'tri' xuất hiện 37 lần
# Từ 'msg' xuất hiện 35 lần
# Từ 'draw' xuất hiện 35 lần
# Từ 'number' xuất hiện 35 lần
# Từ 'cs' xuất hiện 35 lần
# Từ 'show' xuất hiện 33 lần
# Từ 'today' xuất hiện 33 lần
# Từ 'offer' xuất hiện 33 lần
# Từ 'line' xuất hiện 33 lần
# Từ 'go' xuất hiện 32 lần
# Từ 'receiv' xuất hiện 31 lần
# Từ 'want' xuất hiện 31 lần
# Từ 'latest' xuất hiện 30 lần
# Từ 'rington' xuất hiện 30 lần
# Từ 'landlin' xuất hiện 30 lần
# Từ '150ppm' xuất hiện 29 lần
# Từ 'video' xuất hiện 29 lần
# Từ '1' xuất hiện 28 lần
# Từ 'voucher' xuất hiện 28 lần
# Từ 'code' xuất hiện 27 lần
# Từ 'holiday' xuất hiện 27 lần
# Từ 'rate' xuất hiện 26 lần
# Từ 'network' xuất hiện 26 lần
# Từ 'select' xuất hiện 26 lần
# Từ '150p' xuất hiện 26 lần
# Từ 'date' xuất hiện 26 lần
# Từ 'box' xuất hiện 26 lần
# Từ 'day' xuất hiện 26 lần
# Từ 'everi' xuất hiện 26 lần
# Từ 'appli' xuất hiện 24 lần
# Từ 'r' xuất hiện 24 lần
# Từ 'cost' xuất hiện 24 lần
# Từ 'end' xuất hiện 24 lần
# Từ 'po' xuất hiện 24 lần
# Từ 'orang' xuất hiện 24 lần
# Từ 'await' xuất hiện 24 lần
# Từ 'camera' xuất hiện 23 lần
# Từ 'chanc' xuất hiện 22 lần
# Từ 'charg' xuất hiện 22 lần
# Từ 'sm' xuất hiện 22 lần
# Từ 'live' xuất hiện 22 lần
# Từ 'poli' xuất hiện 22 lần
# Từ 'attempt' xuất hiện 22 lần
# Từ 'entri' xuất hiện 21 lần
# Từ 'word' xuất hiện 21 lần
# Từ 'valid' xuất hiện 21 lần
# Từ 'find' xuất hiện 21 lần
# Từ '3' xuất hiện 20 lần
# Từ 'back' xuất hiện 20 lần
# Từ 'uk' xuất hiện 20 lần
# Từ 'mob' xuất hiện 20 lần
# Từ '18' xuất hiện 20 lần
# Từ 'game' xuất hiện 20 lần
# Từ 'weekli' xuất hiện 20 lần
# Từ 'pound' xuất hiện 19 lần
# Từ 'know' xuất hiện 19 lần
# Từ '500' xuất hiện 19 lần
# Từ 'club' xuất hiện 19 lần
# Từ '1st' xuất hiện 19 lần
# Từ '2nd' xuất hiện 19 lần
# Từ '8007' xuất hiện 19 lần
# Từ 'pic' xuất hiện 19 lần
# Từ 'credit' xuất hiện 18 lần
# Từ 'http' xuất hiện 18 lần
# Từ 'deliveri' xuất hiện 18 lần
# Từ 'account' xuất hiện 18 lần
# Từ 'join' xuất hiện 18 lần
# Từ '16' xuất hiện 18 lần
# Từ 'sae' xuất hiện 18 lần
# Từ 'time' xuất hiện 18 lần
# Từ 'bonu' xuất hiện 17 lần
# Từ 'wait' xuất hiện 17 lần
# Từ 'expir' xuất hiện 17 lần
# Từ 'order' xuất hiện 17 lần
# Từ '750' xuất hiện 17 lần
# Từ 'unsubscrib' xuất hiện 17 lần
# Từ 'wk' xuất hiện 17 lần
# Từ 'next' xuất hiện 16 lần
# Từ 'thank' xuất hiện 16 lần
# Từ '08000930705' xuất hiện 16 lần
# Từ 'special' xuất hiện 16 lần
# Từ '12hr' xuất hiện 16 lần
# Từ 'privat' xuất hiện 16 lần
# Từ 'see' xuất hiện 16 lần
# Từ 'take' xuất hiện 16 lần
# Từ 'land' xuất hiện 16 lần
# Từ 'dear' xuất hiện 16 lần
# Từ 'gift' xuất hiện 16 lần
# Từ 'camcord' xuất hiện 15 lần
# Từ 'statement' xuất hiện 15 lần
# Từ 'point' xuất hiện 15 lần
# Từ 'identifi' xuất hiện 15 lần
# Từ 'name' xuất hiện 15 lần
# Từ 'music' xuất hiện 15 lần
# Từ 'xma' xuất hiện 15 lần
# Từ 'price' xuất hiện 15 lần
# Từ 'enter' xuất hiện 15 lần
# Từ 'hi' xuất hiện 15 lần
# Từ 'auction' xuất hiện 15 lần
# Từ 'final' xuất hiện 14 lần
# Từ 'freemsg' xuất hiện 14 lần
# Từ 'updat' xuất hiện 14 lần
# Từ 'colour' xuất hiện 14 lần
# Từ '100' xuất hiện 14 lần
# Từ 'play' xuất hiện 14 lần
# Từ 'match' xuất hiện 14 lần
# Từ 'top' xuất hiện 14 lần
# Từ 'yr' xuất hiện 14 lần
# Từ 'sexi' xuất hiện 14 lần
# Từ 'content' xuất hiện 14 lần
# Từ '86688' xuất hiện 14 lần
# Từ 'winner' xuất hiện 13 lần
# Từ 'weekend' xuất hiện 13 lần
# Từ 'friend' xuất hiện 13 lần
# Từ 'someon' xuất hiện 13 lần
# Từ '10p' xuất hiện 13 lần
# Từ 'hot' xuất hiện 13 lần
# Từ 'doubl' xuất hiện 13 lần
# Từ 'mobileupd8' xuất hiện 13 lần
# Từ '2003' xuất hiện 13 lần
# Từ '800' xuất hiện 13 lần
# Từ 'tell' xuất hiện 13 lần
# Từ 'like' xuất hiện 12 lần
# Từ 'use' xuất hiện 12 lần
# Từ 'ye' xuất hiện 12 lần
# Từ 'last' xuất hiện 12 lần
# Từ 'caller' xuất hiện 12 lần
# Từ 'real' xuất hiện 12 lần
# Từ 'dog' xuất hiện 12 lần
# Từ 'start' xuất hiện 12 lần
# Từ 'reveal' xuất hiện 12 lần
# Từ 'congratul' xuất hiện 12 lần
# Từ 'anytim' xuất hiện 12 lần
# Từ 'minut' xuất hiện 12 lần
# Từ 'fanci' xuất hiện 12 lần
# Từ '08000839402' xuất hiện 12 lần
# Từ 'half' xuất hiện 12 lần
# Từ 'help' xuất hiện 12 lần
# Từ 'good' xuất hiện 12 lần
# Từ 'enjoy' xuất hiện 12 lần
# Từ 'info' xuất hiện 11 lần
# Từ 'pobox' xuất hiện 11 lần
# Từ 'nation' xuất hiện 11 lần
# Từ 'eg' xuất hiện 11 lần
# Từ 'complimentari' xuất hiện 11 lần
# Từ 'oper' xuất hiện 11 lần
# Từ 'ltd' xuất hiện 11 lần
# Từ 'make' xuất hiện 11 lần
# Từ 'think' xuất hiện 11 lần
# Từ 'cd' xuất hiện 11 lần
# Từ 'current' xuất hiện 11 lần
# Từ 'rental' xuất hiện 11 lần
# Từ 'import' xuất hiện 11 lần
# Từ 'need' xuất hiện 11 lần
# Từ 'wan' xuất hiện 11 lần
# Từ 'xxx' xuất hiện 10 lần
# Từ 'tomorrow' xuất hiện 10 lần
# Từ 'follow' xuất hiện 10 lần
# Từ 'player' xuất hiện 10 lần
# Từ 'sent' xuất hiện 10 lần
# Từ 'direct' xuất hiện 10 lần
# Từ 'invit' xuất hiện 10 lần
# Từ '87066' xuất hiện 10 lần
# Từ 'unlimit' xuất hiện 10 lần
# Từ 'easi' xuất hiện 10 lần
# Từ 'babe' xuất hiện 10 lần
# Từ 'motorola' xuất hiện 10 lần
# Từ 'love' xuất hiện 10 lần
# Từ 'ipod' xuất hiện 10 lần
# Từ 'shop' xuất hiện 10 lần
# Từ 'one' xuất hiện 10 lần
# Từ 'opt' xuất hiện 10 lần
# Từ 'sex' xuất hiện 10 lần
# Từ 'na' xuất hiện 10 lần
# Từ 'b' xuất hiện 10 lần
# Từ 'wkli' xuất hiện 9 lần
# Từ 'question' xuất hiện 9 lần
# Từ 'reward' xuất hiện 9 lần
# Từ 'wap' xuất hiện 9 lần
# Từ 'dont' xuất hiện 9 lần
# Từ 'year' xuất hiện 9 lần
# Từ '0800' xuất hiện 9 lần
# Từ 'quiz' xuất hiện 9 lần
# Từ 'age' xuất hiện 9 lần
# Từ 'look' xuất hiện 9 lần
# Từ 'choos' xuất hiện 9 lần
# Từ '1000' xuất hiện 9 lần
# Từ '150' xuất hiện 9 lần
# Từ 'ts' xuất hiện 9 lần
# Từ 'subscrib' xuất hiện 9 lần
# Từ 'chariti' xuất hiện 9 lần
# Từ 'girl' xuất hiện 9 lần
# Từ 'inform' xuất hiện 9 lần
# Từ 'great' xuất hiện 9 lần
# Từ 'comp' xuất hiện 8 lần
# Từ 'fun' xuất hiện 8 lần
# Từ 'valu' xuất hiện 8 lần
# Từ 'miss' xuất hiện 8 lần
# Từ 'news' xuất hiện 8 lần
# Từ '87077' xuất hiện 8 lần
# Từ 'access' xuất hiện 8 lần
# Từ 'x' xuất hiện 8 lần
# Từ 'welcom' xuất hiện 8 lần
# Từ 'term' xuất hiện 8 lần
# Từ 'worth' xuất hiện 8 lần
# Từ 'savamob' xuất hiện 8 lần
# Từ 'area' xuất hiện 8 lần
# Từ '5' xuất hiện 8 lần
# Từ 'mate' xuất hiện 8 lần
# Từ 'either' xuất hiện 8 lần
# Từ 'bid' xuất hiện 8 lần
# Từ 'pl' xuất hiện 8 lần
# Từ 'user' xuất hiện 8 lần
# Từ '08712460324' xuất hiện 8 lần
# Từ 'lucki' xuất hiện 8 lần
# Từ 'give' xuất hiện 8 lần
# Từ 'part' xuất hiện 8 lần
# Từ 'fantasi' xuất hiện 8 lần
# Từ 'england' xuất hiện 7 lần
# Từ '10' xuất hiện 7 lần
# Từ 'inc' xuất hiện 7 lần
# Từ 'speak' xuất hiện 7 lần
# Từ '2004' xuất hiện 7 lần
# Từ 'txting' xuất hiện 7 lần
# Từ 'download' xuất hiện 7 lần
# Từ 'even' xuất hiện 7 lần
# Từ 'secret' xuất hiện 7 lần
# Từ 'admir' xuất hiện 7 lần
# Từ 'tnc' xuất hiện 7 lần
# Từ 'horni' xuất hiện 7 lần
# Từ 'sport' xuất hiện 7 lần
# Từ 'maxim' xuất hiện 7 lần
# Từ 'bluetooth' xuất hiện 7 lần
# Từ 'ldn' xuất hiện 7 lần
# Từ 'tenerif' xuất hiện 7 lần
# Từ 'tc' xuất hiện 7 lần
# Từ 'us' xuất hiện 7 lần
# Từ 'custcar' xuất hiện 7 lần
# Từ 'remov' xuất hiện 7 lần
# Từ '25p' xuất hiện 7 lần
# Từ 'gr8' xuất hiện 7 lần
# Từ 'fantast' xuất hiện 7 lần
# Từ 'best' xuất hiện 7 lần
# Từ 'night' xuất hiện 7 lần
# Từ 'could' xuất hiện 7 lần
# Từ 'summer' xuất hiện 7 lần
# Từ 'store' xuất hiện 7 lần
# Từ 'ntt' xuất hiện 7 lần
# Từ 'log' xuất hiện 7 lần
# Từ 'onto' xuất hiện 7 lần
# Từ 'n' xuất hiện 7 lần
# Từ 'plu' xuất hiện 7 lần
# Từ 'bill' xuất hiện 7 lần
# Từ 'im' xuất hiện 7 lần
# Từ 'detail' xuất hiện 7 lần
# Từ 'may' xuất hiện 6 lần
# Từ 'std' xuất hiện 6 lần
# Từ 'entitl' xuất hiện 6 lần
# Từ 'link' xuất hiện 6 lần
# Từ 'congrat' xuất hiện 6 lần
# Từ 'etc' xuất hiện 6 lần
# Từ 'repres' xuất hiện 6 lần
# Từ 'flight' xuất hiện 6 lần
# Từ '08712300220' xuất hiện 6 lần
# Từ 'quot' xuất hiện 6 lần
# Từ 'standard' xuất hiện 6 lần
# Từ 'sp' xuất hiện 6 lần
# Từ 'handset' xuất hiện 6 lần
# Từ 'answer' xuất hiện 6 lần
# Từ 'loyalti' xuất hiện 6 lần
# Từ 'cc' xuất hiện 6 lần
# Từ 'discount' xuất hiện 6 lần
# Từ 'first' xuất hiện 6 lần
# Từ 'logo' xuất hiện 6 lần
# Từ '40gb' xuất hiện 6 lần
# Từ 'member' xuất hiện 6 lần
# Từ 'age16' xuất hiện 6 lần
# Từ 'spree' xuất hiện 6 lần
# Từ 'holder' xuất hiện 6 lần
# Từ 'pc' xuất hiện 6 lần
# Từ 'b4' xuất hiện 6 lần
# Từ 'book' xuất hiện 6 lần
# Từ 'extra' xuất hiện 6 lần
# Từ 'zed' xuất hiện 6 lần
# Từ 'care' xuất hiện 6 lần
# Từ 'record' xuất hiện 6 lần
# Từ 'asap' xuất hiện 6 lần
# Từ 'gay' xuất hiện 6 lần
# Từ 'guess' xuất hiện 6 lần
# Từ 'digit' xuất hiện 6 lần
# Từ 'an' xuất hiện 6 lần
# Từ 'luck' xuất hiện 6 lần
# Từ 'got' xuất hiện 6 lần
# Từ '0870' xuất hiện 6 lần
# Từ 'arriv' xuất hiện 6 lần
# Từ 'titl' xuất hiện 6 lần
# Từ 'del' xuất hiện 6 lần
# Từ 'pick' xuất hiện 6 lần
# Từ 'hey' xuất hiện 5 lần
# Từ 'still' xuất hiện 5 lần
# Từ 'ok' xuất hiện 5 lần
# Từ 'month' xuất hiện 5 lần
# Từ 'click' xuất hiện 5 lần
# Từ 'subscript' xuất hiện 5 lần
# Từ 'pass' xuất hiện 5 lần
# Từ 'come' xuất hiện 5 lần
# Từ 'voda' xuất hiện 5 lần
# Từ 'sunshin' xuất hiện 5 lần
# Từ 'soni' xuất hiện 5 lần
# Từ 'dvd' xuất hiện 5 lần
# Từ 'locat' xuất hiện 5 lần
# Từ 'bt' xuất hiện 5 lần
# Từ 'must' xuất hiện 5 lần
# Từ 'local' xuất hiện 5 lần
# Từ 'luv' xuất hiện 5 lần
# Từ 'frnd' xuất hiện 5 lần
# Từ '62468' xuất hiện 5 lần
# Từ 'goto' xuất hiện 5 lần
# Từ 'meet' xuất hiện 5 lần
# Từ 'partner' xuất hiện 5 lần
# Từ 'flirt' xuất hiện 5 lần
# Từ 'singl' xuất hiện 5 lần
# Từ 'themob' xuất hiện 5 lần
# Từ 'keep' xuất hiện 5 lần
# Từ 'rcvd' xuất hiện 5 lần
# Từ 'sonyericsson' xuất hiện 5 lần
# Từ 'eve' xuất hiện 5 lần
# Từ 'pobox36504w45wq' xuất hiện 5 lần
# Từ 'activ' xuất hiện 5 lần
# Từ 'visit' xuất hiện 5 lần
# Từ 'mp3' xuất hiện 5 lần
# Từ 'sub' xuất hiện 5 lần
# Từ 'ring' xuất hiện 5 lần
# Từ 'announc' xuất hiện 5 lần
# Từ 'guy' xuất hiện 5 lần
# Từ 'vodafon' xuất hiện 5 lần
# Từ '80062' xuất hiện 5 lần
# Từ 'immedi' xuất hiện 5 lần
# Từ 'alert' xuất hiện 5 lần
# Từ 'txtauction' xuất hiện 5 lần
# Từ 'break' xuất hiện 5 lần
# Từ 'no1' xuất hiện 5 lần
# Từ 'talk' xuất hiện 5 lần
# Từ '08718720201' xuất hiện 5 lần
# Từ '6' xuất hiện 5 lần
# Từ 'regist' xuất hiện 5 lần
# Từ 'ask' xuất hiện 5 lần
# Từ 'xchat' xuất hiện 5 lần
# Từ 'o2' xuất hiện 5 lần
# Từ 'surpris' xuất hiện 5 lần
# Từ 'readi' xuất hiện 5 lần
# Từ '20p' xuất hiện 5 lần
# Từ '1327' xuất hiện 5 lần
# Từ 'croydon' xuất hiện 5 lần
# Từ 'cr9' xuất hiện 5 lần
# Từ '5wb' xuất hiện 5 lần
# Từ 'reach' xuất hiện 5 lần
# Từ '86021' xuất hiện 5 lần
# Từ 'eeri' xuất hiện 5 lần
# Từ 'rpli' xuất hiện 5 lần
# Từ 'comput' xuất hiện 5 lần
# Từ 'fone' xuất hiện 5 lần
# Từ 'flag' xuất hiện 5 lần
# Từ 'spook' xuất hiện 5 lần
# Từ 'tariff' xuất hiện 5 lần
# Từ 'cancel' xuất hiện 5 lần
# Từ '3510i' xuất hiện 5 lần
# Từ '300' xuất hiện 5 lần
# Từ 'hour' xuất hiện 4 lần
# Từ 'v' xuất hiện 4 lần
# Từ 'ac' xuất hiện 4 lần
# Từ 'correct' xuất hiện 4 lần
# Từ '150pm' xuất hiện 4 lần
# Từ 'recent' xuất hiện 4 lần
# Từ 'app' xuất hiện 4 lần
# Từ 'laid' xuất hiện 4 lần
# Từ 'largest' xuất hiện 4 lần
# Từ 'ec2a' xuất hiện 4 lần
# Từ 'noth' xuất hiện 4 lần
# Từ 'netcollex' xuất hiện 4 lần
# Từ 'freephon' xuất hiện 4 lần
# Từ '2optout' xuất hiện 4 lần
# Từ 'hmv' xuất hiện 4 lần
# Từ 'upgrad' xuất hiện 4 lần
# Từ 'card' xuất hiện 4 lần
# Từ '4u' xuất hiện 4 lần
# Từ 'check' xuất hiện 4 lần
# Từ 'decemb' xuất hiện 4 lần
# Từ 'refer' xuất hiện 4 lần
# Từ 'ad' xuất hiện 4 lần
# Từ 'vari' xuất hiện 4 lần
# Từ 'post' xuất hiện 4 lần
# Từ '5000' xuất hiện 4 lần
# Từ 'cw25wx' xuất hiện 4 lần
# Từ 'condit' xuất hiện 4 lần
# Từ '83355' xuất hiện 4 lần
# Từ 'mono' xuất hiện 4 lần
# Từ '85023' xuất hiện 4 lần
# Từ 'within' xuất hiện 4 lần
# Từ 'hello' xuất hiện 4 lần
# Từ 'forward' xuất hiện 4 lần
# Từ 'polyphon' xuất hiện 4 lần
# Từ 'pobox84' xuất hiện 4 lần
# Từ '36504' xuất hiện 4 lần
# Từ 'm8' xuất hiện 4 lần
# Từ 'ibiza' xuất hiện 4 lần
# Từ 'ppm' xuất hiện 4 lần
# Từ 'vip' xuất hiện 4 lần
# Từ 'sale' xuất hiện 4 lần
# Từ 'money' xuất hiện 4 lần
# Từ 'away' xuất hiện 4 lần
# Từ 'sk38xh' xuất hiện 4 lần
# Từ 'contract' xuất hiện 4 lần
# Từ 'place' xuất hiện 4 lần
# Từ 'deliv' xuất hiện 4 lần
# Từ '08712405020' xuất hiện 4 lần
# Từ 'cum' xuất hiện 4 lần
# Từ 'xx' xuất hiện 4 lần
# Từ '08707509020' xuất hiện 4 lần
# Từ 'linerent' xuất hiện 4 lần
# Từ 'optout' xuất hiện 4 lần
# Từ '2nite' xuất hiện 4 lần
# Từ 'hope' xuất hiện 4 lần
# Từ 'hotel' xuất hiện 4 lần
# Từ '2day' xuất hiện 4 lần
# Từ 'brand' xuất hiện 4 lần
# Từ '250' xuất hiện 4 lần
# Từ 'london' xuất hiện 4 lần
# Từ 'mobi' xuất hiện 4 lần
# Từ 'action' xuất hiện 4 lần
# Từ 'arcad' xuất hiện 4 lần
# Từ '08001950382' xuất hiện 4 lần
# Từ 'would' xuất hiện 4 lần
# Từ 'costa' xuất hiện 4 lần
# Từ 'sol' xuất hiện 4 lần
# Từ '87239' xuất hiện 4 lần
# Từ 'inclus' xuất hiện 4 lần
# Từ 'saturday' xuất hiện 4 lần
# Từ 'ntwk' xuất hiện 4 lần
# Từ 'hit' xuất hiện 4 lần
# Từ 'crazi' xuất hiện 4 lần
# Từ 'porn' xuất hiện 4 lần
# Từ 'mth' xuất hiện 4 lần
# Từ 'film' xuất hiện 4 lần
# Từ 'santa' xuất hiện 4 lần
# Từ 'cup' xuất hiện 3 lần
# Từ '12' xuất hiện 3 lần
# Từ '11' xuất hiện 3 lần
# Từ 'co' xuất hiện 3 lần
# Từ 'hl' xuất hiện 3 lần
# Từ 'review' xuất hiện 3 lần
# Từ 'trip' xuất hiện 3 lần
# Từ 'hear' xuất hiện 3 lần
# Từ 'k52' xuất hiện 3 lần
# Từ '786' xuất hiện 3 lần
# Từ 'unredeem' xuất hiện 3 lần
# Từ 'tonight' xuất hiện 3 lần
# Từ 'tv' xuất hiện 3 lần
# Từ '89545' xuất hiện 3 lần
# Từ 'star' xuất hiện 3 lần
# Từ '25' xuất hiện 3 lần
# Từ 'recd' xuất hiện 3 lần
# Từ 'penc' xuất hiện 3 lần
# Từ 'chart' xuất hiện 3 lần
# Từ '0845' xuất hiện 3 lần
# Từ 'newest' xuất hiện 3 lần
# Từ 'm26' xuất hiện 3 lần
# Từ '3uz' xuất hiện 3 lần
# Từ '08002986906' xuất hiện 3 lần
# Từ 'germani' xuất hiện 3 lần
# Từ 'via' xuất hiện 3 lần
# Từ 'valentin' xuất hiện 3 lần
# Từ '83600' xuất hiện 3 lần
# Từ '11mth' xuất hiện 3 lần
# Từ '87131' xuất hiện 3 lần
# Từ 'heart' xuất hiện 3 lần
# Từ '3min' xuất hiện 3 lần
# Từ 'close' xuất hiện 3 lần
# Từ 'wc1n3xx' xuất hiện 3 lần
# Từ 'loan' xuất hiện 3 lần
# Từ 'notic' xuất hiện 3 lần
# Từ 'ibhltd' xuất hiện 3 lần
# Từ 'ldnw15h' xuất hiện 3 lần
# Từ 'renew' xuất hiện 3 lần
# Từ 'box95qu' xuất hiện 3 lần
# Từ 'unsub' xuất hiện 3 lần
# Từ '08715705022' xuất hiện 3 lần
# Từ '542' xuất hiện 3 lần
# Từ 'ladi' xuất hiện 3 lần
# Từ 'kick' xuất hiện 3 lần
# Từ 'euro2004' xuất hiện 3 lần
# Từ 'daili' xuất hiện 3 lần
# Từ 'postcod' xuất hiện 3 lần
# Từ '20' xuất hiện 3 lần
# Từ 'work' xuất hiện 3 lần
# Từ 'textoper' xuất hiện 3 lần
# Từ '50' xuất hiện 3 lần
# Từ 'listen' xuất hiện 3 lần
# Từ '4t' xuất hiện 3 lần
# Từ 'pari' xuất hiện 3 lần
# Từ 'citi' xuất hiện 3 lần
# Từ 'skilgm' xuất hiện 3 lần
# Từ 'ever' xuất hiện 3 lần
# Từ 'life' xuất hiện 3 lần
# Từ 'w45wq' xuất hiện 3 lần
# Từ '3qxj9' xuất hiện 3 lần
# Từ '9ae' xuất hiện 3 lần
# Từ 'alfi' xuất hiện 3 lần
# Từ 'moon' xuất hiện 3 lần
# Từ 'children' xuất hiện 3 lần
# Từ 'song' xuất hiện 3 lần
# Từ '08701417012' xuất hiện 3 lần
# Từ 'profit' xuất hiện 3 lần
# Từ 'cust' xuất hiện 3 lần
# Từ 'five' xuất hiện 3 lần
# Từ '434' xuất hiện 3 lần
# Từ 'sk3' xuất hiện 3 lần
# Từ '8wp' xuất hiện 3 lần
# Từ 'address' xuất hiện 3 lần
# Từ 'male' xuất hiện 3 lần
# Từ 'cheap' xuất hiện 3 lần
# Từ 'compani' xuất hiện 3 lần
# Từ '3g' xuất hiện 3 lần
# Từ 'videophon' xuất hiện 3 lần
# Từ 'videochat' xuất hiện 3 lần
# Từ 'wid' xuất hiện 3 lần
# Từ 'java' xuất hiện 3 lần
# Từ 'dload' xuất hiện 3 lần
# Từ 'nolin' xuất hiện 3 lần
# Từ 'rentl' xuất hiện 3 lần
# Từ 'f' xuất hiện 3 lần
# Từ 'peopl' xuất hiện 3 lần
# Từ 'cant' xuất hiện 3 lần
# Từ 'sipix' xuất hiện 3 lần
# Từ 'receipt' xuất hiện 3 lần
# Từ 'bore' xuất hiện 3 lần
# Từ 'yesterday' xuất hiện 3 lần
# Từ 'mani' xuất hiện 3 lần
# Từ 'let' xuất hiện 3 lần
# Từ 'futur' xuất hiện 3 lần
# Từ 'jordan' xuất hiện 3 lần
# Từ '84128' xuất hiện 3 lần
# Từ 'set' xuất hiện 3 lần
# Từ 'jamster' xuất hiện 3 lần
# Từ 'origin' xuất hiện 3 lần
# Từ '3gbp' xuất hiện 3 lần
# Từ 'photo' xuất hiện 3 lần
# Từ 'arsen' xuất hiện 3 lần
# Từ 'pod' xuất hiện 3 lần
# Từ 'alon' xuất hiện 3 lần
# Từ '09066362231' xuất hiện 3 lần
# Từ '07xxxxxxxxx' xuất hiện 3 lần
# Từ 'high' xuất hiện 3 lần
# Từ 'shortli' xuất hiện 3 lần
# Từ '7250i' xuất hiện 3 lần
# Từ 'stay' xuất hiện 3 lần
# Từ '82242' xuất hiện 3 lần
# Từ 'sorri' xuất hiện 3 lần
# Từ 'connect' xuất hiện 3 lần
# Từ 'ticket' xuất hiện 3 lần
# Từ '18yr' xuất hiện 3 lần
# Từ 'abta' xuất hiện 3 lần
# Từ 'right' xuất hiện 3 lần
# Từ 'person' xuất hiện 3 lần
# Từ 'well' xuất hiện 3 lần
# Từ '09050090044' xuất hiện 3 lần
# Từ 'toclaim' xuất hiện 3 lần
# Từ 'pobox334' xuất hiện 3 lần
# Từ 'stockport' xuất hiện 3 lần
# Từ 'max10min' xuất hiện 3 lần
# Từ 'provid' xuất hiện 3 lần
# Từ 'freefon' xuất hiện 3 lần
# Từ 'box97n7qp' xuất hiện 3 lần
# Từ 'men' xuất hiện 3 lần
# Từ 'offici' xuất hiện 3 lần
# Từ 'ip4' xuất hiện 3 lần
# Từ '5we' xuất hiện 3 lần
# Từ 'cross' xuất hiện 3 lần
# Từ 'also' xuất hiện 3 lần
# Từ '88066' xuất hiện 3 lần
# Từ '80082' xuất hiện 3 lần
# Từ 'halloween' xuất hiện 3 lần
# Từ 'sky' xuất hiện 3 lần
# Từ 'adult' xuất hiện 3 lần
# Từ '09066612661' xuất hiện 3 lần
# Từ 'sept' xuất hiện 3 lần
# Từ '28' xuất hiện 3 lần
# Từ 'king' xuất hiện 3 lần
# Từ 'super' xuất hiện 3 lần
# Từ 'littl' xuất hiện 3 lần
# Từ '50p' xuất hiện 3 lần
# Từ 'deliveredtomorrow' xuất hiện 3 lần
# Từ 'save' xuất hiện 3 lần
# Từ 'callback' xuất hiện 3 lần
# Từ '200' xuất hiện 3 lần
# Từ '7' xuất hiện 3 lần
# Từ 'nat' xuất hiện 3 lần
# Từ 'goal' xuất hiện 3 lần
# Từ '30' xuất hiện 3 lần
# Từ 'fa' xuất hiện 2 lần
# Từ 'tkt' xuất hiện 2 lần
# Từ '87121' xuất hiện 2 lần
# Từ 'darl' xuất hiện 2 lần
# Từ 'chg' xuất hiện 2 lần
# Từ 'rcv' xuất hiện 2 lần
# Từ 'six' xuất hiện 2 lần
# Từ 'team' xuất hiện 2 lần
# Từ 'sptv' xuất hiện 2 lần
# Từ 'cinema' xuất hiện 2 lần
# Từ '09061209465' xuất hiện 2 lần
# Từ 'suprman' xuất hiện 2 lần
# Từ 'matrix3' xuất hiện 2 lần
# Từ 'starwars3' xuất hiện 2 lần
# Từ 'advis' xuất hiện 2 lần
# Từ 'simpli' xuất hiện 2 lần
# Từ 'password' xuất hiện 2 lần
# Từ 'verifi' xuất hiện 2 lần
# Từ 'gent' xuất hiện 2 lần
# Từ '45239' xuất hiện 2 lần
# Từ '350' xuất hiện 2 lần
# Từ 'q' xuất hiện 2 lần
# Từ 'countri' xuất hiện 2 lần
# Từ 'ansr' xuất hiện 2 lần
# Từ 'tyron' xuất hiện 2 lần
# Từ '69888' xuất hiện 2 lần
# Từ 'hardcor' xuất hiện 2 lần
# Từ 'randi' xuất hiện 2 lần
# Từ '08700621170150p' xuất hiện 2 lần
# Từ 'arrang' xuất hiện 2 lần
# Từ 'uniqu' xuất hiện 2 lần
# Từ 'enough' xuất hiện 2 lần
# Từ 'august' xuất hiện 2 lần
# Từ 'dream' xuất hiện 2 lần
# Từ 'soon' xuất hiện 2 lần
# Từ 'horo' xuất hiện 2 lần
# Từ 'sign' xuất hiện 2 lần
# Từ 'sam' xuất hiện 2 lần
# Từ '125gift' xuất hiện 2 lần
# Từ '69698' xuất hiện 2 lần
# Từ 'qualiti' xuất hiện 2 lần
# Từ 'pay' xuất hiện 2 lần
# Từ 'sim' xuất hiện 2 lần
# Từ '021' xuất hiện 2 lần
# Từ 'blind' xuất hiện 2 lần
# Từ '82468' xuất hiện 2 lần
# Từ 'smart' xuất hiện 2 lần
# Từ 'fix' xuất hiện 2 lần
# Từ '0844' xuất hiện 2 lần
# Từ '861' xuất hiện 2 lần
# Từ '85' xuất hiện 2 lần
# Từ 'prepay' xuất hiện 2 lần
# Từ 'lifetim' xuất hiện 2 lần
# Từ 'shag' xuất hiện 2 lần
# Từ 'avail' xuất hiện 2 lần
# Từ '4mth' xuất hiện 2 lần
# Từ 'mobilesdirect' xuất hiện 2 lần
# Từ '08000938767' xuất hiện 2 lần
# Từ 'or2stoptxt' xuất hiện 2 lần
# Từ 'true' xuất hiện 2 lần
# Từ 'box334sk38ch' xuất hiện 2 lần
# Từ 'competit' xuất hiện 2 lần
# Từ '80086' xuất hiện 2 lần
# Từ 'lover' xuất hiện 2 lần
# Từ 'name1' xuất hiện 2 lần
# Từ 'name2' xuất hiện 2 lần
# Từ 'mobno' xuất hiện 2 lần
# Từ 'adam' xuất hiện 2 lần
# Từ '07123456789' xuất hiện 2 lần
# Từ 'yahoo' xuất hiện 2 lần
# Từ 'txtno' xuất hiện 2 lần
# Từ 'ave' xuất hiện 2 lần
# Từ 'purpos' xuất hiện 2 lần
# Từ 'tenant' xuất hiện 2 lần
# Từ 'refus' xuất hiện 2 lần
# Từ '0207' xuất hiện 2 lần
# Từ '153' xuất hiện 2 lần
# Từ 'juli' xuất hiện 2 lần
# Từ 'dave' xuất hiện 2 lần
# Từ '09061743806' xuất hiện 2 lần
# Từ 'box326' xuất hiện 2 lần
# Từ 'cha' xuất hiện 2 lần
# Từ '24hr' xuất hiện 2 lần
# Từ '08718738001' xuất hiện 2 lần
# Từ 'web' xuất hiện 2 lần
# Từ 'call09050000327' xuất hiện 2 lần
# Từ '2000' xuất hiện 2 lần
# Từ '08712402050' xuất hiện 2 lần
# Từ '10ppm' xuất hiện 2 lần
# Từ 'ag' xuất hiện 2 lần
# Từ 'promo' xuất hiện 2 lần
# Từ 'kept' xuất hiện 2 lần
# Từ 'result' xuất hiện 2 lần
# Từ '83222' xuất hiện 2 lần
# Từ 'textbuddi' xuất hiện 2 lần
# Từ 'search' xuất hiện 2 lần
# Từ '89693' xuất hiện 2 lần
# Từ '40533' xuất hiện 2 lần
# Từ 'rstm' xuất hiện 2 lần
# Từ 'sw7' xuất hiện 2 lần
# Từ '3ss' xuất hiện 2 lần
# Từ 'premium' xuất hiện 2 lần
# Từ 'sue' xuất hiện 2 lần
# Từ 'old' xuất hiện 2 lần
# Từ '09071512433' xuất hiện 2 lần
# Từ '050703' xuất hiện 2 lần
# Từ 'csbcm4235wc1n3xx' xuất hiện 2 lần
# Từ 'callcost' xuất hiện 2 lần
# Từ 'mobilesvari' xuất hiện 2 lần
# Từ 'email' xuất hiện 2 lần
# Từ 'nokia6650' xuất hiện 2 lần
# Từ '81151' xuất hiện 2 lần
# Từ 'ctxt' xuất hiện 2 lần
# Từ 'helplin' xuất hiện 2 lần
# Từ '08706091795' xuất hiện 2 lần
# Từ '40' xuất hiện 2 lần
# Từ 'around' xuất hiện 2 lần
# Từ 'premier' xuất hiện 2 lần
# Từ '88039' xuất hiện 2 lần
# Từ 'tscs087147403231winawk' xuất hiện 2 lần
# Từ '0578' xuất hiện 2 lần
# Từ 'commun' xuất hiện 2 lần
# Từ 'subpoli' xuất hiện 2 lần
# Từ '08718727870' xuất hiện 2 lần
# Từ 'm263uz' xuất hiện 2 lần
# Từ 'cashto' xuất hiện 2 lần
# Từ '08000407165' xuất hiện 2 lần
# Từ 'getstop' xuất hiện 2 lần
# Từ '88222' xuất hiện 2 lần
# Từ 'php' xuất hiện 2 lần
# Từ '08002888812' xuất hiện 2 lần
# Từ 'wed' xuất hiện 2 lần
# Từ '09066350750' xuất hiện 2 lần
# Từ 'world' xuất hiện 2 lần
# Từ 'discreet' xuất hiện 2 lần
# Từ 'suppli' xuất hiện 2 lần
# Từ 'virgin' xuất hiện 2 lần
# Từ '41685' xuất hiện 2 lần
# Từ 'till' xuất hiện 2 lần
# Từ '10k' xuất hiện 2 lần
# Từ 'liverpool' xuất hiện 2 lần
# Từ '09058094565' xuất hiện 2 lần
# Từ 'remind' xuất hiện 2 lần
# Từ 'cheaper' xuất hiện 2 lần
# Từ 'peak' xuất hiện 2 lần
# Từ '88600' xuất hiện 2 lần
# Từ 'lux' xuất hiện 2 lần
# Từ 'filthi' xuất hiện 2 lần
# Từ 'valid12hr' xuất hiện 2 lần
# Từ '09063458130' xuất hiện 2 lần
# Từ 'polyph' xuất hiện 2 lần
# Từ 'somebodi' xuất hiện 2 lần
# Từ 'secretli' xuất hiện 2 lần
# Từ 'datebox1282essexcm61xn' xuất hiện 2 lần
# Từ 'ls15hb' xuất hiện 2 lần
# Từ 'euro' xuất hiện 2 lần
# Từ 'flower' xuất hiện 2 lần
# Từ '84025' xuất hiện 2 lần
# Từ 'lot' xuất hiện 2 lần
# Từ '09050003091' xuất hiện 2 lần
# Từ 'c52' xuất hiện 2 lần
# Từ 'p' xuất hiện 2 lần
# Từ '09061790121' xuất hiện 2 lần
# Từ 'speedchat' xuất hiện 2 lần
# Từ '08000776320' xuất hiện 2 lần
# Từ 'wish' xuất hiện 2 lần
# Từ 'forget' xuất hiện 2 lần
# Từ 'request' xuất hiện 2 lần
# Từ '4fil' xuất hiện 2 lần
# Từ 'ralli' xuất hiện 2 lần
# Từ 'energi' xuất hiện 2 lần
# Từ 'celeb' xuất hiện 2 lần
# Từ 'voicemail' xuất hiện 2 lần
# Từ 'choic' xuất hiện 2 lần
# Từ '87021' xuất hiện 2 lần
# Từ 'txtin' xuất hiện 2 lần
# Từ '4info' xuất hiện 2 lần
# Từ 'complet' xuất hiện 2 lần
# Từ 'hungri' xuất hiện 2 lần
# Từ 'feel' xuất hiện 2 lần
# Từ 'lion' xuất hiện 2 lần
# Từ 'lionm' xuất hiện 2 lần
# Từ 'lionp' xuất hiện 2 lần
# Từ 'potter' xuất hiện 2 lần
# Từ 'phoenix' xuất hiện 2 lần
# Từ 'harri' xuất hiện 2 lần
# Từ 'among' xuất hiện 2 lần
# Từ 'reader' xuất hiện 2 lần
# Từ 'balanc' xuất hiện 2 lần
# Từ 'sauci' xuất hiện 2 lần
# Từ 'bear' xuất hiện 2 lần
# Từ 'upload' xuất hiện 2 lần
# Từ '08718730666' xuất hiện 2 lần
# Từ 'textpod' xuất hiện 2 lần
# Từ 'clair' xuất hiện 2 lần
# Từ 'luci' xuất hiện 2 lần
# Từ 'hubbi' xuất hiện 2 lần
# Từ 'fri' xuất hiện 2 lần
# Từ 'leav' xuất hiện 2 lần
# Từ '80488' xuất hiện 2 lần
# Từ 'jsco' xuất hiện 2 lần
# Từ 'sing' xuất hiện 2 lần
# Từ '7250' xuất hiện 2 lần
# Từ 'british' xuất hiện 2 lần
# Từ 'sw73ss' xuất hiện 2 lần
# Từ 'dracula' xuất hiện 2 lần
# Từ 'ghost' xuất hiện 2 lần
# Từ 'addamsfa' xuất hiện 2 lần
# Từ 'munster' xuất hiện 2 lần
# Từ 'exorcist' xuất hiện 2 lần
# Từ 'twilight' xuất hiện 2 lần
# Từ 'respons' xuất hiện 2 lần
# Từ 'cam' xuất hiện 2 lần
# Từ 'msg150p' xuất hiện 2 lần
# Từ '2rcv' xuất hiện 2 lần
# Từ 'hlp' xuất hiện 2 lần
# Từ '08712317606' xuất hiện 2 lần
# Từ '08712405022' xuất hiện 2 lần
# Từ 'wiv' xuất hiện 2 lần
# Từ 'marri' xuất hiện 2 lần
# Từ '81303' xuất hiện 2 lần
# Từ 'hard' xuất hiện 2 lần
# Từ '121' xuất hiện 2 lần
# Từ 'biggest' xuất hiện 2 lần
# Từ 'wow' xuất hiện 2 lần
# Từ 'boy' xuất hiện 2 lần
# Từ '2007' xuất hiện 2 lần
# Từ 'tour' xuất hiện 2 lần
# Từ 'chosen' xuất hiện 2 lần
# Từ 'bahama' xuất hiện 2 lần
# Từ 'buy' xuất hiện 2 lần
# Từ 'press' xuất hiện 2 lần
# Từ '0' xuất hiện 2 lần
# Từ 'purchas' xuất hiện 2 lần
# Từ 'big' xuất hiện 2 lần
# Từ 'excit' xuất hiện 2 lần
# Từ '3100' xuất hiện 2 lần
# Từ 'straight' xuất hiện 2 lần
# Từ 'wet' xuất hiện 2 lần
# Từ '89555' xuất hiện 2 lần
# Từ 'g696ga' xuất hiện 2 lần
# Từ 'pm' xuất hiện 2 lần
# Từ 'upto' xuất hiện 2 lần
# Từ '12mth' xuất hiện 2 lần
# Từ '0776xxxxxxx' xuất hiện 2 lần
# Từ '326' xuất hiện 2 lần
# Từ 'total' xuất hiện 2 lần
# Từ '80182' xuất hiện 2 lần
# Từ '08452810073' xuất hiện 2 lần
# Từ '09066358152' xuất hiện 2 lần
# Từ 'prompt' xuất hiện 2 lần
# Từ 'mind' xuất hiện 2 lần
# Từ 'done' xuất hiện 2 lần
# Từ '61610' xuất hiện 2 lần
# Từ 'yo' xuất hiện 2 lần
# Từ 'tsc' xuất hiện 2 lần
# Từ 'aom' xuất hiện 2 lần
# Từ 'gender' xuất hiện 2 lần
# Từ 'yer' xuất hiện 2 lần
# Từ 'eng' xuất hiện 2 lần
# Từ 'box39822' xuất hiện 2 lần
# Từ 'w111wx' xuất hiện 2 lần
# Từ 'hol' xuất hiện 2 lần
# Từ 'med' xuất hiện 2 lần
# Từ 'satisfi' xuất hiện 2 lần
# Từ 'home' xuất hiện 2 lần
# Từ 'pix' xuất hiện 2 lần
# Từ 'ref' xuất hiện 2 lần
# Từ 'respond' xuất hiện 2 lần
# Từ '300p' xuất hiện 2 lần
# Từ 'heard' xuất hiện 2 lần
# Từ 'u4' xuất hiện 2 lần
# Từ 'rude' xuất hiện 2 lần
# Từ '8552' xuất hiện 2 lần
# Từ '88877' xuất hiện 2 lần
# Từ 'lost' xuất hiện 2 lần
# Từ 'upd8' xuất hiện 2 lần
# Từ '21870000' xuất hiện 2 lần
# Từ 'mailbox' xuất hiện 2 lần
# Từ '09056242159' xuất hiện 2 lần
# Từ 'retriev' xuất hiện 2 lần
# Từ 'pub' xuất hiện 2 lần
# Từ 'street' xuất hiện 2 lần
# Từ 'duchess' xuất hiện 2 lần
# Từ 'cornwal' xuất hiện 2 lần
# Từ '008704050406' xuất hiện 2 lần
# Từ '08701417012150p' xuất hiện 2 lần
# Từ 'score' xuất hiện 2 lần
# Từ 'town' xuất hiện 2 lần
# Từ 'babi' xuất hiện 2 lần
# Từ 'thing' xuất hiện 2 lần
# Từ 'slo' xuất hiện 2 lần
# Từ '24' xuất hiện 2 lần
# Từ 'acl03530150pm' xuất hiện 2 lần
# Từ 'brought' xuất hiện 2 lần
# Từ 'bx420' xuất hiện 2 lần
# Từ 'amaz' xuất hiện 2 lần
# Từ 'picsfree1' xuất hiện 2 lần
# Từ 'instruct' xuất hiện 2 lần
# Từ 'knock' xuất hiện 2 lần
# Từ 'norm' xuất hiện 2 lần
# Từ '69696' xuất hiện 2 lần
# Từ 'nyt' xuất hiện 2 lần
# Từ '3lp' xuất hiện 2 lần
# Từ 'includ' xuất hiện 2 lần
# Từ 'fastest' xuất hiện 2 lần
# Từ 'grow' xuất hiện 2 lần
# Từ '2stoptxt' xuất hiện 2 lần
# Từ 'luxuri' xuất hiện 2 lần
# Từ 'canari' xuất hiện 2 lần
# Từ 'island' xuất hiện 2 lần
# Từ 'burger' xuất hiện 2 lần
# Từ 'interflora' xuất hiện 2 lần
# Từ 'everyon' xuất hiện 2 lần
# Từ 'sinc' xuất hiện 2 lần
# Từ 'warm' xuất hiện 2 lần
# Từ 'bring' xuất hiện 2 lần
# Từ 'sound' xuất hiện 2 lần
# Từ '88888' xuất hiện 2 lần
# Từ 'realiti' xuất hiện 2 lần
# Từ 'yet' xuất hiện 2 lần
# Từ 'drive' xuất hiện 2 lần
# Từ 'improv' xuất hiện 2 lần
# Từ 'lotr' xuất hiện 2 lần
# Từ '08708034412' xuất hiện 2 lần
# Từ 'lookatm' xuất hiện 2 lần
# Từ '09061221066' xuất hiện 2 lần
# Từ 'fromm' xuất hiện 2 lần
# Từ 'pobox45w2tg150p' xuất hiện 2 lần
# Từ 'truli' xuất hiện 2 lần
# Từ 'wo' xuất hiện 2 lần
# Từ 'movi' xuất hiện 2 lần
# Từ 'bank' xuất hiện 2 lần
# Từ 'granit' xuất hiện 2 lần
# Từ 'issu' xuất hiện 2 lần
# Từ 'explos' xuất hiện 2 lần
# Từ 'nasdaq' xuất hiện 2 lần
# Từ 'symbol' xuất hiện 2 lần
# Từ 'cdgt' xuất hiện 2 lần
# Từ 'thur' xuất hiện 2 lần
# Từ 'sat' xuất hiện 2 lần
# Từ 'unabl' xuất hiện 2 lần
# Từ 'class' xuất hiện 2 lần
# Từ 'iscom' xuất hiện 2 lần
# Từ 'blu' xuất hiện 2 lần
# Từ 'wml' xuất hiện 2 lần
# Từ '09061743386' xuất hiện 2 lần
# Từ 'spanish' xuất hiện 2 lần
# Từ 'indic' xuất hiện 2 lần
# Từ 'accid' xuất hiện 2 lần
# Từ '2find' xuất hiện 2 lần
# Từ 'anoth' xuất hiện 2 lần
# Từ 'polo' xuất hiện 2 lần
# Từ 'suit' xuất hiện 2 lần
# Từ '373' xuất hiện 2 lần
# Từ 'w1j' xuất hiện 2 lần
# Từ '6hl' xuất hiện 2 lần
# Từ 'busi' xuất hiện 2 lần
# Từ 'explicit' xuất hiện 2 lần
# Từ 'sec' xuất hiện 2 lần
# Từ '02073162414' xuất hiện 2 lần
# Từ '89070' xuất hiện 2 lần
# Từ 'mnth' xuất hiện 2 lần
# Từ '86888' xuất hiện 2 lần
# Từ '3hr' xuất hiện 2 lần
# Từ 'txtstop' xuất hiện 2 lần
# Từ 'randomli' xuất hiện 2 lần
# Từ 'loyal' xuất hiện 2 lần
# Từ '09066380611' xuất hiện 2 lần
# Từ 'support' xuất hiện 2 lần
# Từ '08718726270' xuất hiện 2 lần
# Từ 'warner' xuất hiện 2 lần
# Từ 'villag' xuất hiện 2 lần
# Từ 'henri' xuất hiện 2 lần
# Từ 'donat' xuất hiện 2 lần
# Từ 'wallpap' xuất hiện 2 lần
# Từ 'due' xuất hiện 2 lần
# Từ 'mayb' xuất hiện 2 lần
# Từ '09061213237' xuất hiện 2 lần
# Từ 'm227xi' xuất hiện 2 lần
# Từ '2p' xuất hiện 2 lần
# Từ '21st' xuất hiện 1 lần
# Từ '08452810075over18' xuất hiện 1 lần
# Từ 'tb' xuất hiện 1 lần
# Từ 'receivea' xuất hiện 1 lần
# Từ 'kl341' xuất hiện 1 lần
# Từ '08002986030' xuất hiện 1 lần
# Từ 'csh11' xuất hiện 1 lần
# Từ '6day' xuất hiện 1 lần
# Từ 'tsandc' xuất hiện 1 lần
# Từ 'membership' xuất hiện 1 lần
# Từ 'jackpot' xuất hiện 1 lần
# Từ '81010' xuất hiện 1 lần
# Từ 'lccltd' xuất hiện 1 lần
# Từ '4403ldnw1a7rw18' xuất hiện 1 lần
# Từ 'xxxmobilemovieclub' xuất hiện 1 lần
# Từ 'macedonia' xuất hiện 1 lần
# Từ 'wale' xuất hiện 1 lần
# Từ 'scotland' xuất hiện 1 lần
# Từ 'poboxox36504w45wq' xuất hiện 1 lần
# Từ 'confirm' xuất hiện 1 lần
# Từ '07732584351' xuất hiện 1 lần
# Từ 'rodger' xuất hiện 1 lần
# Từ 'burn' xuất hiện 1 lần
# Từ 'jersey' xuất hiện 1 lần
# Từ 'devil' xuất hiện 1 lần
# Từ 'detroit' xuất hiện 1 lần
# Từ 'red' xuất hiện 1 lần
# Từ 'wing' xuất hiện 1 lần
# Từ 'ice' xuất hiện 1 lần
# Từ 'hockey' xuất hiện 1 lần
# Từ 'incorrect' xuất hiện 1 lần
# Từ '09066364589' xuất hiện 1 lần
# Từ 'eurodisinc' xuất hiện 1 lần
# Từ 'trav' xuất hiện 1 lần
# Từ 'aco' xuất hiện 1 lần
# Từ 'entry41' xuất hiện 1 lần
# Từ 'di' xuất hiện 1 lần
# Từ 'morefrmmob' xuất hiện 1 lần
# Từ 'shracomorsglsuplt' xuất hiện 1 lần
# Từ 'ls1' xuất hiện 1 lần
# Từ '3aj' xuất hiện 1 lần
# Từ 'ken' xuất hiện 1 lần
# Từ 'stuff' xuất hiện 1 lần
# Từ '169' xuất hiện 1 lần
# Từ '6031' xuất hiện 1 lần
# Từ '85069' xuất hiện 1 lần
# Từ 'usher' xuất hiện 1 lần
# Từ 'britney' xuất hiện 1 lần
# Từ 'fml' xuất hiện 1 lần
# Từ '07742676969' xuất hiện 1 lần
# Từ '08719180248' xuất hiện 1 lần
# Từ '09064019788' xuất hiện 1 lần
# Từ 'box42wr29c' xuất hiện 1 lần
# Từ '7548' xuất hiện 1 lần
# Từ '4041' xuất hiện 1 lần
# Từ 'algarv' xuất hiện 1 lần
# Từ 'gravel' xuất hiện 1 lần
# Từ 'nt' xuất hiện 1 lần
# Từ 'svc' xuất hiện 1 lần
# Từ '69988' xuất hiện 1 lần
# Từ 'femal' xuất hiện 1 lần
# Từ 'annonc' xuất hiện 1 lần
# Từ '07046744435' xuất hiện 1 lần
# Từ '0871277810810' xuất hiện 1 lần
# Từ 'bootydeli' xuất hiện 1 lần
# Từ 'bangbab' xuất hiện 1 lần
# Từ 'way' xuất hiện 1 lần
# Từ 'bangb' xuất hiện 1 lần
# Từ 'menu' xuất hiện 1 lần
# Từ 's89' xuất hiện 1 lần
# Từ '0808' xuất hiện 1 lần
# Từ '145' xuất hiện 1 lần
# Từ '4742' xuất hiện 1 lần
# Từ '30th' xuất hiện 1 lần
# Từ 'career' xuất hiện 1 lần
# Từ 'flyng' xuất hiện 1 lần
# Từ 'ari' xuất hiện 1 lần
# Từ 'thirtyeight' xuất hiện 1 lần
# Từ '447801259231' xuất hiện 1 lần
# Từ '09058094597' xuất hiện 1 lần
# Từ 'realli' xuất hiện 1 lần
# Từ 'nake' xuất hiện 1 lần
# Từ 'chang' xuất hiện 1 lần
# Từ '87070' xuất hiện 1 lần
# Từ 'club4' xuất hiện 1 lần
# Từ 'box1146' xuất hiện 1 lần
# Từ 'mk45' xuất hiện 1 lần
# Từ '2wt' xuất hiện 1 lần
# Từ 'genuin' xuất hiện 1 lần
# Từ 'rodds1' xuất hiện 1 lần
# Từ 'aberdeen' xuất hiện 1 lần
# Từ 'unit' xuất hiện 1 lần
# Từ 'kingdom' xuất hiện 1 lần
# Từ 'hide' xuất hiện 1 lần
# Từ 'gossip' xuất hiện 1 lần
# Từ 'fit' xuất hiện 1 lần
# Từ 'funki' xuất hiện 1 lần
# Từ '85222' xuất hiện 1 lần
# Từ 'winnersclub' xuất hiện 1 lần
# Từ '84' xuất hiện 1 lần
# Từ 'xxuk' xuất hiện 1 lần
# Từ 'suzi' xuất hiện 1 lần
# Từ 'websit' xuất hiện 1 lần
# Từ '08708800282' xuất hiện 1 lần
# Từ 'rp176781' xuất hiện 1 lần
# Từ '08717205546' xuất hiện 1 lần
# Từ 't91' xuất hiện 1 lần
# Từ 'gbp' xuất hiện 1 lần
# Từ '09057039994' xuất hiện 1 lần
# Từ '6month' xuất hiện 1 lần
# Từ '2814032' xuất hiện 1 lần
# Từ 'cal' xuất hiện 1 lần
# Từ 'l' xuất hiện 1 lần
# Từ '09064012103' xuất hiện 1 lần
# Từ '09111032124' xuất hiện 1 lần
# Từ 'pobox12n146tf150p' xuất hiện 1 lần
# Từ '09058094455' xuất hiện 1 lần
# Từ '3650' xuất hiện 1 lần
# Từ '09066382422' xuất hiện 1 lần
# Từ '300603' xuất hiện 1 lần
# Từ 'bcm4284' xuất hiện 1 lần
# Từ 'homeown' xuất hiện 1 lần
# Từ 'previous' xuất hiện 1 lần
# Từ '1956669' xuất hiện 1 lần
# Từ 'upgrdcentr' xuất hiện 1 lần
# Từ '26th' xuất hiện 1 lần
# Từ 'okmail' xuất hiện 1 lần
# Từ 'moan' xuất hiện 1 lần
# Từ '69888nyt' xuất hiện 1 lần
# Từ '09050002311' xuất hiện 1 lần
# Từ 'b4280703' xuất hiện 1 lần
# Từ 'boltblu' xuất hiện 1 lần
# Từ 'poly3' xuất hiện 1 lần
# Từ 'slide' xuất hiện 1 lần
# Từ 'yeah' xuất hiện 1 lần
# Từ 'slow' xuất hiện 1 lần
# Từ 'jamz' xuất hiện 1 lần
# Từ 'toxic' xuất hiện 1 lần
# Từ 'pin' xuất hiện 1 lần
# Từ 'tgxxrz' xuất hiện 1 lần
# Từ 'reciev' xuất hiện 1 lần
# Từ 'channel' xuất hiện 1 lần
# Từ 'teletext' xuất hiện 1 lần
# Từ 'pg' xuất hiện 1 lần
# Từ '07815296484' xuất hiện 1 lần
# Từ '41782' xuất hiện 1 lần
# Từ 'monthlysubscript' xuất hiện 1 lần
# Từ 'csc' xuất hiện 1 lần
# Từ '2stop' xuất hiện 1 lần
# Từ '09050005321' xuất hiện 1 lần
# Từ 'textand' xuất hiện 1 lần
# Từ '08002988890' xuất hiện 1 lần
# Từ '07753741225' xuất hiện 1 lần
# Từ '08715203677' xuất hiện 1 lần
# Từ '42478' xuất hiện 1 lần
# Từ '0825' xuất hiện 1 lần
# Từ 'xclusiv' xuất hiện 1 lần
# Từ 'clubsaisai' xuất hiện 1 lần
# Từ '2morow' xuất hiện 1 lần
# Từ 'soire' xuất hiện 1 lần
# Từ 'zouk' xuất hiện 1 lần
# Từ 'nichol' xuất hiện 1 lần
# Từ 'rose' xuất hiện 1 lần
# Từ '22' xuất hiện 1 lần
# Từ '4882' xuất hiện 1 lần
# Từ '09064019014' xuất hiện 1 lần
# Từ '08715203694' xuất hiện 1 lần
# Từ '88800' xuất hiện 1 lần
# Từ '89034' xuất hiện 1 lần
# Từ '08718711108' xuất hiện 1 lần
# Từ 'sun0819' xuất hiện 1 lần
# Từ 'seem' xuất hiện 1 lần
# Từ 'cool' xuất hiện 1 lần
# Từ '08452810071' xuất hiện 1 lần
# Từ 'lapdanc' xuất hiện 1 lần
# Từ 'bedroom' xuất hiện 1 lần
# Từ 'g2' xuất hiện 1 lần
# Từ '1da' xuất hiện 1 lần
# Từ '150ppmsg' xuất hiện 1 lần
# Từ '448712404000' xuất hiện 1 lần
# Từ '08712404000' xuất hiện 1 lần
# Từ 'deck' xuất hiện 1 lần
# Từ '08714712388' xuất hiện 1 lần
# Từ '08714712394' xuất hiện 1 lần
# Từ 'alertfrom' xuất hiện 1 lần
# Từ 'jeri' xuất hiện 1 lần
# Từ 'stewarts' xuất hiện 1 lần
# Từ '2kbsubject' xuất hiện 1 lần
# Từ 'prescripiton' xuất hiện 1 lần
# Từ 'drvgsto' xuất hiện 1 lần
# Từ '123' xuất hiện 1 lần
# Từ 'realiz' xuất hiện 1 lần
# Từ 'thousand' xuất hiện 1 lần
# Từ 'run' xuất hiện 1 lần
# Từ 'tattoo' xuất hiện 1 lần
# Từ 'romant' xuất hiện 1 lần
# Từ '08704439680t' xuất hiện 1 lần
# Từ 'unclaim' xuất hiện 1 lần
# Từ '09066368327' xuất hiện 1 lần
# Từ 'claimcod' xuất hiện 1 lần
# Từ 'm39m51' xuất hiện 1 lần
# Từ 'thought' xuất hiện 1 lần
# Từ 'perfect' xuất hiện 1 lần
# Từ '087018728737' xuất hiện 1 lần
# Từ 'toppoli' xuất hiện 1 lần
# Từ 'tune' xuất hiện 1 lần
# Từ '81618' xuất hiện 1 lần
# Từ 'pole' xuất hiện 1 lần
# Từ '14thmarch' xuất hiện 1 lần
# Từ 'availa' xuất hiện 1 lần
# Từ '8077' xuất hiện 1 lần
# Từ 'rg21' xuất hiện 1 lần
# Từ '4jx' xuất hiện 1 lần
# Từ 'outbid' xuất hiện 1 lần
# Từ 'simonwatson5120' xuất hiện 1 lần
# Từ 'shinco' xuất hiện 1 lần
# Từ 'plyr' xuất hiện 1 lần
# Từ 'notif' xuất hiện 1 lần
# Từ 'smsservic' xuất hiện 1 lần
# Từ 'yourinclus' xuất hiện 1 lần
# Từ '07821230901' xuất hiện 1 lần
# Từ 'fall' xuất hiện 1 lần
# Từ '83110' xuất hiện 1 lần
# Từ 'mysteri' xuất hiện 1 lần
# Từ '09061104283' xuất hiện 1 lần
# Từ 'approx' xuất hiện 1 lần
# Từ '07808' xuất hiện 1 lần
# Từ 'xxxxxx' xuất hiện 1 lần
# Từ '08719899217' xuất hiện 1 lần
# Từ 'posh' xuất hiện 1 lần
# Từ 'bird' xuất hiện 1 lần
# Từ 'chap' xuất hiện 1 lần
# Từ 'trial' xuất hiện 1 lần
# Từ 'prod' xuất hiện 1 lần
# Từ 'champney' xuất hiện 1 lần
# Từ 'put' xuất hiện 1 lần
# Từ 'dob' xuất hiện 1 lần
# Từ 'ta' xuất hiện 1 lần
# Từ '0721072' xuất hiện 1 lần
# Từ 'drop' xuất hiện 1 lần
# Từ '5k' xuất hiện 1 lần
# Từ 'travel' xuất hiện 1 lần
# Từ 'cr01327bt' xuất hiện 1 lần
# Từ 'fixedlin' xuất hiện 1 lần
# Từ 'mid' xuất hiện 1 lần
# Từ 'alreadi' xuất hiện 1 lần
# Từ 'paid' xuất hiện 1 lần
# Từ 'mymobi' xuất hiện 1 lần
# Từ 'lastest' xuất hiện 1 lần
# Từ 'stereophon' xuất hiện 1 lần
# Từ 'marley' xuất hiện 1 lần
# Từ 'dizze' xuất hiện 1 lần
# Từ 'racal' xuất hiện 1 lần
# Từ 'libertin' xuất hiện 1 lần
# Từ 'stroke' xuất hiện 1 lần
# Từ 'nookii' xuất hiện 1 lần
# Từ 'bookmark' xuất hiện 1 lần
# Từ 'januari' xuất hiện 1 lần
# Từ 'box403' xuất hiện 1 lần
# Từ 'w1t1ji' xuất hiện 1 lần
# Từ 'matthew' xuất hiện 1 lần
# Từ '09063440451' xuất hiện 1 lần
# Từ 'ppm150' xuất hiện 1 lần
# Từ 'box334' xuất hiện 1 lần
# Từ '09061749602' xuất hiện 1 lần
# Từ '528' xuất hiện 1 lần
# Từ 'hp20' xuất hiện 1 lần
# Từ '1yf' xuất hiện 1 lần
# Từ 'touch' xuất hiện 1 lần
# Từ 'folk' xuất hiện 1 lần
# Từ 'stori' xuất hiện 1 lần
# Từ '09050001808' xuất hiện 1 lần
# Từ 'm95' xuất hiện 1 lần
# Từ 'panason' xuất hiện 1 lần
# Từ 'bluetoothhdset' xuất hiện 1 lần
# Từ 'doublemin' xuất hiện 1 lần
# Từ 'doubletxt' xuất hiện 1 lần
# Từ '09065394514' xuất hiện 1 lần
# Từ '09058097218' xuất hiện 1 lần
# Từ 'bloke' xuất hiện 1 lần
# Từ 'zoe' xuất hiện 1 lần
# Từ 'kickoff' xuất hiện 1 lần
# Từ 'eastend' xuất hiện 1 lần
# Từ 'dot' xuất hiện 1 lần
# Từ 'compar' xuất hiện 1 lần
# Từ 'violet' xuất hiện 1 lần
# Từ 'tulip' xuất hiện 1 lần
# Từ 'lili' xuất hiện 1 lần
# Từ 'e' xuất hiện 1 lần
# Từ 'replys150' xuất hiện 1 lần
# Từ '09058091854' xuất hiện 1 lần
# Từ 'box385' xuất hiện 1 lần
# Từ 'm6' xuất hiện 1 lần
# Từ '6wu' xuất hiện 1 lần
# Từ '09061221061' xuất hiện 1 lần
# Từ '28day' xuất hiện 1 lần
# Từ 'box177' xuất hiện 1 lần
# Từ 'm221bp' xuất hiện 1 lần
# Từ '2yr' xuất hiện 1 lần
# Từ 'warranti' xuất hiện 1 lần
# Từ '3030' xuất hiện 1 lần
# Từ 'elvi' xuất hiện 1 lần
# Từ 'presley' xuất hiện 1 lần
# Từ 'birthday' xuất hiện 1 lần
# Từ '449050000301' xuất hiện 1 lần
# Từ '09050000301' xuất hiện 1 lần
# Từ 'speed' xuất hiện 1 lần
# Từ '80155' xuất hiện 1 lần
# Từ 'em' xuất hiện 1 lần
# Từ 'swap' xuất hiện 1 lần
# Từ 'chatter' xuất hiện 1 lần
# Từ 'chat80155' xuất hiện 1 lần
# Từ 'rcd' xuất hiện 1 lần
# Từ 'survey' xuất hiện 1 lần
# Từ 'howev' xuất hiện 1 lần
# Từ '80160' xuất hiện 1 lần
# Từ 'hmv1' xuất hiện 1 lần
# Từ '08707808226' xuất hiện 1 lần
# Từ 'notifi' xuất hiện 1 lần
# Từ 'market' xuất hiện 1 lần
# Từ '84122' xuất hiện 1 lần
# Từ '08450542832' xuất hiện 1 lần
# Từ 'sexual' xuất hiện 1 lần
# Từ 'cute' xuất hiện 1 lần
# Từ '69911' xuất hiện 1 lần
# Từ 'wrc' xuất hiện 1 lần
# Từ 'oz' xuất hiện 1 lần
# Từ 'lucozad' xuất hiện 1 lần
# Từ 'le' xuất hiện 1 lần
# Từ '61200' xuất hiện 1 lần
# Từ 'pack' xuất hiện 1 lần
# Từ 'itcould' xuất hiện 1 lần
# Từ '087016248' xuất hiện 1 lần
# Từ '08719181503' xuất hiện 1 lần
# Từ 'door' xuất hiện 1 lần
# Từ 'exp' xuất hiện 1 lần
# Từ '30apr' xuất hiện 1 lần
# Từ '08719181513' xuất hiện 1 lần
# Từ 'nok' xuất hiện 1 lần
# Từ 'accommod' xuất hiện 1 lần
# Từ 'variou' xuất hiện 1 lần
# Từ 'global' xuất hiện 1 lần
# Từ '08712402779' xuất hiện 1 lần
# Từ '08718730555' xuất hiện 1 lần
# Từ '09096102316' xuất hiện 1 lần
# Từ '2moro' xuất hiện 1 lần
# Từ 'jane' xuất hiện 1 lần
# Từ 'videosound' xuất hiện 1 lần
# Từ 'gold' xuất hiện 1 lần
# Từ '09701213186' xuất hiện 1 lần
# Từ 'sang' xuất hiện 1 lần
# Từ '80' xuất hiện 1 lần
# Từ 'free2day' xuất hiện 1 lần
# Từ 'st' xuất hiện 1 lần
# Từ 'georg' xuất hiện 1 lần
# Từ '89080' xuất hiện 1 lần
# Từ '0870241182716' xuất hiện 1 lần
# Từ 'k' xuất hiện 1 lần
# Từ 'nick' xuất hiện 1 lần
# Từ 'tom' xuất hiện 1 lần
# Từ 'pete' xuất hiện 1 lần
# Từ 'dick' xuất hiện 1 lần
# Từ 'fact' xuất hiện 1 lần
# Từ 'type' xuất hiện 1 lần
# Từ 'win150ppmx3age16' xuất hiện 1 lần
# Từ 'dartboard' xuất hiện 1 lần
# Từ 'trebl' xuất hiện 1 lần
# Từ 'optin' xuất hiện 1 lần
# Từ 'what' xuất hiện 1 lần
# Từ 'bbc' xuất hiện 1 lần
# Từ 'help08714742804' xuất hiện 1 lần
# Từ 'havin' xuất hiện 1 lần
# Từ 'borin' xuất hiện 1 lần
# Từ '09099725823' xuất hiện 1 lần
# Từ 'bought' xuất hiện 1 lần
# Từ '07801543489' xuất hiện 1 lần
# Từ 'meetin' xuất hiện 1 lần
# Từ 'cumin' xuất hiện 1 lần
# Từ '09099726395' xuất hiện 1 lần
# Từ '2channel' xuất hiện 1 lần
# Từ 'leadership' xuất hiện 1 lần
# Từ 'skill' xuất hiện 1 lần
# Từ 'strong' xuất hiện 1 lần
# Từ 'psychic' xuất hiện 1 lần
# Từ 'vote' xuất hiện 1 lần
# Từ 'along' xuất hiện 1 lần
# Từ 'karaok' xuất hiện 1 lần
# Từ 'instal' xuất hiện 1 lần
# Từ 'brows' xuất hiện 1 lần
# Từ 'artist' xuất hiện 1 lần
# Từ '08719899230' xuất hiện 1 lần
# Từ 'olymp' xuất hiện 1 lần
# Từ 'pro' xuất hiện 1 lần
# Từ '08701237397' xuất hiện 1 lần
# Từ 'redeem' xuất hiện 1 lần
# Từ '09058094599' xuất hiện 1 lần
# Từ 'bx' xuất hiện 1 lần
# Từ '526' xuất hiện 1 lần
# Từ '0a' xuất hiện 1 lần
# Từ 'allow' xuất hiện 1 lần
# Từ 'feelin' xuất hiện 1 lần
# Từ 'kinda' xuất hiện 1 lần
# Từ 'lnli' xuất hiện 1 lần
# Từ 'jst' xuất hiện 1 lần
# Từ 'rgent' xuất hiện 1 lần
# Từ 'lookin' xuất hiện 1 lần
# Từ 'daytim' xuất hiện 1 lần
# Từ 'busti' xuất hiện 1 lần
# Từ 'woman' xuất hiện 1 lần
# Từ 'sort' xuất hiện 1 lần
# Từ '09099726429' xuất hiện 1 lần
# Từ 'janinexx' xuất hiện 1 lần
# Từ '09050001295' xuất hiện 1 lần
# Từ 'a21' xuất hiện 1 lần
# Từ 'monthli' xuất hiện 1 lần
# Từ '0089' xuất hiện 1 lần
# Từ 'four' xuất hiện 1 lần
# Từ '09063442151' xuất hiện 1 lần
# Từ 'suffici' xuất hiện 1 lần
# Từ '09094646899' xuất hiện 1 lần
# Từ 'vu' xuất hiện 1 lần
# Từ 'bcm1896wc1n3xx' xuất hiện 1 lần
# Từ 'trackmarqu' xuất hiện 1 lần
# Từ 'vipclub4u' xuất hiện 1 lần
# Từ 'mandi' xuất hiện 1 lần
# Từ 'sullivan' xuất hiện 1 lần
# Từ 'hotmix' xuất hiện 1 lần
# Từ 'fm' xuất hiện 1 lần
# Từ 'easter' xuất hiện 1 lần
# Từ 'telephon' xuất hiện 1 lần
# Từ '09041940223' xuất hiện 1 lần
# Từ 'transfer' xuất hiện 1 lần
# Từ 'els' xuất hiện 1 lần
# Từ 'callfreefon' xuất hiện 1 lần
# Từ '08081560665' xuất hiện 1 lần
# Từ 'cruis' xuất hiện 1 lần
# Từ '07786200117' xuất hiện 1 lần
# Từ 'conact' xuất hiện 1 lần
# Từ 'pobox12n146tf15' xuất hiện 1 lần
# Từ '07734396839' xuất hiện 1 lần
# Từ 'ibh' xuất hiện 1 lần
# Từ 'nokia6600' xuất hiện 1 lần
# Từ 'space' xuất hiện 1 lần
# Từ 'invad' xuất hiện 1 lần
# Từ 'orig' xuất hiện 1 lần
# Từ 'consol' xuất hiện 1 lần
# Từ 'brother' xuất hiện 1 lần
# Từ 'cro1327' xuất hiện 1 lần
# Từ 'foley' xuất hiện 1 lần
# Từ 'eye' xuất hiện 1 lần
# Từ '1225' xuất hiện 1 lần
# Từ 'hottest' xuất hiện 1 lần
# Từ 'hack' xuất hiện 1 lần
# Từ 'backdoor' xuất hiện 1 lần
# Từ 'room' xuất hiện 1 lần
# Từ 'fraction' xuất hiện 1 lần
# Từ 'neo69' xuất hiện 1 lần
# Từ '09050280520' xuất hiện 1 lần
# Từ 'dp' xuất hiện 1 lần
# Từ 'bcm' xuất hiện 1 lần
# Từ '8027' xuất hiện 1 lần
# Từ '08718726970' xuất hiện 1 lần
# Từ 'nearli' xuất hiện 1 lần
# Từ 'ban' xuất hiện 1 lần
# Từ '09058094594' xuất hiện 1 lần
# Từ '09061743811' xuất hiện 1 lần
# Từ '09090900040' xuất hiện 1 lần
# Từ 'extrem' xuất hiện 1 lần
# Từ 'dirti' xuất hiện 1 lần
# Từ 'offic' xuất hiện 1 lần
# Từ 'privaci' xuất hiện 1 lần
# Từ 'sic' xuất hiện 1 lần
# Từ '60p' xuất hiện 1 lần
# Từ 'wild' xuất hiện 1 lần
# Từ 'ill' xuất hiện 1 lần
# Từ 'hurri' xuất hiện 1 lần
# Từ 'stop2stop' xuất hiện 1 lần
# Từ '08715500022' xuất hiện 1 lần
# Từ 'rpl' xuất hiện 1 lần
# Từ 'cnl' xuất hiện 1 lần
# Từ '08702490080' xuất hiện 1 lần
# Từ 'vpod' xuất hiện 1 lần
# Từ '09090204448' xuất hiện 1 lần
# Từ 'minapn' xuất hiện 1 lần
# Từ 'ls278bb' xuất hiện 1 lần
# Từ '09065394973' xuất hiện 1 lần
# Từ '31' xuất hiện 1 lần
# Từ '2005' xuất hiện 1 lần
# Từ '2006' xuất hiện 1 lần
# Từ 'fifa' xuất hiện 1 lần
# Từ 'held' xuất hiện 1 lần
# Từ '09061743810' xuất hiện 1 lần
# Từ 'open' xuất hiện 1 lần
# Từ '08006344447' xuất hiện 1 lần
# Từ '09094100151' xuất hiện 1 lần
# Từ 'cast' xuất hiện 1 lần
# Từ 'box61' xuất hiện 1 lần
# Từ 'm60' xuất hiện 1 lần
# Từ '1er' xuất hiện 1 lần
# Từ '09066362220' xuất hiện 1 lần
# Từ 'wither' xuất hiện 1 lần
# Từ 'web2mobil' xuất hiện 1 lần
# Từ 'box139' xuất hiện 1 lần
# Từ 'la32wu' xuất hiện 1 lần
# Từ 'txtx' xuất hiện 1 lần
# Từ '85233' xuất hiện 1 lần
# Từ '84199' xuất hiện 1 lần
# Từ 'box420' xuất hiện 1 lần
# Từ 'stamp' xuất hiện 1 lần
# Từ 'self' xuất hiện 1 lần
# Từ 'envelop' xuất hiện 1 lần
# Từ 'drink' xuất hiện 1 lần
# Từ '113' xuất hiện 1 lần
# Từ 'bray' xuất hiện 1 lần
# Từ 'wicklow' xuất hiện 1 lần
# Từ 'eir' xuất hiện 1 lần
# Từ 'skillgam' xuất hiện 1 lần
# Từ '1winaweek' xuất hiện 1 lần
# Từ '150ppermesssubscript' xuất hiện 1 lần
# Từ 'b4u' xuất hiện 1 lần
# Từ 'marsm' xuất hiện 1 lần
# Từ '08717168528' xuất hiện 1 lần
# Từ 'buffi' xuất hiện 1 lần
# Từ 'qlynnbv' xuất hiện 1 lần
# Từ 'help08700621170150p' xuất hiện 1 lần
# Từ 'bundl' xuất hiện 1 lần
# Từ 'deal' xuất hiện 1 lần
# Từ 'avbl' xuất hiện 1 lần
# Từ 'mf' xuất hiện 1 lần
# Từ '08714712379' xuất hiện 1 lần
# Từ 'k718' xuất hiện 1 lần
# Từ '09065069120' xuất hiện 1 lần
# Từ 'ya' xuất hiện 1 lần
# Từ '4goten' xuất hiện 1 lần
# Từ 'bout' xuất hiện 1 lần
# Từ 'scammer' xuất hiện 1 lần
# Từ 'though' xuất hiện 1 lần
# Từ 'regular' xuất hiện 1 lần
# Từ 'prem' xuất hiện 1 lần
# Từ 'no' xuất hiện 1 lần
# Từ 'bewar' xuất hiện 1 lần
# Từ '2morro' xuất hiện 1 lần
# Từ 'passion' xuất hiện 1 lần
# Từ '09099726481' xuất hiện 1 lần
# Từ 'dena' xuất hiện 1 lần
# Từ 'r836' xuất hiện 1 lần
# Từ '09065069154' xuất hiện 1 lần
# Từ 'splashmobil' xuất hiện 1 lần
# Từ 'subscrit' xuất hiện 1 lần
# Từ '01223585334' xuất hiện 1 lần
# Từ '2c' xuất hiện 1 lần
# Từ 'gettin' xuất hiện 1 lần
# Từ '2end' xuất hiện 1 lần
# Từ '3pound' xuất hiện 1 lần
# Từ '2stoptx' xuất hiện 1 lần
# Từ '08718738034' xuất hiện 1 lần
# Từ '21' xuất hiện 1 lần
# Từ 'arrow' xuất hiện 1 lần
# Từ '08718726971' xuất hiện 1 lần
# Từ 'tddnewslett' xuất hiện 1 lần
# Từ 'thedailydraw' xuất hiện 1 lần
# Từ 'helen' xuất hiện 1 lần
# Từ 'dozen' xuất hiện 1 lần
# Từ 'prizeswith' xuất hiện 1 lần
# Từ '09066368753' xuất hiện 1 lần
# Từ '97n7qp' xuất hiện 1 lần
# Từ 'restrict' xuất hiện 1 lần
# Từ 'buddi' xuất hiện 1 lần
# Từ 'sir' xuất hiện 1 lần
# Từ '08712402902' xuất hiện 1 lần
# Từ 'footbal' xuất hiện 1 lần
# Từ 'gamestar' xuất hiện 1 lần
# Từ '88088' xuất hiện 1 lần
# Từ 'monoc' xuất hiện 1 lần
# Từ 'polyc' xuất hiện 1 lần
# Từ 'stream' xuất hiện 1 lần
# Từ '0871212025016' xuất hiện 1 lần
# Từ 'becausethey' xuất hiện 1 lần
# Từ 'pobox1' xuất hiện 1 lần
# Từ 'w14rg' xuất hiện 1 lần
# Từ 'nasti' xuất hiện 1 lần
# Từ 'filthyguy' xuất hiện 1 lần
# Từ 'bitch' xuất hiện 1 lần
# Từ '4msg' xuất hiện 1 lần
# Từ 'gotto' xuất hiện 1 lần
# Từ 'login' xuất hiện 1 lần
# Từ '08702840625' xuất hiện 1 lần
# Từ 'creat' xuất hiện 1 lần
# Từ 'page' xuất hiện 1 lần
# Từ 'read' xuất hiện 1 lần
# Từ 'wrote' xuất hiện 1 lần
# Từ 'opinion' xuất hiện 1 lần
# Từ 'sppok' xuất hiện 1 lần
# Từ 'complementari' xuất hiện 1 lần
# Từ 'wa14' xuất hiện 1 lần
# Từ '2px' xuất hiện 1 lần
# Từ 'sender' xuất hiện 1 lần
# Từ 'hvae' xuất hiện 1 lần
# Từ '6230' xuất hiện 1 lần
# Từ '83383' xuất hiện 1 lần
# Từ 'text82228' xuất hiện 1 lần
# Từ 'mini' xuất hiện 1 lần
# Từ 'snap' xuất hiện 1 lần
# Từ 'quizclub' xuất hiện 1 lần
# Từ 'rwm' xuất hiện 1 lần
# Từ 'gmw' xuất hiện 1 lần
# Từ 'vid' xuất hiện 1 lần
# Từ 'keyword' xuất hiện 1 lần
# Từ 'ten' xuất hiện 1 lần
# Từ 'tarot' xuất hiện 1 lần
# Từ '85555' xuất hiện 1 lần
# Từ 'horniest' xuất hiện 1 lần
# Từ 'whose' xuất hiện 1 lần
# Từ '0870737910216yr' xuất hiện 1 lần
# Từ '077xxx' xuất hiện 1 lần
# Từ '09066362206' xuất hiện 1 lần
# Từ 'w4' xuất hiện 1 lần
# Từ '5wq' xuất hiện 1 lần
# Từ 'park' xuất hiện 1 lần
# Từ 'ab' xuất hiện 1 lần
# Từ 'sara' xuất hiện 1 lần
# Từ 'fan' xuất hiện 1 lần
# Từ 'str' xuất hiện 1 lần
# Từ 'europ' xuất hiện 1 lần
# Từ '10th' xuất hiện 1 lần
# Từ 'ba128nnfwfly150ppm' xuất hiện 1 lần
# Từ '20m12aq' xuất hiện 1 lần
# Từ 'jame' xuất hiện 1 lần
# Từ 'eh74rr' xuất hiện 1 lần
# Từ 'women' xuất hiện 1 lần
# Từ 'instantli' xuất hiện 1 lần
# Từ '69969' xuất hiện 1 lần
# Từ 'bcmsfwc1n3xx' xuất hiện 1 lần
# Từ 'footi' xuất hiện 1 lần
# Từ 'stadium' xuất hiện 1 lần
# Từ 'larg' xuất hiện 1 lần
# Từ 'walk' xuất hiện 1 lần
# Từ 'child' xuất hiện 1 lần
# Từ 'afraid' xuất hiện 1 lần
# Từ 'dark' xuất hiện 1 lần
# Từ 'becom' xuất hiện 1 lần
# Từ 'teenag' xuất hiện 1 lần
# Từ 'bin' xuất hiện 1 lần
# Từ 'instant' xuất hiện 1 lần
# Từ '08715203028' xuất hiện 1 lần
# Từ '9th' xuất hiện 1 lần
# Từ 'fav' xuất hiện 1 lần
# Từ '2u' xuất hiện 1 lần
# Từ 'breathe1' xuất hiện 1 lần
# Từ 'crazyin' xuất hiện 1 lần
# Từ 'sleepingwith' xuất hiện 1 lần
# Từ 'finest' xuất hiện 1 lần
# Từ 'ymca' xuất hiện 1 lần
# Từ 'pobox365o4w45wq' xuất hiện 1 lần
# Từ 'åòit' xuất hiện 1 lần
# Từ 'late' xuất hiện 1 lần
# Từ 'christma' xuất hiện 1 lần
# Từ '505060' xuất hiện 1 lần
# Từ 'midnight' xuất hiện 1 lần
# Từ 'romcapspam' xuất hiện 1 lần
# Từ 'presenc' xuất hiện 1 lần
# Từ 'outgo' xuất hiện 1 lần
# Từ 'breath' xuất hiện 1 lần
# Từ '08712103738' xuất hiện 1 lần
# Từ '09058099801' xuất hiện 1 lần
# Từ 'b4190604' xuất hiện 1 lần
# Từ '7876150ppm' xuất hiện 1 lần
# Từ 'frog' xuất hiện 1 lần
# Từ 'mad1' xuất hiện 1 lần
# Từ 'mad2' xuất hiện 1 lần
# Từ '69855' xuất hiện 1 lần
# Từ 'stopbcm' xuất hiện 1 lần
# Từ 'sf' xuất hiện 1 lần
# Từ 'yhl' xuất hiện 1 lần
# Từ '09058094454' xuất hiện 1 lần
# Từ 'packag' xuất hiện 1 lần
# Từ '54' xuất hiện 1 lần
# Từ 'resubmit' xuất hiện 1 lần
# Từ 'expiri' xuất hiện 1 lần
# Từ '08712400200' xuất hiện 1 lần
# Từ '08718723815' xuất hiện 1 lần
# Từ '08714714011' xuất hiện 1 lần
# Từ 'anyon' xuất hiện 1 lần
# Từ 'slower' xuất hiện 1 lần
# Từ 'idiot' xuất hiện 1 lần
# Từ 'faster' xuất hiện 1 lần
# Từ 'maniac' xuất hiện 1 lần
# Từ 'profession' xuất hiện 1 lần
# Từ 'tiger' xuất hiện 1 lần
# Từ 'wood' xuất hiện 1 lần
# Từ 'pt2' xuất hiện 1 lần
# Từ '87575' xuất hiện 1 lần
# Từ '400min' xuất hiện 1 lần
# Từ '69200' xuất hiện 1 lần
# Từ 'hr' xuất hiện 1 lần
# Từ 'chrgd' xuất hiện 1 lần
# Từ '2exit' xuất hiện 1 lần
# Từ 'ton' xuất hiện 1 lần
# Từ 'hunk' xuất hiện 1 lần
# Từ 'abroad' xuất hiện 1 lần
# Từ 'lone' xuất hiện 1 lần
# Từ 'xxsp' xuất hiện 1 lần
# Từ 'stopcost' xuất hiện 1 lần
# Từ '08712400603' xuất hiện 1 lần
# Từ 'agent' xuất hiện 1 lần
# Từ 'load' xuất hiện 1 lần
# Từ 'goodi' xuất hiện 1 lần
# Từ 'mat' xuất hiện 1 lần
# Từ 'lord' xuất hiện 1 lần
# Từ 'return' xuất hiện 1 lần
# Từ 'june' xuất hiện 1 lần
# Từ 'soundtrack' xuất hiện 1 lần
# Từ 'stdtxtrate' xuất hiện 1 lần
# Từ '28th' xuất hiện 1 lần
# Từ 'feb' xuất hiện 1 lần
# Từ 'str8' xuất hiện 1 lần
# Từ 'classic' xuất hiện 1 lần
# Từ 'clip' xuất hiện 1 lần
# Từ '35p' xuất hiện 1 lần
# Từ 'better' xuất hiện 1 lần
# Từ 'mmsto' xuất hiện 1 lần
# Từ '32323' xuất hiện 1 lần
# Từ 'vat' xuất hiện 1 lần
# Từ '09053750005' xuất hiện 1 lần
# Từ '08718725756' xuất hiện 1 lần
# Từ '140ppm' xuất hiện 1 lần
# Từ '08712101358' xuất hiện 1 lần
# Từ '09066358361' xuất hiện 1 lần
# Từ 'y87' xuất hiện 1 lần
# Từ 'x29' xuất hiện 1 lần
# Từ '09065989180' xuất hiện 1 lần
# Từ '08718726978' xuất hiện 1 lần
# Từ '44' xuất hiện 1 lần
# Từ '7732584351' xuất hiện 1 lần
# Từ '09058097189' xuất hiện 1 lần
# Từ '5226' xuất hiện 1 lần
# Từ 'hava' xuất hiện 1 lần
# Từ '1131' xuất hiện 1 lần
# Từ 'rct' xuất hiện 1 lần
# Từ 'thnq' xuất hiện 1 lần
# Từ 'adrian' xuất hiện 1 lần
# Từ 'rgd' xuất hiện 1 lần
# Từ 'vatian' xuất hiện 1 lần
# Từ '07090201529' xuất hiện 1 lần
# Từ '09066364349' xuất hiện 1 lần
# Từ 'lose' xuất hiện 1 lần
# Từ 'mistak' xuất hiện 1 lần
# Từ 'shortcod' xuất hiện 1 lần
# Từ '08081263000' xuất hiện 1 lần
# Từ '08712402972' xuất hiện 1 lần
# Từ '09058095201' xuất hiện 1 lần
# Từ 'never' xuất hiện 1 lần
# Từ 'much' xuất hiện 1 lần
# Từ 'came' xuất hiện 1 lần
# Từ 'made' xuất hiện 1 lần
# Từ '600' xuất hiện 1 lần
# Từ '400' xuất hiện 1 lần
# Từ 'deltomorrow' xuất hiện 1 lần
# Từ '09066368470' xuất hiện 1 lần
# Từ 'begin' xuất hiện 1 lần
# Từ '24m' xuất hiện 1 lần
# Từ 'smartcal' xuất hiện 1 lần
# Từ '08448714184' xuất hiện 1 lần
# Từ 'landlineonli' xuất hiện 1 lần
# Từ 'orno' xuất hiện 1 lần
# Từ 'fink' xuất hiện 1 lần
# Từ 'met' xuất hiện 1 lần
# Từ '09099726553' xuất hiện 1 lần
# Từ 'promis' xuất hiện 1 lần
# Từ 'carli' xuất hiện 1 lần
# Từ 'lkpobox177hp51fl' xuất hiện 1 lần
# Từ 'lingeri' xuất hiện 1 lần
# Từ 'superb' xuất hiện 1 lần
# Từ 'weddingfriend' xuất hiện 1 lần
# Từ 'knicker' xuất hiện 1 lần
# Từ 'beg' xuất hiện 1 lần
# Từ '01223585236' xuất hiện 1 lần
# Từ 'bloomberg' xuất hiện 1 lần
# Từ 'center' xuất hiện 1 lần
# Từ 'phone750' xuất hiện 1 lần
# Từ 'wan2' xuất hiện 1 lần
# Từ 'westlif' xuất hiện 1 lần
# Từ 'unbreak' xuất hiện 1 lần
# Từ 'untam' xuất hiện 1 lần
# Từ 'unkempt' xuất hiện 1 lần
# Từ 'dorothi' xuất hiện 1 lần
# Từ '09071517866' xuất hiện 1 lần
# Từ '150ppmpobox10183bhamb64x' xuất hiện 1 lần
# Từ '10am' xuất hiện 1 lần
# Từ '8pm' xuất hiện 1 lần
# Từ 'sell' xuất hiện 1 lần
# Từ 'fast' xuất hiện 1 lần
# Từ 'rock' xuất hiện 1 lần
# Từ 'chik' xuất hiện 1 lần
# Từ 'filth' xuất hiện 1 lần
# Từ 'saristar' xuất hiện 1 lần
# Từ 'e14' xuất hiện 1 lần
# Từ '9yt' xuất hiện 1 lần
# Từ '08701752560' xuất hiện 1 lần
# Từ '450p' xuất hiện 1 lần
# Từ 'stop2' xuất hiện 1 lần
# Từ '9061100010' xuất hiện 1 lần
# Từ '1st4term' xuất hiện 1 lần
# Từ 'mobcudb' xuất hiện 1 lần
# Từ '09050000460' xuất hiện 1 lần
# Từ 'j89' xuất hiện 1 lần
# Từ 'box245c2150pm' xuất hiện 1 lần
# Từ 'banneduk' xuất hiện 1 lần
# Từ 'round' xuất hiện 1 lần
# Từ 'highest' xuất hiện 1 lần
# Từ 'maximum' xuất hiện 1 lần
# Từ 'believ' xuất hiện 1 lần
# Từ 'incred' xuất hiện 1 lần
# Từ 'g' xuất hiện 1 lần
# Từ 'learn' xuất hiện 1 lần
# Từ 'blow' xuất hiện 1 lần
# Từ 'o2fwd' xuất hiện 1 lần
# Từ 'will' xuất hiện 1 lần
# Từ 'strt' xuất hiện 1 lần
# Từ 'ltdhelpdesk' xuất hiện 1 lần
# Từ '02085076972' xuất hiện 1 lần
# Từ '09066660100' xuất hiện 1 lần
# Từ '2309' xuất hiện 1 lần
# Từ '07090298926' xuất hiện 1 lần
# Từ 'html' xuất hiện 1 lần
# Từ 'mfl' xuất hiện 1 lần
# Từ 'wamma' xuất hiện 1 lần
# Từ 'doggin' xuất hiện 1 lần
# Từ 'promot' xuất hiện 1 lần
# Từ '8714714' xuất hiện 1 lần
# Từ 'x49' xuất hiện 1 lần
# Từ 'txtstar' xuất hiện 1 lần
# Từ '2night' xuất hiện 1 lần
# Từ 'uve' xuất hiện 1 lần
# Từ 'wildest' xuất hiện 1 lần
# Từ '146tf150p' xuất hiện 1 lần
# Từ 'airport' xuất hiện 1 lần
# Từ 'loung' xuất hiện 1 lần
# Từ '09058095107' xuất hiện 1 lần
# Từ 's3xi' xuất hiện 1 lần
# Từ 'mila' xuất hiện 1 lần
# Từ 'age23' xuất hiện 1 lần
# Từ 'blond' xuất hiện 1 lần
# Từ 'mtalk' xuất hiện 1 lần
# Từ '5free' xuất hiện 1 lần
# Từ 'increment' xuất hiện 1 lần
# Từ 'help08718728876' xuất hiện 1 lần
# Từ '08717895698' xuất hiện 1 lần
# Từ 'mobstorequiz10ppm' xuất hiện 1 lần
# Từ 'funk' xuất hiện 1 lần
# Từ 'tones2u' xuất hiện 1 lần
# Từ 'twink' xuất hiện 1 lần
# Từ 'scalli' xuất hiện 1 lần
# Từ 'skin' xuất hiện 1 lần
# Từ 'jock' xuất hiện 1 lần
# Từ '08712466669' xuất hiện 1 lần
# Từ 'k61' xuất hiện 1 lần
# Từ '12hour' xuất hiện 1 lần
# Từ '74355' xuất hiện 1 lần
# Từ 'row' xuất hiện 1 lần
# Từ 'concert' xuất hiện 1 lần
# Từ 'novemb' xuất hiện 1 lần
# Từ '09061104276' xuất hiện 1 lần
# Từ '62220cncl' xuất hiện 1 lần
# Từ 'stopc' xuất hiện 1 lần
# Từ 'åòharri' xuất hiện 1 lần
# Từ '37819' xuất hiện 1 lần
# Từ 'oh' xuất hiện 1 lần
# Từ 'god' xuất hiện 1 lần
# Từ 'found' xuất hiện 1 lần
# Từ 'glad' xuất hiện 1 lần
# Từ 'xafter' xuất hiện 1 lần
# Từ 'cst' xuất hiện 1 lần
# Từ 'pictur' xuất hiện 1 lần
# Từ '08719181259' xuất hiện 1 lần
# Từ 'xxxxx' xuất hiện 1 lần
# Từ 'real1' xuất hiện 1 lần
# Từ 'pushbutton' xuất hiện 1 lần
# Từ 'dontcha' xuất hiện 1 lần
# Từ 'babygoodby' xuất hiện 1 lần
# Từ 'golddigg' xuất hiện 1 lần
# Từ 'webeburnin' xuất hiện 1 lần
# Từ 'gnarl' xuất hiện 1 lần
# Từ 'barkley' xuất hiện 1 lần
# Từ 'secur' xuất hiện 1 lần
# Từ 'unsecur' xuất hiện 1 lần
# Từ 'ca' xuất hiện 1 lần
# Từ '195' xuất hiện 1 lần
# Từ '6669' xuất hiện 1 lần
# Từ 'ringtonek' xuất hiện 1 lần
# Từ '84484' xuất hiện 1 lần
# Từ 'housew' xuất hiện 1 lần
# Từ '087104711148' xuất hiện 1 lần
# Từ 'tripl' xuất hiện 1 lần
# Từ 'echo' xuất hiện 1 lần
# Từ 'dial' xuất hiện 1 lần
# Từ 'bx526' xuất hiện 1 lần
# Từ '09066364311' xuất hiện 1 lần
# Từ '09065989182' xuất hiện 1 lần
# Từ '08709501522' xuất hiện 1 lần
# Từ '139' xuất hiện 1 lần
# Từ 'la3' xuất hiện 1 lần
# Từ '2wu' xuất hiện 1 lần
# Từ '09064017305' xuất hiện 1 lần
# Từ 'pobox75ldns7' xuất hiện 1 lần
# Từ 'chase' xuất hiện 1 lần
# Từ 'definit' xuất hiện 1 lần
# Từ 'ignor' xuất hiện 1 lần
# Từ 'kath' xuất hiện 1 lần
# Từ 'manchest' xuất hiện 1 lần
# Từ 'bad' xuất hiện 1 lần
# Từ '08717111821' xuất hiện 1 lần
# Từ 'season' xuất hiện 1 lần
# Từ '2wk' xuất hiện 1 lần
# Từ 'villa' xuất hiện 1 lần
# Từ 'hero' xuất hiện 1 lần
# Từ 'tip' xuất hiện 1 lần
# Từ '07973788240' xuất hiện 1 lần
# Từ '08715203649' xuất hiện 1 lần
# Từ 'gsoh' xuất hiện 1 lần
# Từ 'spam' xuất hiện 1 lần
# Từ 'gigolo' xuất hiện 1 lần
# Từ 'oncal' xuất hiện 1 lần
# Từ 'mjzgroup' xuất hiện 1 lần
# Từ '08707500020' xuất hiện 1 lần
# Từ 'ukp' xuất hiện 1 lần
# Từ '09061790125' xuất hiện 1 lần
# Từ 'spjanuari' xuất hiện 1 lần
# Từ 'simpson' xuất hiện 1 lần
# Từ 'releas' xuất hiện 1 lần
# Từ 'band' xuất hiện 1 lần
# Từ 'die' xuất hiện 1 lần
# Từ 'amanda' xuất hiện 1 lần
# Từ 'regard' xuất hiện 1 lần
# Từ 'tel' xuất hiện 1 lần
# Từ '3680' xuất hiện 1 lần
# Từ 'subject' xuất hiện 1 lần
# Từ '47' xuất hiện 1 lần
# Từ 'po19' xuất hiện 1 lần
# Từ '2ez' xuất hiện 1 lần
# Từ 'cmon' xuất hiện 1 lần
# Từ 'turn' xuất hiện 1 lần
# Từ 'sticki' xuất hiện 1 lần
# Từ '0796xxxxxx' xuất hiện 1 lần
# Từ 'prizeawait' xuất hiện 1 lần
# Từ 'left' xuất hiện 1 lần
# Từ '07008009200' xuất hiện 1 lần
# Từ '3750' xuất hiện 1 lần
# Từ '3lion' xuất hiện 1 lần
# Từ '69669' xuất hiện 1 lần
# Từ 'normal' xuất hiện 1 lần
# Từ 'gpr' xuất hiện 1 lần
# Từ 'accordingli' xuất hiện 1 lần
# Từ 'repeat' xuất hiện 1 lần
# Từ 'block' xuất hiện 1 lần
# Từ 'breaker' xuất hiện 1 lần
# Từ 'delux' xuất hiện 1 lần
# Từ 'format' xuất hiện 1 lần
# Từ 'featur' xuất hiện 1 lần
# Từ 'graphic' xuất hiện 1 lần
# Từ 'bbdelux' xuất hiện 1 lần
# Từ 'challeng' xuất hiện 1 lần
# Từ 'natalja' xuất hiện 1 lần
# Từ '02' xuất hiện 1 lần
# Từ 'kit' xuất hiện 1 lần
# Từ 'strip' xuất hiện 1 lần
# Từ '1013' xuất hiện 1 lần
# Từ 'ig11' xuất hiện 1 lần
# Từ 'oja' xuất hiện 1 lần
# Từ '08712402578' xuất hiện 1 lần
# Từ 'anonym' xuất hiện 1 lần
# Từ 'mask' xuất hiện 1 lần
# Từ 'potenti' xuất hiện 1 lần
# Từ 'abus' xuất hiện 1 lần
# Từ '09061744553' xuất hiện 1 lần
# Từ 'polyh' xuất hiện 1 lần
# Từ '0789xxxxxxx' xuất hiện 1 lần
# Từ 'shi' xuất hiện 1 lần
# Từ '09058091870' xuất hiện 1 lần
# Từ 'landmark' xuất hiện 1 lần
# Từ 'bob' xuất hiện 1 lần
# Từ 'barri' xuất hiện 1 lần
# Từ 'ben' xuất hiện 1 lần
# Từ 'tonex' xuất hiện 1 lần
# Từ '8000930705' xuất hiện 1 lần
# Từ 'recpt' xuất hiện 1 lần
# Từ 'process' xuất hiện 1 lần
# Từ 'headset' xuất hiện 1 lần
# Từ 'floppi' xuất hiện 1 lần
# Từ 'snappi' xuất hiện 1 lần
# Từ 'happi' xuất hiện 1 lần
# Từ 'mg' xuất hiện 1 lần
# Từ '89123' xuất hiện 1 lần
# Từ 'proze' xuất hiện 1 lần
# Từ 'norcorp' xuất hiện 1 lần
# Từ 'item' xuất hiện 1 lần
# Từ '7cfca1a' xuất hiện 1 lần
# Từ 'wine' xuất hiện 1 lần
# Từ '946' xuất hiện 1 lần
# Từ 'wot' xuất hiện 1 lần
# Từ 'cock' xuất hiện 1 lần
# Từ 'man' xuất hiện 1 lần
# Từ 'wife' xuất hiện 1 lần
# Từ '89938' xuất hiện 1 lần
# Từ 'string' xuất hiện 1 lần
# Từ 'rec' xuất hiện 1 lần
# Từ 'otbox' xuất hiện 1 lần
# Từ '731' xuất hiện 1 lần
# Từ 'la1' xuất hiện 1 lần
# Từ '7w' xuất hiện 1 lần
# Từ 'sexiest' xuất hiện 1 lần
# Từ 'dirtiest' xuất hiện 1 lần
# Từ 'w8in' xuất hiện 1 lần
# Từ '4utxt' xuất hiện 1 lần
# Từ 'laugh' xuất hiện 1 lần
# Từ 'logon' xuất hiện 1 lần
# Từ '8883' xuất hiện 1 lần
# Từ 'cm' xuất hiện 1 lần
# Từ '4217' xuất hiện 1 lần
# Từ 'w1a' xuất hiện 1 lần
# Từ '6zf' xuất hiện 1 lần
# Từ '09071512432' xuất hiện 1 lần
# Từ '300603t' xuất hiện 1 lần
# Từ 'cannam' xuất hiện 1 lần
# Từ 'capit' xuất hiện 1 lần
# Từ 'australia' xuất hiện 1 lần
# Từ 'mquiz' xuất hiện 1 lần
# Từ '7634' xuất hiện 1 lần
# Từ '7684' xuất hiện 1 lần
# Từ 'rip' xuất hiện 1 lần
# Từ '08717509990' xuất hiện 1 lần
# Từ '08718738002' xuất hiện 1 lần
# Từ '48922' xuất hiện 1 lần
# Từ '07099833605' xuất hiện 1 lần
# Từ 'chloe' xuất hiện 1 lần
# Từ 'smash' xuất hiện 1 lần
# Từ '07808726822' xuất hiện 1 lần
# Từ 'rayman' xuất hiện 1 lần
# Từ 'golf' xuất hiện 1 lần
# Từ 'activ8' xuất hiện 1 lần
# Từ 'key' xuất hiện 1 lần
# Từ 'termsappli' xuất hiện 1 lần
# Từ 'black' xuất hiện 1 lần
# Từ 'continu' xuất hiện 1 lần
# Từ 'in2' xuất hiện 1 lần
# Từ 'presid' xuất hiện 1 lần
# Từ 'id' xuất hiện 1 lần
# Từ '09066649731from' xuất hiện 1 lần
# Từ '09061702893' xuất hiện 1 lần
# Từ '09077818151' xuất hiện 1 lần
# Từ '078498' xuất hiện 1 lần
# Từ '08719180219' xuất hiện 1 lần
# Từ 'fgkslpopw' xuất hiện 1 lần
# Từ 'fgkslpo' xuất hiện 1 lần
# Từ '08715203652' xuất hiện 1 lần
# Từ '42810' xuất hiện 1 lần
# Từ 'skip' xuất hiện 1 lần
# Từ 'customercar' xuất hiện 1 lần
# Từ 'lyricalladi' xuất hiện 1 lần
# Từ 'ou' xuất hiện 1 lần
# Từ 'sn' xuất hiện 1 lần
# Từ 'pobox202' xuất hiện 1 lần
# Từ 'nr31' xuất hiện 1 lần
# Từ '7z' xuất hiện 1 lần
# Từ '450pw' xuất hiện 1 lần
# Từ '83118' xuất hiện 1 lần
# Từ 'colin' xuất hiện 1 lần
# Từ 'farrel' xuất hiện 1 lần
# Từ 'swat' xuất hiện 1 lần
# Từ 'wkend' xuất hiện 1 lần
# Từ 'popcorn' xuất hiện 1 lần
# Từ 'kiosk' xuất hiện 1 lần
# Từ 'mre' xuất hiện 1 lần
# Từ 'simpl' xuất hiện 1 lần
# Từ 'shot' xuất hiện 1 lần
# Từ 'yard' xuất hiện 1 lần
# Từ 'bergkamp' xuất hiện 1 lần
# Từ 'margin' xuất hiện 1 lần
# Từ '78' xuất hiện 1 lần
# Từ 'sexychat' xuất hiện 1 lần
# Từ 'ami' xuất hiện 1 lần
# Từ 'coupl' xuất hiện 1 lần
# Từ 'parti' xuất hiện 1 lần
# Từ 'benefit' xuất hiện 1 lần
# Từ 'train' xuất hiện 1 lần
# Từ 'advisor' xuất hiện 1 lần
# Từ 'diall' xuất hiện 1 lần
# Từ '402' xuất hiện 1 lần
# Từ 'meal' xuất hiện 1 lần
# Từ 'dine' xuất hiện 1 lần
# Từ 'experiencehttp' xuất hiện 1 lần
# Từ '09058094507' xuất hiện 1 lần
# Từ 'unicef' xuất hiện 1 lần
# Từ 'asian' xuất hiện 1 lần
# Từ 'tsunami' xuất hiện 1 lần
# Từ 'disast' xuất hiện 1 lần
# Từ 'fund' xuất hiện 1 lần
# Từ 'goldvik' xuất hiện 1 lần
# Từ 'phoni' xuất hiện 1 lần
# Từ 'xxxx' xuất hiện 1 lần
# Từ 'freeentri' xuất hiện 1 lần
# Từ 'xt' xuất hiện 1 lần
# Từ '08714712412' xuất hiện 1 lần
# Từ '08715203685' xuất hiện 1 lần
# Từ 'deepest' xuất hiện 1 lần
# Từ 'darkest' xuất hiện 1 lần
# Từ '09094646631' xuất hiện 1 lần
# Từ 'natali' xuất hiện 1 lần
# Từ '08701213186' xuất hiện 1 lần
# Từ '83039' xuất hiện 1 lần
# Từ 'accommodationvouch' xuất hiện 1 lần
# Từ 'mustprovid' xuất hiện 1 lần
# Từ '15541' xuất hiện 1 lần
# Từ '5p' xuất hiện 1 lần
# Từ 'tscs08714740323' xuất hiện 1 lần
# Từ '1winawk' xuất hiện 1 lần
# Từ '09066361921' xuất hiện 1 lần
# Từ 'pink' xuất hiện 1 lần
# Từ 'panther' xuất hiện 1 lần
# Từ 'sugabab' xuất hiện 1 lần
# Từ 'zebra' xuất hiện 1 lần
# Từ 'anim' xuất hiện 1 lần
# Từ 'badass' xuất hiện 1 lần
# Từ 'hoodi' xuất hiện 1 lần
# Từ 'resent' xuất hiện 1 lần
# Từ 'previou' xuất hiện 1 lần
# Từ 'fail' xuất hiện 1 lần
# Từ 'error' xuất hiện 1 lần
# Từ 'queri' xuất hiện 1 lần
# Từ 'customersqueri' xuất hiện 1 lần
# Từ '08715205273' xuất hiện 1 lần
# Từ 'vco' xuất hiện 1 lần
# Từ '078' xuất hiện 1 lần
# Từ 'garden' xuất hiện 1 lần
# Từ 'bulb' xuất hiện 1 lần
# Từ 'seed' xuất hiện 1 lần
# Từ 'scotsman' xuất hiện 1 lần
# Từ 'go2' xuất hiện 1 lần
# Từ 'ree' xuất hiện 1 lần
# Từ 'compens' xuất hiện 1 lần
# Từ '08715203656' xuất hiện 1 lần
# Từ '42049' xuất hiện 1 lần
# Từ 'someonon' xuất hiện 1 lần
# Từ '09064015307' xuất hiện 1 lần
# Từ '177' xuất hiện 1 lần
# Từ '09061790126' xuất hiện 1 lần
# Từ 'textcomp' xuất hiện 1 lần
# Từ 'subsequ' xuất hiện 1 lần
# Từ '09095350301' xuất hiện 1 lần
# Từ 'erot' xuất hiện 1 lần
# Từ 'ecstaci' xuất hiện 1 lần
# Từ 'dept' xuất hiện 1 lần
# Từ '08717507382' xuất hiện 1 lần
# Từ 'two' xuất hiện 1 lần
# Từ 'radio' xuất hiện 1 lần
# Từ 'coincid' xuất hiện 1 lần
# Từ 'lead' xuất hiện 1 lần
# Từ 'paus' xuất hiện 1 lần
# Từ 'gr8prize' xuất hiện 1 lần
# Từ '8800' xuất hiện 1 lần
# Từ 'psp' xuất hiện 1 lần
# Từ '80878' xuất hiện 1 lần
# Từ '09058094583' xuất hiện 1 lần
# Từ '32000' xuất hiện 1 lần
# Từ 'legitimat' xuất hiện 1 lần
# Từ 'efreefon' xuất hiện 1 lần
# Từ 'wat' xuất hiện 1 lần
# Từ 'polic' xuất hiện 1 lần
# Từ 'station' xuất hiện 1 lần
# Từ 'toilet' xuất hiện 1 lần
# Từ 'stolen' xuất hiện 1 lần
# Từ 'cop' xuất hiện 1 lần
# Từ 'sparkl' xuất hiện 1 lần
# Từ '45' xuất hiện 1 lần
# Từ '0121' xuất hiện 1 lần
# Từ '2025050' xuất hiện 1 lần
# Từ 'ringtoneåá' xuất hiện 1 lần
# Từ '09050000332' xuất hiện 1 lần
# Từ '09064017295' xuất hiện 1 lần
# Từ '08448350055' xuất hiện 1 lần
# Từ 'marvel' xuất hiện 1 lần
# Từ 'ultim' xuất hiện 1 lần
# Từ 'spider' xuất hiện 1 lần
# Từ '83338' xuất hiện 1 lần
# Từ '8ball' xuất hiện 1 lần
# Từ '07808247860' xuất hiện 1 lần
# Từ '08719899229' xuất hiện 1 lần
# Từ '40411' xuất hiện 1 lần
# Từ '49557' xuất hiện 1 lần
# Từ 'gsex' xuất hiện 1 lần
# Từ '2667' xuất hiện 1 lần
# Từ 'wc1n' xuất hiện 1 lần
# Từ '3xx' xuất hiện 1 lần
# Từ '3mobil' xuất hiện 1 lần
# Từ 'chatlin' xuất hiện 1 lần
# Từ 'inclu' xuất hiện 1 lần
# Từ 'india' xuất hiện 1 lần
# Từ 'serv' xuất hiện 1 lần
# Từ 'sed' xuất hiện 1 lần
# Từ 'l8er' xuất hiện 1 lần
# Từ 'mega' xuất hiện 1 lần
# Từ 'giv' xuất hiện 1 lần
# Từ 'shit' xuất hiện 1 lần
# Từ 'bailiff' xuất hiện 1 lần
# Từ 'hous' xuất hiện 1 lần
# Từ '087187272008' xuất hiện 1 lần
# Từ 'now1' xuất hiện 1 lần

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35404

# %%
from collections import Counter
word_freq = Counter(ham_corpus).most_common(30)
df_word_freq = pd.DataFrame(word_freq, columns=['Ham Word', 'Frequency'])
sns.barplot(x='Ham Word', y='Frequency', data=df_word_freq)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
ham_words_dict = {}  # Khởi tạo từ điển để lưu trữ tần suất xuất hiện của ham words

# Duyệt qua từng từ trong danh sách và tăng tần suất xuất hiện trong từ điển
for word in ham_corpus:
    if word in ham_words_dict:
        ham_words_dict[word] += 1
    else:
        ham_words_dict[word] = 1

ham_words_dict = sorted(ham_words_dict.items(), key=lambda x: x[1], reverse=True)

# In tần suất xuất hiện của từng từ
for word, freq in ham_words_dict:
    print(f"Từ '{word}' xuất hiện {freq} lần")
ham_words_dict = dict(ham_words_dict)
# Out:
# Từ 'u' xuất hiện 883 lần
# Từ 'go' xuất hiện 404 lần
# Từ 'get' xuất hiện 349 lần
# Từ 'gt' xuất hiện 288 lần
# Từ 'lt' xuất hiện 287 lần
# Từ '2' xuất hiện 284 lần
# Từ 'come' xuất hiện 275 lần
# Từ 'got' xuất hiện 236 lần
# Từ 'know' xuất hiện 236 lần
# Từ 'like' xuất hiện 234 lần
# Từ 'call' xuất hiện 233 lần
# Từ 'time' xuất hiện 219 lần
# Từ 'ok' xuất hiện 217 lần
# Từ 'love' xuất hiện 216 lần
# Từ 'good' xuất hiện 213 lần
# Từ 'want' xuất hiện 208 lần
# Từ 'ur' xuất hiện 197 lần
# Từ 'day' xuất hiện 190 lần
# Từ 'need' xuất hiện 170 lần
# Từ 'one' xuất hiện 165 lần
# Từ 'lor' xuất hiện 159 lần
# Từ '4' xuất hiện 156 lần
# Từ 'home' xuất hiện 152 lần
# Từ 'think' xuất hiện 149 lần
# Từ 'see' xuất hiện 147 lần
# Từ 'take' xuất hiện 143 lần
# Từ 'still' xuất hiện 143 lần
# Từ 'da' xuất hiện 142 lần
# Từ 'tell' xuất hiện 133 lần
# Từ 'make' xuất hiện 129 lần
# Từ 'say' xuất hiện 127 lần
# Từ 'back' xuất hiện 127 lần
# Từ 'today' xuất hiện 123 lần
# Từ 'hope' xuất hiện 122 lần
# Từ 'ask' xuất hiện 121 lần
# Từ 'sorri' xuất hiện 121 lần
# Từ 'n' xuất hiện 120 lần
# Từ 'send' xuất hiện 120 lần
# Từ 'r' xuất hiện 120 lần
# Từ 'work' xuất hiện 118 lần
# Từ 'dont' xuất hiện 118 lần
# Từ 'meet' xuất hiện 112 lần
# Từ 'hi' xuất hiện 111 lần
# Từ 'well' xuất hiện 109 lần
# Từ 'thing' xuất hiện 109 lần
# Từ 'wat' xuất hiện 108 lần
# Từ 'k' xuất hiện 107 lần
# Từ 'much' xuất hiện 107 lần
# Từ 'night' xuất hiện 107 lần
# Từ 'oh' xuất hiện 106 lần
# Từ 'miss' xuất hiện 106 lần
# Từ 'happi' xuất hiện 104 lần
# Từ 'give' xuất hiện 102 lần
# Từ 'later' xuất hiện 100 lần
# Từ 'hey' xuất hiện 100 lần
# Từ 'great' xuất hiện 97 lần
# Từ 'na' xuất hiện 96 lần
# Từ 'wait' xuất hiện 96 lần
# Từ 'way' xuất hiện 95 lần
# Từ 'alreadi' xuất hiện 90 lần
# Từ 'thank' xuất hiện 87 lần
# Từ 'let' xuất hiện 86 lần
# Từ 'yeah' xuất hiện 86 lần
# Từ 'text' xuất hiện 85 lần
# Từ 'feel' xuất hiện 83 lần
# Từ 'realli' xuất hiện 83 lần
# Từ 'pl' xuất hiện 83 lần
# Từ 'wan' xuất hiện 81 lần
# Từ 'dear' xuất hiện 81 lần
# Từ 'right' xuất hiện 80 lần
# Từ 'e' xuất hiện 77 lần
# Từ 'even' xuất hiện 77 lần
# Từ 'friend' xuất hiện 77 lần
# Từ 'sure' xuất hiện 76 lần
# Từ 'said' xuất hiện 76 lần
# Từ 'co' xuất hiện 76 lần
# Từ 'would' xuất hiện 75 lần
# Từ 'leav' xuất hiện 75 lần
# Từ 'lol' xuất hiện 74 lần
# Từ 'babe' xuất hiện 74 lần
# Từ 'pleas' xuất hiện 74 lần
# Từ 'im' xuất hiện 73 lần
# Từ 'phone' xuất hiện 73 lần
# Từ 'ye' xuất hiện 72 lần
# Từ 'tri' xuất hiện 72 lần
# Từ 'sleep' xuất hiện 72 lần
# Từ 'anyth' xuất hiện 71 lần
# Từ 'pick' xuất hiện 71 lần
# Từ 'tomorrow' xuất hiện 69 lần
# Từ 'morn' xuất hiện 69 lần
# Từ 'someth' xuất hiện 69 lần
# Từ 'keep' xuất hiện 68 lần
# Từ 'care' xuất hiện 68 lần
# Từ 'finish' xuất hiện 67 lần
# Từ 'buy' xuất hiện 67 lần
# Từ 'week' xuất hiện 66 lần
# Từ 'watch' xuất hiện 65 lần
# Từ 'also' xuất hiện 65 lần
# Từ 'number' xuất hiện 64 lần
# Từ 'life' xuất hiện 63 lần
# Từ 'last' xuất hiện 62 lần
# Từ 'new' xuất hiện 61 lần
# Từ 'look' xuất hiện 60 lần
# Từ 'around' xuất hiện 59 lần
# Từ 'gon' xuất hiện 59 lần
# Từ 'use' xuất hiện 59 lần
# Từ 'year' xuất hiện 59 lần
# Từ 'amp' xuất hiện 58 lần
# Từ 'c' xuất hiện 57 lần
# Từ 'tonight' xuất hiện 57 lần
# Từ 'ca' xuất hiện 57 lần
# Từ 'could' xuất hiện 57 lần
# Từ 'late' xuất hiện 57 lần
# Từ 'ya' xuất hiện 56 lần
# Từ 'dun' xuất hiện 55 lần
# Từ 'talk' xuất hiện 55 lần
# Từ 'b' xuất hiện 55 lần
# Từ 'messag' xuất hiện 55 lần
# Từ 'money' xuất hiện 55 lần
# Từ 'free' xuất hiện 55 lần
# Từ 'smile' xuất hiện 55 lần
# Từ 'wish' xuất hiện 55 lần
# Từ 'soon' xuất hiện 54 lần
# Từ 'guy' xuất hiện 54 lần
# Từ 'msg' xuất hiện 53 lần
# Từ 'place' xuất hiện 53 lần
# Từ 'plan' xuất hiện 53 lần
# Từ 'ìï' xuất hiện 53 lần
# Từ 'first' xuất hiện 52 lần
# Từ 'alway' xuất hiện 52 lần
# Từ 'us' xuất hiện 52 lần
# Từ 'start' xuất hiện 51 lần
# Từ 'haha' xuất hiện 51 lần
# Từ 'sent' xuất hiện 51 lần
# Từ 'told' xuất hiện 51 lần
# Từ 'happen' xuất hiện 50 lần
# Từ 'thk' xuất hiện 50 lần
# Từ 'mani' xuất hiện 50 lần
# Từ 'find' xuất hiện 49 lần
# Từ 'cant' xuất hiện 49 lần
# Từ 'nice' xuất hiện 48 lần
# Từ 'yet' xuất hiện 48 lần
# Từ 'lot' xuất hiện 48 lần
# Từ 'went' xuất hiện 48 lần
# Từ 'fuck' xuất hiện 47 lần
# Từ 'check' xuất hiện 46 lần
# Từ 'next' xuất hiện 46 lần
# Từ 'eat' xuất hiện 45 lần
# Từ 'done' xuất hiện 45 lần
# Từ 'class' xuất hiện 45 lần
# Từ 'thought' xuất hiện 45 lần
# Từ 'mean' xuất hiện 45 lần
# Từ 'stuff' xuất hiện 44 lần
# Từ 'fine' xuất hiện 44 lần
# Từ 'reach' xuất hiện 44 lần
# Từ 'gud' xuất hiện 44 lần
# Từ 'v' xuất hiện 43 lần
# Từ 'car' xuất hiện 43 lần
# Từ 'bit' xuất hiện 43 lần
# Từ 'mayb' xuất hiện 42 lần
# Từ 'someon' xuất hiện 42 lần
# Từ 'long' xuất hiện 42 lần
# Từ 'ill' xuất hiện 42 lần
# Từ 'hour' xuất hiện 42 lần
# Từ 'worri' xuất hiện 41 lần
# Từ 'yup' xuất hiện 41 lần
# Từ 'stop' xuất hiện 41 lần
# Từ 'better' xuất hiện 41 lần
# Từ '3' xuất hiện 40 lần
# Từ 'never' xuất hiện 40 lần
# Từ '1' xuất hiện 40 lần
# Từ 'cool' xuất hiện 40 lần
# Từ 'job' xuất hiện 40 lần
# Từ 'person' xuất hiện 40 lần
# Từ 'repli' xuất hiện 40 lần
# Từ 'problem' xuất hiện 40 lần
# Từ 'lunch' xuất hiện 39 lần
# Từ 'peopl' xuất hiện 39 lần
# Từ 'drive' xuất hiện 39 lần
# Từ 'everi' xuất hiện 39 lần
# Từ 'quit' xuất hiện 39 lần
# Từ 'lar' xuất hiện 38 lần
# Từ 'pay' xuất hiện 38 lần
# Từ 'may' xuất hiện 38 lần
# Từ 'help' xuất hiện 37 lần
# Từ 'that' xuất hiện 37 lần
# Từ 'liao' xuất hiện 37 lần
# Từ 'dat' xuất hiện 37 lần
# Từ 'shop' xuất hiện 37 lần
# Từ 'bring' xuất hiện 37 lần
# Từ 'wonder' xuất hiện 36 lần
# Từ 'month' xuất hiện 36 lần
# Từ 'hello' xuất hiện 36 lần
# Từ 'girl' xuất hiện 36 lần
# Từ 'end' xuất hiện 36 lần
# Từ 'yo' xuất hiện 36 lần
# Từ 'hous' xuất hiện 36 lần
# Từ 'minut' xuất hiện 36 lần
# Từ 'kiss' xuất hiện 36 lần
# Từ 'rememb' xuất hiện 35 lần
# Từ 'dinner' xuất hiện 35 lần
# Từ 'room' xuất hiện 35 lần
# Từ 'x' xuất hiện 35 lần
# Từ 'best' xuất hiện 35 lần
# Từ 'guess' xuất hiện 35 lần
# Từ 'ju' xuất hiện 35 lần
# Từ 'readi' xuất hiện 35 lần
# Từ 'min' xuất hiện 35 lần
# Từ 'man' xuất hiện 34 lần
# Từ 'noth' xuất hiện 34 lần
# Từ 'might' xuất hiện 34 lần
# Từ 'shit' xuất hiện 34 lần
# Từ 'mind' xuất hiện 34 lần
# Từ 'earli' xuất hiện 33 lần
# Từ 'anoth' xuất hiện 33 lần
# Từ 'aight' xuất hiện 33 lần
# Từ 'sir' xuất hiện 33 lần
# Từ 'stay' xuất hiện 33 lần
# Từ 'big' xuất hiện 33 lần
# Từ 'actual' xuất hiện 33 lần
# Từ 'put' xuất hiện 33 lần
# Từ 'god' xuất hiện 33 lần
# Từ 'probabl' xuất hiện 33 lần
# Từ 'wont' xuất hiện 32 lần
# Từ 'ah' xuất hiện 32 lần
# Từ 'bed' xuất hiện 32 lần
# Từ 'anyway' xuất hiện 32 lần
# Từ 'heart' xuất hiện 32 lần
# Từ 'boy' xuất hiện 32 lần
# Từ 'book' xuất hiện 32 lần
# Từ 'den' xuất hiện 32 lần
# Từ 'name' xuất hiện 31 lần
# Từ 'show' xuất hiện 31 lần
# Từ 'chang' xuất hiện 31 lần
# Từ 'babi' xuất hiện 31 lần
# Từ 'dunno' xuất hiện 31 lần
# Từ 'princess' xuất hiện 31 lần
# Từ 'word' xuất hiện 30 lần
# Từ 'leh' xuất hiện 30 lần
# Từ 'face' xuất hiện 30 lần
# Từ 'thanx' xuất hiện 30 lần
# Từ 'wake' xuất hiện 30 lần
# Từ 'enjoy' xuất hiện 30 lần
# Từ 'dad' xuất hiện 30 lần
# Từ 'left' xuất hiện 29 lần
# Từ 'sweet' xuất hiện 29 lần
# Từ 'run' xuất hiện 29 lần
# Từ 'hear' xuất hiện 29 lần
# Từ 'shall' xuất hiện 29 lần
# Từ 'bad' xuất hiện 29 lần
# Từ 'world' xuất hiện 28 lần
# Từ 'bu' xuất hiện 28 lần
# Từ 'forgot' xuất hiện 28 lần
# Từ 'tmr' xuất hiện 28 lần
# Từ 'didnt' xuất hiện 28 lần
# Từ 'two' xuất hiện 28 lần
# Từ 'ever' xuất hiện 28 lần
# Từ 'sat' xuất hiện 28 lần
# Từ 'wif' xuất hiện 27 lần
# Từ 'weekend' xuất hiện 27 lần
# Từ 'hurt' xuất hiện 27 lần
# Từ 'school' xuất hiện 27 lần
# Từ 'mail' xuất hiện 27 lần
# Từ 'littl' xuất hiện 27 lần
# Từ 'walk' xuất hiện 27 lần
# Từ 'everyth' xuất hiện 27 lần
# Từ 'goe' xuất hiện 26 lần
# Từ 'though' xuất hiện 26 lần
# Từ 'lesson' xuất hiện 26 lần
# Từ 'pain' xuất hiện 26 lần
# Từ 'afternoon' xuất hiện 26 lần
# Từ 'movi' xuất hiện 26 lần
# Từ 'abt' xuất hiện 26 lần
# Từ 'okay' xuất hiện 26 lần
# Từ 'test' xuất hiện 26 lần
# Từ 'abl' xuất hiện 26 lần
# Từ 'sound' xuất hiện 26 lần
# Từ 'luv' xuất hiện 26 lần
# Từ 'di' xuất hiện 26 lần
# Từ 'offic' xuất hiện 26 lần
# Từ 'live' xuất hiện 25 lần
# Từ 'enough' xuất hiện 25 lần
# Từ 'decid' xuất hiện 25 lần
# Từ 'sinc' xuất hiện 25 lần
# Từ 'birthday' xuất hiện 25 lần
# Từ 'play' xuất hiện 25 lần
# Từ 'juz' xuất hiện 25 lần
# Từ 'bath' xuất hiện 25 lần
# Từ 'speak' xuất hiện 24 lần
# Từ 'saw' xuất hiện 24 lần
# Từ 'hair' xuất hiện 24 lần
# Từ 'havent' xuất hiện 24 lần
# Từ 'smoke' xuất hiện 24 lần
# Từ 'wot' xuất hiện 24 lần
# Từ 'made' xuất hiện 24 lần
# Từ 'dude' xuất hiện 24 lần
# Từ '5' xuất hiện 24 lần
# Từ 'bore' xuất hiện 24 lần
# Từ 'town' xuất hiện 24 lần
# Từ 'half' xuất hiện 23 lần
# Từ 'came' xuất hiện 23 lần
# Từ 'els' xuất hiện 23 lần
# Từ 'haf' xuất hiện 23 lần
# Từ 'without' xuất hiện 23 lần
# Từ 'til' xuất hiện 23 lần
# Từ 'hav' xuất hiện 23 lần
# Từ 'oso' xuất hiện 23 lần
# Từ 'fun' xuất hiện 23 lần
# Từ 'onlin' xuất hiện 23 lần
# Từ 'lei' xuất hiện 23 lần
# Từ 'ard' xuất hiện 22 lần
# Từ 'alright' xuất hiện 22 lần
# Từ 'real' xuất hiện 22 lần
# Từ 'special' xuất hiện 22 lần
# Từ 'food' xuất hiện 22 lần
# Từ 'head' xuất hiện 22 lần
# Từ 'beauti' xuất hiện 22 lần
# Từ 'sch' xuất hiện 22 lần
# Từ 'goin' xuất hiện 22 lần
# Từ 'mom' xuất hiện 21 lần
# Từ 'wo' xuất hiện 21 lần
# Từ 'pa' xuất hiện 21 lần
# Từ 'caus' xuất hiện 21 lần
# Từ 'must' xuất hiện 21 lần
# Từ 'open' xuất hiện 21 lần
# Từ 'dream' xuất hiện 21 lần
# Từ 'tv' xuất hiện 21 lần
# Từ 'nite' xuất hiện 21 lần
# Từ 'read' xuất hiện 21 lần
# Từ 'drink' xuất hiện 21 lần
# Từ 'tot' xuất hiện 21 lần
# Từ 'togeth' xuất hiện 21 lần
# Từ 'drop' xuất hiện 21 lần
# Từ '6' xuất hiện 21 lần
# Từ 'second' xuất hiện 20 lần
# Từ 'yesterday' xuất hiện 20 lần
# Từ 'busi' xuất hiện 20 lần
# Từ 'account' xuất hiện 20 lần
# Từ 'studi' xuất hiện 20 lần
# Từ 'si' xuất hiện 20 lần
# Từ 'decim' xuất hiện 20 lần
# Từ 'noe' xuất hiện 20 lần
# Từ 'full' xuất hiện 20 lần
# Từ 'chikku' xuất hiện 20 lần
# Từ 'huh' xuất hiện 20 lần
# Từ 'detail' xuất hiện 20 lần
# Từ 'famili' xuất hiện 20 lần
# Từ 'de' xuất hiện 20 lần
# Từ 'away' xuất hiện 20 lần
# Từ 'treat' xuất hiện 19 lần
# Từ 'set' xuất hiện 19 lần
# Từ 'aft' xuất hiện 19 lần
# Từ 'till' xuất hiện 19 lần
# Từ 'tomo' xuất hiện 19 lần
# Từ 'answer' xuất hiện 19 lần
# Từ 'awesom' xuất hiện 19 lần
# Từ 'true' xuất hiện 19 lần
# Từ 'trip' xuất hiện 19 lần
# Từ 'post' xuất hiện 19 lần
# Từ 'mum' xuất hiện 19 lần
# Từ 'train' xuất hiện 19 lần
# Từ 'rite' xuất hiện 19 lần
# Từ '9' xuất hiện 18 lần
# Từ 'part' xuất hiện 18 lần
# Từ 'frnd' xuất hiện 18 lần
# Từ 'close' xuất hiện 18 lần
# Từ 'old' xuất hiện 18 lần
# Từ 'question' xuất hiện 18 lần
# Từ 'believ' xuất hiện 18 lần
# Từ 'plz' xuất hiện 18 lần
# Từ 'reason' xuất hiện 18 lần
# Từ 'gd' xuất hiện 18 lần
# Từ 'neva' xuất hiện 18 lần
# Từ 'sad' xuất hiện 18 lần
# Từ 'plu' xuất hiện 18 lần
# Từ 'point' xuất hiện 17 lần
# Từ 'brother' xuất hiện 17 lần
# Từ 'move' xuất hiện 17 lần
# Từ 'took' xuất hiện 17 lần
# Từ 'ta' xuất hiện 17 lần
# Từ 'wen' xuất hiện 17 lần
# Từ 'address' xuất hiện 17 lần
# Từ 'hand' xuất hiện 17 lần
# Từ 'join' xuất hiện 17 lần
# Từ 'touch' xuất hiện 17 lần
# Từ 'colleg' xuất hiện 17 lần
# Từ 'die' xuất hiện 17 lần
# Từ 'wil' xuất hiện 17 lần
# Từ 'hold' xuất hiện 17 lần
# Từ 'ring' xuất hiện 17 lần
# Từ 'sort' xuất hiện 17 lần
# Từ 'mine' xuất hiện 17 lần
# Từ 'whatev' xuất hiện 17 lần
# Từ 'search' xuất hiện 16 lần
# Từ 'ha' xuất hiện 16 lần
# Từ 'smth' xuất hiện 16 lần
# Từ 'tho' xuất hiện 16 lần
# Từ 'fri' xuất hiện 16 lần
# Từ 'forget' xuất hiện 16 lần
# Từ 'prob' xuất hiện 16 lần
# Từ 'gone' xuất hiện 16 lần
# Từ 'coz' xuất hiện 16 lần
# Từ 'complet' xuất hiện 16 lần
# Từ 'carlo' xuất hiện 16 lần
# Từ 'boytoy' xuất hiện 16 lần
# Từ 'id' xuất hiện 16 lần
# Từ 'exam' xuất hiện 16 lần
# Từ 'park' xuất hiện 16 lần
# Từ 'far' xuất hiện 16 lần
# Từ 'sister' xuất hiện 16 lần
# Từ 'g' xuất hiện 16 lần
# Từ 'kind' xuất hiện 16 lần
# Từ 'outsid' xuất hiện 16 lần
# Từ 'pub' xuất hiện 16 lần
# Từ 'email' xuất hiện 16 lần
# Từ 'sun' xuất hiện 16 lần
# Từ 'sell' xuất hiện 16 lần
# Từ 'mate' xuất hiện 16 lần
# Từ 'seem' xuất hiện 15 lần
# Từ 'cut' xuất hiện 15 lần
# Từ 'mu' xuất hiện 15 lần
# Từ 'everyon' xuất hiện 15 lần
# Từ 'wit' xuất hiện 15 lần
# Từ 'bank' xuất hiện 15 lần
# Từ 'final' xuất hiện 15 lần
# Từ 'xxx' xuất hiện 15 lần
# Từ 'darlin' xuất hiện 15 lần
# Từ 'oredi' xuất hiện 15 lần
# Từ 'easi' xuất hiện 15 lần
# Từ 'lose' xuất hiện 15 lần
# Từ 'oki' xuất hiện 15 lần
# Từ 'nope' xuất hiện 15 lần
# Từ 'pretti' xuất hiện 15 lần
# Từ 'listen' xuất hiện 15 lần
# Từ 'drug' xuất hiện 15 lần
# Từ 'laugh' xuất hiện 15 lần
# Từ 'sit' xuất hiện 15 lần
# Từ 'anyon' xuất hiện 15 lần
# Từ 'parti' xuất hiện 15 lần
# Từ 'tht' xuất hiện 15 lần
# Từ 'how' xuất hiện 15 lần
# Từ 'joke' xuất hiện 14 lần
# Từ 'usual' xuất hiện 14 lần
# Từ 'whole' xuất hiện 14 lần
# Từ 'sm' xuất hiện 14 lần
# Từ 'rain' xuất hiện 14 lần
# Từ 'friday' xuất hiện 14 lần
# Từ 'hmm' xuất hiện 14 lần
# Từ 'uncl' xuất hiện 14 lần
# Từ 'parent' xuất hiện 14 lần
# Từ 'spend' xuất hiện 14 lần
# Từ 'found' xuất hiện 14 lần
# Từ 'ga' xuất hiện 14 lần
# Từ 'break' xuất hiện 14 lần
# Từ 'chat' xuất hiện 14 lần
# Từ 'import' xuất hiện 14 lần
# Từ 'compani' xuất hiện 14 lần
# Từ 'meant' xuất hiện 14 lần
# Từ 'friendship' xuất hiện 14 lần
# Từ 'jay' xuất hiện 14 lần
# Từ 'project' xuất hiện 14 lần
# Từ 'bout' xuất hiện 14 lần
# Từ '7' xuất hiện 14 lần
# Từ 'suppos' xuất hiện 14 lần
# Từ 'differ' xuất hiện 14 lần
# Từ 'sea' xuất hiện 14 lần
# Từ 'snow' xuất hiện 14 lần
# Từ 'understand' xuất hiện 14 lần
# Từ 'wife' xuất hiện 14 lần
# Từ 'chennai' xuất hiện 14 lần
# Từ 'avail' xuất hiện 13 lần
# Từ 'catch' xuất hiện 13 lần
# Từ 'almost' xuất hiện 13 lần
# Từ 'hee' xuất hiện 13 lần
# Từ 'ticket' xuất hiện 13 lần
# Từ 'cash' xuất hiện 13 lần
# Từ 'shower' xuất hiện 13 lần
# Từ 'mah' xuất hiện 13 lần
# Từ 'type' xuất hiện 13 lần
# Từ 'cours' xuất hiện 13 lần
# Từ 'txt' xuất hiện 13 lần
# Từ 'goodmorn' xuất hiện 13 lần
# Từ 'side' xuất hiện 13 lần
# Từ 'case' xuất hiện 13 lần
# Từ 'tel' xuất hiện 13 lần
# Từ 'fr' xuất hiện 13 lần
# Từ 'figur' xuất hiện 13 lần
# Từ 'moment' xuất hiện 13 lần
# Từ 'charg' xuất hiện 13 lần
# Từ 'card' xuất hiện 13 lần
# Từ 'bt' xuất hiện 13 lần
# Từ 'simpl' xuất hiện 13 lần
# Từ '8' xuất hiện 13 lần
# Từ 'fast' xuất hiện 13 lần
# Từ 'yar' xuất hiện 13 lần
# Từ 'valentin' xuất hiện 13 lần
# Từ 'eve' xuất hiện 13 lần
# Từ 'knw' xuất hiện 13 lần
# Từ 'nt' xuất hiện 13 lần
# Từ 'least' xuất hiện 13 lần
# Từ 'earlier' xuất hiện 13 lần
# Từ 'mobil' xuất hiện 13 lần
# Từ 'fren' xuất hiện 13 lần
# Từ 'w' xuất hiện 13 lần
# Từ 'alon' xuất hiện 13 lần
# Từ 'promis' xuất hiện 12 lần
# Từ 'date' xuất hiện 12 lần
# Từ 'eh' xuất hiện 12 lần
# Từ 'hungri' xuất hiện 12 lần
# Từ 'turn' xuất hiện 12 lần
# Từ 'crave' xuất hiện 12 lần
# Từ 'save' xuất hiện 12 lần
# Từ 'stand' xuất hiện 12 lần
# Từ 'cost' xuất hiện 12 lần
# Từ 'tire' xuất hiện 12 lần
# Từ 'what' xuất hiện 12 lần
# Từ 'hard' xuất hiện 12 lần
# Từ 'contact' xuất hiện 12 lần
# Từ 'safe' xuất hiện 12 lần
# Từ 'march' xuất hiện 12 lần
# Từ 'win' xuất hiện 12 lần
# Từ 'fix' xuất hiện 12 lần
# Từ 'swing' xuất hiện 12 lần
# Từ 'christma' xuất hiện 12 lần
# Từ 'light' xuất hiện 12 lần
# Từ 'return' xuất hiện 12 lần
# Từ 'interest' xuất hiện 12 lần
# Từ 'ago' xuất hiện 12 lần
# Từ 'seen' xuất hiện 12 lần
# Từ 'coupl' xuất hiện 12 lần
# Từ 'ass' xuất hiện 12 lần
# Từ 'th' xuất hiện 12 lần
# Từ 'scream' xuất hiện 12 lần
# Từ 'confirm' xuất hiện 12 lần
# Từ 'pic' xuất hiện 12 lần
# Từ 'gym' xuất hiện 12 lần
# Từ 'clean' xuất hiện 12 lần
# Từ 'game' xuất hiện 12 lần
# Từ 'darren' xuất hiện 12 lần
# Từ 'gal' xuất hiện 12 lần
# Từ 'ugh' xuất hiện 12 lần
# Từ 'wrong' xuất hiện 12 lần
# Từ 'grin' xuất hiện 12 lần
# Từ 'difficult' xuất hiện 12 lần
# Từ 'comin' xuất hiện 11 lần
# Từ 'abiola' xuất hiện 11 lần
# Từ 'hospit' xuất hiện 11 lần
# Từ 'download' xuất hiện 11 lần
# Từ 'load' xuất hiện 11 lần
# Từ 'hit' xuất hiện 11 lần
# Từ 'wine' xuất hiện 11 lần
# Từ 'hmmm' xuất hiện 11 lần
# Từ 'muz' xuất hiện 11 lần
# Từ 'deal' xuất hiện 11 lần
# Từ 'stori' xuất hiện 11 lần
# Từ 'orchard' xuất hiện 11 lần
# Từ 'kate' xuất hiện 11 lần
# Từ 'teach' xuất hiện 11 lần
# Từ 'road' xuất hiện 11 lần
# Từ 'laptop' xuất hiện 11 lần
# Từ 'angri' xuất hiện 11 lần
# Từ 'expect' xuất hiện 11 lần
# Từ 'disturb' xuất hiện 11 lần
# Từ 'wana' xuất hiện 11 lần
# Từ 'normal' xuất hiện 11 lần
# Từ 'rest' xuất hiện 11 lần
# Từ 'lost' xuất hiện 11 lần
# Từ 'chanc' xuất hiện 11 lần
# Từ 'st' xuất hiện 11 lần
# Từ 'forward' xuất hiện 11 lần
# Từ 'slow' xuất hiện 11 lần
# Từ 'rock' xuất hiện 11 lần
# Từ 'india' xuất hiện 11 lần
# Từ 'pm' xuất hiện 11 lần
# Từ 'monday' xuất hiện 11 lần
# Từ 'rent' xuất hiện 11 lần
# Từ 'frm' xuất hiện 11 lần
# Từ 'holiday' xuất hiện 11 lần
# Từ 'kid' xuất hiện 11 lần
# Từ 'paper' xuất hiện 11 lần
# Từ 'idea' xuất hiện 11 lần
# Từ 'whenev' xuất hiện 11 lần
# Từ 'crazi' xuất hiện 10 lần
# Từ 'nah' xuất hiện 10 lần
# Từ 'usf' xuất hiện 10 lần
# Từ 'sick' xuất hiện 10 lần
# Từ 'oop' xuất hiện 10 lần
# Từ 'song' xuất hiện 10 lần
# Từ 'xx' xuất hiện 10 lần
# Từ 'il' xuất hiện 10 lần
# Từ 'gave' xuất hiện 10 lần
# Từ 'page' xuất hiện 10 lần
# Từ 'felt' xuất hiện 10 lần
# Từ 'inform' xuất hiện 10 lần
# Từ 'ni8' xuất hiện 10 lần
# Từ 'sometim' xuất hiện 10 lần
# Từ 'mr' xuất hiện 10 lần
# Từ 'gr8' xuất hiện 10 lần
# Từ 'trust' xuất hiện 10 lần
# Từ 'semest' xuất hiện 10 lần
# Từ 'pass' xuất hiện 10 lần
# Từ 'fone' xuất hiện 10 lần
# Từ 'small' xuất hiện 10 lần
# Từ 'ex' xuất hiện 10 lần
# Từ 'woke' xuất hiện 10 lần
# Từ 'custom' xuất hiện 10 lần
# Từ 'mm' xuất hiện 10 lần
# Từ 'yep' xuất hiện 10 lần
# Từ 'voic' xuất hiện 10 lần
# Từ 'either' xuất hiện 10 lần
# Từ 'water' xuất hiện 10 lần
# Từ 'across' xuất hiện 10 lần
# Từ 'remind' xuất hiện 10 lần
# Từ 'door' xuất hiện 10 lần
# Từ 'age' xuất hiện 10 lần
# Từ 'knew' xuất hiện 10 lần
# Từ 'fill' xuất hiện 10 lần
# Từ 'support' xuất hiện 10 lần
# Từ 'fact' xuất hiện 10 lần
# Từ 'doin' xuất hiện 10 lần
# Từ 'excus' xuất hiện 10 lần
# Từ 'hr' xuất hiện 10 lần
# Từ 'per' xuất hiện 9 lần
# Từ 'sunday' xuất hiện 9 lần
# Từ 'mark' xuất hiện 9 lần
# Từ 'saturday' xuất hiện 9 lần
# Từ 'invit' xuất hiện 9 lần
# Từ 'wow' xuất hiện 9 lần
# Từ 'offer' xuất hiện 9 lần
# Từ 'forev' xuất hiện 9 lần
# Từ 'short' xuất hiện 9 lần
# Từ 'lucki' xuất hiện 9 lần
# Từ 'price' xuất hiện 9 lần
# Từ 'comput' xuất hiện 9 lần
# Từ 'lazi' xuất hiện 9 lần
# Từ 'lect' xuất hiện 9 lần
# Từ 'pray' xuất hiện 9 lần
# Từ 'wast' xuất hiện 9 lần
# Từ 'doesnt' xuất hiện 9 lần
# Từ 'especi' xuất hiện 9 lần
# Từ 'dead' xuất hiện 9 lần
# Từ 'mrt' xuất hiện 9 lần
# Từ 'ive' xuất hiện 9 lần
# Từ 'bill' xuất hiện 9 lần
# Từ 'appreci' xuất hiện 9 lần
# Từ 'wid' xuất hiện 9 lần
# Từ 'blue' xuất hiện 9 lần
# Từ 'stupid' xuất hiện 9 lần
# Từ 'unless' xuất hiện 9 lần
# Từ 'somebodi' xuất hiện 9 lần
# Từ 'somewher' xuất hiện 9 lần
# Từ 'al' xuất hiện 9 lần
# Từ 'receiv' xuất hiện 9 lần
# Từ 'ten' xuất hiện 9 lần
# Từ '10' xuất hiện 9 lần
# Từ 'line' xuất hiện 9 lần
# Từ 'cum' xuất hiện 9 lần
# Từ 'depend' xuất hiện 9 lần
# Từ 'meh' xuất hiện 9 lần
# Từ 'fight' xuất hiện 9 lần
# Từ 'less' xuất hiện 9 lần
# Từ 'ladi' xuất hiện 9 lần
# Từ 'warm' xuất hiện 9 lần
# Từ 'em' xuất hiện 9 lần
# Từ '1st' xuất hiện 9 lần
# Từ 'xy' xuất hiện 9 lần
# Từ 'add' xuất hiện 9 lần
# Từ 'glad' xuất hiện 9 lần
# Từ 'eye' xuất hiện 9 lần
# Từ 'possibl' xuất hiện 9 lần
# Từ 'gift' xuất hiện 9 lần
# Từ 'bag' xuất hiện 9 lần
# Từ 'poor' xuất hiện 9 lần
# Từ 'photo' xuất hiện 9 lần
# Từ 'wear' xuất hiện 9 lần
# Từ 'truth' xuất hiện 9 lần
# Từ 'ad' xuất hiện 9 lần
# Từ 'heard' xuất hiện 9 lần
# Từ 'hiya' xuất hiện 9 lần
# Từ 'doctor' xuất hiện 9 lần
# Từ 'film' xuất hiện 9 lần
# Từ 'nobodi' xuất hiện 9 lần
# Từ 'collect' xuất hiện 9 lần
# Từ 'other' xuất hiện 9 lần
# Từ 'bb' xuất hiện 9 lần
# Từ 'player' xuất hiện 9 lần
# Từ 'surpris' xuất hiện 9 lần
# Từ 'sexi' xuất hiện 9 lần
# Từ 'copi' xuất hiện 8 lần
# Từ 'anymor' xuất hiện 8 lần
# Từ 'pizza' xuất hiện 8 lần
# Từ 'clear' xuất hiện 8 lần
# Từ 'cheer' xuất hiện 8 lần
# Từ 'quick' xuất hiện 8 lần
# Từ 'roommat' xuất hiện 8 lần
# Từ 'letter' xuất hiện 8 lần
# Từ 'nigeria' xuất hiện 8 lần
# Từ 'situat' xuất hiện 8 lần
# Từ 'spent' xuất hiện 8 lần
# Từ 'wk' xuất hiện 8 lần
# Từ 'weight' xuất hiện 8 lần
# Từ 'bother' xuất hiện 8 lần
# Từ 'bak' xuất hiện 8 lần
# Từ 'log' xuất hiện 8 lần
# Từ 'net' xuất hiện 8 lần
# Từ 'xma' xuất hiện 8 lần
# Từ 'mrng' xuất hiện 8 lần
# Từ 'rs' xuất hiện 8 lần
# Từ 'connect' xuất hiện 8 lần
# Từ 'slept' xuất hiện 8 lần
# Từ 'bcoz' xuất hiện 8 lần
# Từ 'correct' xuất hiện 8 lần
# Từ 'lem' xuất hiện 8 lần
# Từ 'celebr' xuất hiện 8 lần
# Từ 'teas' xuất hiện 8 lần
# Từ 'bslvyl' xuất hiện 8 lần
# Từ 'imagin' xuất hiện 8 lần
# Từ 'pete' xuất hiện 8 lần
# Từ 'round' xuất hiện 8 lần
# Từ 'urself' xuất hiện 8 lần
# Từ 'basic' xuất hiện 8 lần
# Từ 'weed' xuất hiện 8 lần
# Từ 'met' xuất hiện 8 lần
# Từ 'mistak' xuất hiện 8 lần
# Từ 'facebook' xuất hiện 8 lần
# Từ 'aha' xuất hiện 8 lần
# Từ 'din' xuất hiện 8 lần
# Từ 'kinda' xuất hiện 8 lần
# Từ 'near' xuất hiện 8 lần
# Từ 'silent' xuất hiện 8 lần
# Từ 'fat' xuất hiện 8 lần
# Từ 'workin' xuất hiện 8 lần
# Từ 'daddi' xuất hiện 8 lần
# Từ 'choos' xuất hiện 8 lần
# Từ 'present' xuất hiện 8 lần
# Từ 'noon' xuất hiện 8 lần
# Từ 'alex' xuất hiện 8 lần
# Từ 'longer' xuất hiện 8 lần
# Từ 'tuesday' xuất hiện 8 lần
# Từ 'ho' xuất hiện 8 lần
# Từ 'order' xuất hiện 8 lần
# Từ 'visit' xuất hiện 8 lần
# Từ 'tonit' xuất hiện 8 lần
# Từ 'librari' xuất hiện 8 lần
# Từ 'slave' xuất hiện 8 lần
# Từ 'omg' xuất hiện 8 lần
# Từ 'gettin' xuất hiện 8 lần
# Từ 'tampa' xuất hiện 8 lần
# Từ 'murder' xuất hiện 8 lần
# Từ 'yr' xuất hiện 8 lần
# Từ 'mo' xuất hiện 8 lần
# Từ 'medic' xuất hiện 8 lần
# Từ 'fall' xuất hiện 8 lần
# Từ 'honey' xuất hiện 8 lần
# Từ 'vl' xuất hiện 8 lần
# Từ 'marri' xuất hiện 8 lần
# Từ 'write' xuất hiện 8 lần
# Từ 'cover' xuất hiện 8 lần
# Từ 'congrat' xuất hiện 8 lần
# Từ 'excel' xuất hiện 8 lần
# Từ 'john' xuất hiện 8 lần
# Từ 'father' xuất hiện 8 lần
# Từ 'hw' xuất hiện 8 lần
# Từ 'list' xuất hiện 8 lần
# Từ 'wednesday' xuất hiện 8 lần
# Từ 'thinkin' xuất hiện 8 lần
# Từ 'mon' xuất hiện 8 lần
# Từ 'manag' xuất hiện 8 lần
# Từ 'bugi' xuất hiện 7 lần
# Từ 'la' xuất hiện 7 lần
# Từ 'cine' xuất hiện 7 lần
# Từ 'bless' xuất hiện 7 lần
# Từ 'suck' xuất hiện 7 lần
# Từ '2nd' xuất hiện 7 lần
# Từ 'weak' xuất hiện 7 lần
# Từ 'wun' xuất hiện 7 lần
# Từ 'pleasur' xuất hiện 7 lần
# Từ 'troubl' xuất hiện 7 lần
# Từ 'men' xuất hiện 7 lần
# Từ 'cuz' xuất hiện 7 lần
# Từ 'umma' xuất hiện 7 lần
# Từ 'eatin' xuất hiện 7 lần
# Từ 'yiju' xuất hiện 7 lần
# Từ 'shirt' xuất hiện 7 lần
# Từ 'joy' xuất hiện 7 lần
# Từ 'becom' xuất hiện 7 lần
# Từ 'hop' xuất hiện 7 lần
# Từ 'discuss' xuất hiện 7 lần
# Từ 'lift' xuất hiện 7 lần
# Từ 'howev' xuất hiện 7 lần
# Từ 'settl' xuất hiện 7 lần
# Từ 'buck' xuất hiện 7 lần
# Từ 'past' xuất hiện 7 lần
# Từ 'file' xuất hiện 7 lần
# Từ 'system' xuất hiện 7 lần
# Từ 'street' xuất hiện 7 lần
# Từ 'batteri' xuất hiện 7 lần
# Từ 'sign' xuất hiện 7 lần
# Từ 'goodnight' xuất hiện 7 lần
# Từ 'dnt' xuất hiện 7 lần
# Từ 'deep' xuất hiện 7 lần
# Từ 'ship' xuất hiện 7 lần
# Từ 'lover' xuất hiện 7 lần
# Từ 'sens' xuất hiện 7 lần
# Từ 'coffe' xuất hiện 7 lần
# Từ 'definit' xuất hiện 7 lần
# Từ 'kb' xuất hiện 7 lần
# Từ 'power' xuất hiện 7 lần
# Từ 'yoga' xuất hiện 7 lần
# Từ 'merri' xuất hiện 7 lần
# Từ 'practic' xuất hiện 7 lần
# Từ 'fault' xuất hiện 7 lần
# Từ 'insur' xuất hiện 7 lần
# Từ 'cold' xuất hiện 7 lần
# Từ 'sigh' xuất hiện 7 lần
# Từ 'pictur' xuất hiện 7 lần
# Từ 'dollar' xuất hiện 7 lần
# Từ 'style' xuất hiện 7 lần
# Từ 'tat' xuất hiện 7 lần
# Từ 'rather' xuất hiện 7 lần
# Từ 'omw' xuất hiện 7 lần
# Từ 'hurri' xuất hiện 7 lần
# Từ 'gee' xuất hiện 7 lần
# Từ 'bare' xuất hiện 7 lần
# Từ 'izzit' xuất hiện 7 lần
# Từ 'ar' xuất hiện 7 lần
# Từ 'indian' xuất hiện 7 lần
# Từ 'imma' xuất hiện 7 lần
# Từ 'shuhui' xuất hiện 7 lần
# Từ 'weather' xuất hiện 7 lần
# Từ 'pop' xuất hiện 7 lần
# Từ 'funni' xuất hiện 7 lần
# Từ 'fetch' xuất hiện 7 lần
# Từ 'awak' xuất hiện 7 lần
# Từ 'torch' xuất hiện 7 lần
# Từ 'bold' xuất hiện 7 lần
# Từ 'holla' xuất hiện 7 lần
# Từ 'top' xuất hiện 7 lần
# Từ 'yest' xuất hiện 7 lần
# Từ 'b4' xuất hiện 7 lần
# Từ 'model' xuất hiện 7 lần
# Từ 'matter' xuất hiện 7 lần
# Từ 'hai' xuất hiện 7 lần
# Từ 'otherwis' xuất hiện 7 lần
# Từ 'greet' xuất hiện 7 lần
# Từ 'piss' xuất hiện 7 lần
# Từ 'nxt' xuất hiện 7 lần
# Từ 'nyt' xuất hiện 7 lần
# Từ 'regard' xuất hiện 7 lần
# Từ 'black' xuất hiện 7 lần
# Từ 'hot' xuất hiện 7 lần
# Từ 'doc' xuất hiện 7 lần
# Từ 'news' xuất hiện 7 lần
# Từ 'cell' xuất hiện 7 lần
# Từ 'mode' xuất hiện 7 lần
# Từ 'dog' xuất hiện 7 lần
# Từ 'shd' xuất hiện 7 lần
# Từ 'share' xuất hiện 7 lần
# Từ 'total' xuất hiện 7 lần
# Từ 'lmao' xuất hiện 7 lần
# Từ 'wed' xuất hiện 7 lần
# Từ 'south' xuất hiện 7 lần
# Từ 'ice' xuất hiện 7 lần
# Từ 'instead' xuất hiện 7 lần
# Từ 'buzz' xuất hiện 7 lần
# Từ 'insid' xuất hiện 7 lần
# Từ 'red' xuất hiện 7 lần
# Từ 'mid' xuất hiện 7 lần
# Từ 'role' xuất hiện 7 lần
# Từ 'vikki' xuất hiện 7 lần
# Từ 'sofa' xuất hiện 7 lần
# Từ 'hug' xuất hiện 7 lần
# Từ 'request' xuất hiện 6 lần
# Từ 'cri' xuất hiện 6 lần
# Từ 'naughti' xuất hiện 6 lần
# Từ 'serious' xuất hiện 6 lần
# Từ 'stock' xuất hiện 6 lần
# Từ 'tea' xuất hiện 6 lần
# Từ 'learn' xuất hiện 6 lần
# Từ 'ahead' xuất hiện 6 lần
# Từ 'inch' xuất hiện 6 lần
# Từ 'tyler' xuất hiện 6 lần
# Từ 'fyi' xuất hiện 6 lần
# Từ 'realiz' xuất hiện 6 lần
# Từ 'kill' xuất hiện 6 lần
# Từ 'coin' xuất hiện 6 lần
# Từ 'includ' xuất hiện 6 lần
# Từ 'loan' xuất hiện 6 lần
# Từ 'consid' xuất hiện 6 lần
# Từ 'lie' xuất hiện 6 lần
# Từ 'boss' xuất hiện 6 lần
# Từ 'askd' xuất hiện 6 lần
# Từ 'apart' xuất hiện 6 lần
# Từ 'directli' xuất hiện 6 lần
# Từ 'delet' xuất hiện 6 lần
# Từ 'fanci' xuất hiện 6 lần
# Từ 'hell' xuất hiện 6 lần
# Từ 'toward' xuất hiện 6 lần
# Từ 'success' xuất hiện 6 lần
# Từ 'kalli' xuất hiện 6 lần
# Từ 'dint' xuất hiện 6 lần
# Từ 'throw' xuất hiện 6 lần
# Từ 'ge' xuất hiện 6 lần
# Từ 'updat' xuất hiện 6 lần
# Từ 'rose' xuất hiện 6 lần
# Từ 'hang' xuất hiện 6 lần
# Từ 'key' xuất hiện 6 lần
# Từ 'cake' xuất hiện 6 lần
# Từ 'track' xuất hiện 6 lần
# Từ 'report' xuất hiện 6 lần
# Từ 'wiv' xuất hiện 6 lần
# Từ 'num' xuất hiện 6 lần
# Từ 'ish' xuất hiện 6 lần
# Từ 'air' xuất hiện 6 lần
# Từ 'cuddl' xuất hiện 6 lần
# Từ 'guid' xuất hiện 6 lần
# Từ 'relax' xuất hiện 6 lần
# Từ 'pilat' xuất hiện 6 lần
# Từ 'current' xuất hiện 6 lần
# Từ 'via' xuất hiện 6 lần
# Từ 'respond' xuất hiện 6 lần
# Từ 'askin' xuất hiện 6 lần
# Từ 'tough' xuất hiện 6 lần
# Từ 'group' xuất hiện 6 lần
# Từ 'transfer' xuất hiện 6 lần
# Từ 'result' xuất hiện 6 lần
# Từ 'isnt' xuất hiện 6 lần
# Từ 'thru' xuất hiện 6 lần
# Từ '8th' xuất hiện 6 lần
# Từ 'fb' xuất hiện 6 lần
# Từ 'credit' xuất hiện 6 lần
# Từ 'opinion' xuất hiện 6 lần
# Từ 'reali' xuất hiện 6 lần
# Từ 'campu' xuất hiện 6 lần
# Từ 'singl' xuất hiện 6 lần
# Từ 'lead' xuất hiện 6 lần
# Từ 'finger' xuất hiện 6 lần
# Từ 'cheap' xuất hiện 6 lần
# Từ 'aiyo' xuất hiện 6 lần
# Từ 'colour' xuất hiện 6 lần
# Từ 'paid' xuất hiện 6 lần
# Từ 'prepar' xuất hiện 6 lần
# Từ 'gap' xuất hiện 6 lần
# Từ 'student' xuất hiện 6 lần
# Từ 'yay' xuất hiện 6 lần
# Từ 'damn' xuất hiện 6 lần
# Từ 'space' xuất hiện 6 lần
# Từ 'skype' xuất hiện 6 lần
# Từ 'mother' xuất hiện 6 lần
# Từ 'midnight' xuất hiện 6 lần
# Từ 'sup' xuất hiện 6 lần
# Từ 'attend' xuất hiện 6 lần
# Từ 'ate' xuất hiện 6 lần
# Từ 'expens' xuất hiện 6 lần
# Từ 'j' xuất hiện 6 lần
# Từ 'content' xuất hiện 6 lần
# Từ 'loverboy' xuất hiện 6 lần
# Từ 'seriou' xuất hiện 6 lần
# Từ 'travel' xuất hiện 6 lần
# Từ 'aiyah' xuất hiện 6 lần
# Từ 'cancel' xuất hiện 6 lần
# Từ 'station' xuất hiện 6 lần
# Từ 'arm' xuất hiện 6 lần
# Từ 'luck' xuất hiện 6 lần
# Từ 'yahoo' xuất hiện 6 lần
# Từ 'bird' xuất hiện 6 lần
# Từ 'natur' xuất hiện 6 lần
# Từ 'vomit' xuất hiện 6 lần
# Từ 'except' xuất hiện 6 lần
# Từ 'internet' xuất hiện 6 lần
# Từ 'prefer' xuất hiện 6 lần
# Từ 'freak' xuất hiện 6 lần
# Từ 'hook' xuất hiện 6 lần
# Từ 'slowli' xuất hiện 6 lần
# Từ 'hate' xuất hiện 6 lần
# Từ 'ahmad' xuất hiện 6 lần
# Từ 'armand' xuất hiện 6 lần
# Từ 'empti' xuất hiện 6 lần
# Từ 'tear' xuất hiện 6 lần
# Từ 'wors' xuất hiện 6 lần
# Từ 'issu' xuất hiện 6 lần
# Từ 'pussi' xuất hiện 6 lần
# Từ 'cute' xuất hiện 6 lần
# Từ 'budget' xuất hiện 6 lần
# Từ 'plenti' xuất hiện 6 lần
# Từ 'behind' xuất hiện 6 lần
# Từ 'cancer' xuất hiện 6 lần
# Từ 'tick' xuất hiện 6 lần
# Từ 'med' xuất hiện 6 lần
# Từ 'press' xuất hiện 5 lần
# Từ 'spell' xuất hiện 5 lần
# Từ 'thatåõ' xuất hiện 5 lần
# Từ 'convinc' xuất hiện 5 lần
# Từ 'egg' xuất hiện 5 lần
# Từ 'ride' xuất hiện 5 lần
# Từ 'embarass' xuất hiện 5 lần
# Từ 'doubl' xuất hiện 5 lần
# Từ 'network' xuất hiện 5 lần
# Từ '530' xuất hiện 5 lần
# Từ 'appoint' xuất hiện 5 lần
# Từ 'ave' xuất hiện 5 lần
# Từ 'boston' xuất hiện 5 lần
# Từ 'scare' xuất hiện 5 lần
# Từ 'tt' xuất hiện 5 lần
# Từ 'enter' xuất hiện 5 lần
# Từ 'predict' xuất hiện 5 lần
# Từ 'begin' xuất hiện 5 lần
# Từ 'interview' xuất hiện 5 lần
# Từ 'avoid' xuất hiện 5 lần
# Từ 'experi' xuất hiện 5 lần
# Từ 'suggest' xuất hiện 5 lần
# Từ 'match' xuất hiện 5 lần
# Từ 'draw' xuất hiện 5 lần
# Từ 'print' xuất hiện 5 lần
# Từ 'kick' xuất hiện 5 lần
# Từ 'websit' xuất hiện 5 lần
# Từ 'cal' xuất hiện 5 lần
# Từ 'bf' xuất hiện 5 lần
# Từ 'anybodi' xuất hiện 5 lần
# Từ 'accept' xuất hiện 5 lần
# Từ 'advanc' xuất hiện 5 lần
# Từ 'geeee' xuất hiện 5 lần
# Từ 'will' xuất hiện 5 lần
# Từ 'bar' xuất hiện 5 lần
# Từ 'bodi' xuất hiện 5 lần
# Từ 'lick' xuất hiện 5 lần
# Từ 'intro' xuất hiện 5 lần
# Từ 'none' xuất hiện 5 lần
# Từ 'darl' xuất hiện 5 lần
# Từ 'yan' xuất hiện 5 lần
# Từ 'jiu' xuất hiện 5 lần
# Từ 'hostel' xuất hiện 5 lần
# Từ '50' xuất hiện 5 lần
# Từ 'arrang' xuất hiện 5 lần
# Từ 'acc' xuất hiện 5 lần
# Từ 'donåõt' xuất hiện 5 lần
# Từ 'link' xuất hiện 5 lần
# Từ 'ttyl' xuất hiện 5 lần
# Từ 'decis' xuất hiện 5 lần
# Từ 'bye' xuất hiện 5 lần
# Từ 'remov' xuất hiện 5 lần
# Từ 'flat' xuất hiện 5 lần
# Từ 'sec' xuất hiện 5 lần
# Từ 'qualiti' xuất hiện 5 lần
# Từ 'jst' xuất hiện 5 lần
# Từ 'l8r' xuất hiện 5 lần
# Từ 'self' xuất hiện 5 lần
# Từ 'hotel' xuất hiện 5 lần
# Từ 'english' xuất hiện 5 lần
# Từ 'btw' xuất hiện 5 lần
# Từ 'blood' xuất hiện 5 lần
# Từ '2mrw' xuất hiện 5 lần
# Từ 'marriag' xuất hiện 5 lần
# Từ 'jazz' xuất hiện 5 lần
# Từ 'yogasana' xuất hiện 5 lần
# Từ 'exhaust' xuất hiện 5 lần
# Từ 'somethin' xuất hiện 5 lần
# Từ 'aunti' xuất hiện 5 lần
# Từ 'pound' xuất hiện 5 lần
# Từ 'gentl' xuất hiện 5 lần
# Từ 'earth' xuất hiện 5 lần
# Từ 'belli' xuất hiện 5 lần
# Từ 'build' xuất hiện 5 lần
# Từ 'law' xuất hiện 5 lần
# Từ 'box' xuất hiện 5 lần
# Từ 'aftr' xuất hiện 5 lần
# Từ 'dey' xuất hiện 5 lần
# Từ 'stress' xuất hiện 5 lần
# Từ 'assum' xuất hiện 5 lần
# Từ 'clock' xuất hiện 5 lần
# Từ 'sing' xuất hiện 5 lần
# Từ 'within' xuất hiện 5 lần
# Từ 'piec' xuất hiện 5 lần
# Từ 'sura' xuất hiện 5 lần
# Từ 'derek' xuất hiện 5 lần
# Từ 'white' xuất hiện 5 lần
# Từ 'ym' xuất hiện 5 lần
# Từ 'diet' xuất hiện 5 lần
# Từ 'wherev' xuất hiện 5 lần
# Từ 'recent' xuất hiện 5 lần
# Từ 'heavi' xuất hiện 5 lần
# Từ 'bowl' xuất hiện 5 lần
# Từ 'site' xuất hiện 5 lần
# Từ 'yun' xuất hiện 5 lần
# Từ 'kerala' xuất hiện 5 lần
# Từ 'regret' xuất hiện 5 lần
# Từ 'asleep' xuất hiện 5 lần
# Từ 'lectur' xuất hiện 5 lần
# Từ 'rais' xuất hiện 5 lần
# Từ 'fool' xuất hiện 5 lần
# Từ 'april' xuất hiện 5 lần
# Từ 'bitch' xuất hiện 5 lần
# Từ 'uni' xuất hiện 5 lần
# Từ 'italian' xuất hiện 5 lần
# Từ 'horribl' xuất hiện 5 lần
# Từ 'nw' xuất hiện 5 lần
# Từ 'moan' xuất hiện 5 lần
# Từ 'app' xuất hiện 5 lần
# Từ 'chines' xuất hiện 5 lần
# Từ 'rang' xuất hiện 5 lần
# Từ 'cbe' xuất hiện 5 lần
# Từ 'boo' xuất hiện 5 lần
# Từ 'irrit' xuất hiện 5 lần
# Từ 'secret' xuất hiện 5 lần
# Từ 'broke' xuất hiện 5 lần
# Từ 'alrit' xuất hiện 5 lần
# Từ 'area' xuất hiện 5 lần
# Từ 'rush' xuất hiện 5 lần
# Từ 'extra' xuất hiện 5 lần
# Từ 'pple' xuất hiện 5 lần
# Từ 'cafe' xuất hiện 5 lần
# Từ 'vote' xuất hiện 5 lần
# Từ 'rem' xuất hiện 5 lần
# Từ 'everybodi' xuất hiện 5 lần
# Từ 'fli' xuất hiện 5 lần
# Từ 'googl' xuất hiện 5 lần
# Từ 'aint' xuất hiện 5 lần
# Từ 'sale' xuất hiện 5 lần
# Từ 'blank' xuất hiện 5 lần
# Từ '2nite' xuất hiện 5 lần
# Từ 'ador' xuất hiện 5 lần
# Từ 'sight' xuất hiện 5 lần
# Từ 'remain' xuất hiện 5 lần
# Từ 'rd' xuất hiện 5 lần
# Từ 'social' xuất hiện 5 lần
# Từ 'bun' xuất hiện 5 lần
# Từ 'lookin' xuất hiện 5 lần
# Từ 'thnk' xuất hiện 5 lần
# Từ 'cook' xuất hiện 5 lần
# Từ 'nvm' xuất hiện 5 lần
# Từ 'relat' xuất hiện 5 lần
# Từ 'obvious' xuất hiện 5 lần
# Từ 'affair' xuất hiện 5 lần
# Từ 'art' xuất hiện 5 lần
# Từ 'process' xuất hiện 5 lần
# Từ 'hill' xuất hiện 5 lần
# Từ 'mood' xuất hiện 5 lần
# Từ 'whether' xuất hiện 5 lần
# Từ 'possess' xuất hiện 5 lần
# Từ 'dress' xuất hiện 5 lần
# Từ 'random' xuất hiện 5 lần
# Từ 'ru' xuất hiện 5 lần
# Từ 'kano' xuất hiện 5 lần
# Từ 'deliv' xuất hiện 5 lần
# Từ 'amount' xuất hiện 5 lần
# Từ 'advic' xuất hiện 5 lần
# Từ 'valu' xuất hiện 5 lần
# Từ 'ignor' xuất hiện 5 lần
# Từ 'cinema' xuất hiện 5 lần
# Từ 'lik' xuất hiện 5 lần
# Từ 'etc' xuất hiện 5 lần
# Từ 'step' xuất hiện 5 lần
# Từ 'common' xuất hiện 5 lần
# Từ 'oni' xuất hiện 4 lần
# Từ 'callertun' xuất hiện 4 lần
# Từ 'sooner' xuất hiện 4 lần
# Từ 'pack' xuất hiện 4 lần
# Từ 'kept' xuất hiện 4 lần
# Từ 'gram' xuất hiện 4 lần
# Từ 'crash' xuất hiện 4 lần
# Từ 'seri' xuất hiện 4 lần
# Từ 'wah' xuất hiện 4 lần
# Từ 'machan' xuất hiện 4 lần
# Từ 'respect' xuất hiện 4 lần
# Từ 'sheet' xuất hiện 4 lần
# Từ 'legal' xuất hiện 4 lần
# Từ 'nyc' xuất hiện 4 lần
# Từ 'research' xuất hiện 4 lần
# Từ '12' xuất hiện 4 lần
# Từ 'yetund' xuất hiện 4 lần
# Từ 'swt' xuất hiện 4 lần
# Từ 'qatar' xuất hiện 4 lần
# Từ 'window' xuất hiện 4 lần
# Từ 'modul' xuất hiện 4 lần
# Từ 'bloodi' xuất hiện 4 lần
# Từ 'worth' xuất hiện 4 lần
# Từ 'spoke' xuất hiện 4 lần
# Từ 'mummi' xuất hiện 4 lần
# Từ '11' xuất hiện 4 lần
# Từ 'straight' xuất hiện 4 lần
# Từ 'shoot' xuất hiện 4 lần
# Từ 'sen' xuất hiện 4 lần
# Từ 'select' xuất hiện 4 lần
# Từ 'regist' xuất hiện 4 lần
# Từ 'teacher' xuất hiện 4 lần
# Từ 'closer' xuất hiện 4 lần
# Từ 'argument' xuất hiện 4 lần
# Từ 'mmm' xuất hiện 4 lần
# Từ 'sunni' xuất hiện 4 lần
# Từ 'accident' xuất hiện 4 lần
# Từ 'high' xuất hiện 4 lần
# Từ 'def' xuất hiện 4 lần
# Từ 'meal' xuất hiện 4 lần
# Từ '2day' xuất hiện 4 lần
# Từ 'pongal' xuất hiện 4 lần
# Từ 'cud' xuất hiện 4 lần
# Từ 'ppl' xuất hiện 4 lần
# Từ 'waitin' xuất hiện 4 lần
# Từ 'record' xuất hiện 4 lần
# Từ 'surf' xuất hiện 4 lần
# Từ 'wtf' xuất hiện 4 lần
# Từ 'breath' xuất hiện 4 lần
# Từ 'allah' xuất hiện 4 lần
# Từ 'cream' xuất hiện 4 lần
# Từ 'burn' xuất hiện 4 lần
# Từ 'express' xuất hiện 4 lần
# Từ 'esplanad' xuất hiện 4 lần
# Từ 'urgent' xuất hiện 4 lần
# Từ 'fifteen' xuất hiện 4 lần
# Từ 'gorgeou' xuất hiện 4 lần
# Từ 'concentr' xuất hiện 4 lần
# Từ 'ure' xuất hiện 4 lần
# Từ 'intellig' xuất hiện 4 lần
# Từ 'woman' xuất hiện 4 lần
# Từ 'posit' xuất hiện 4 lần
# Từ 'dri' xuất hiện 4 lần
# Từ 'charact' xuất hiện 4 lần
# Từ 'bday' xuất hiện 4 lần
# Từ 'malaria' xuất hiện 4 lần
# Từ 'passion' xuất hiện 4 lần
# Từ 'develop' xuất hiện 4 lần
# Từ 'three' xuất hiện 4 lần
# Từ 'gener' xuất hiện 4 lần
# Từ 'lab' xuất hiện 4 lần
# Từ 'bite' xuất hiện 4 lần
# Từ 'danc' xuất hiện 4 lần
# Từ 'grand' xuất hiện 4 lần
# Từ 'pie' xuất hiện 4 lần
# Từ 'suit' xuất hiện 4 lần
# Từ 'often' xuất hiện 4 lần
# Từ 'futur' xuất hiện 4 lần
# Từ 'leona' xuất hiện 4 lần
# Từ 'bud' xuất hiện 4 lần
# Từ 'effect' xuất hiện 4 lần
# Từ 'thursday' xuất hiện 4 lần
# Từ 'taken' xuất hiện 4 lần
# Từ 'bet' xuất hiện 4 lần
# Từ 'hella' xuất hiện 4 lần
# Từ 'evng' xuất hiện 4 lần
# Từ 'peac' xuất hiện 4 lần
# Từ 'explain' xuất hiện 4 lần
# Từ 'king' xuất hiện 4 lần
# Từ 'map' xuất hiện 4 lần
# Từ 'an' xuất hiện 4 lần
# Từ 'weird' xuất hiện 4 lần
# Từ 'drivin' xuất hiện 4 lần
# Từ 'anytim' xuất hiện 4 lần
# Từ 'exactli' xuất hiện 4 lần
# Từ 'twice' xuất hiện 4 lần
# Từ 'realis' xuất hiện 4 lần
# Từ 'spoken' xuất hiện 4 lần
# Từ 'confus' xuất hiện 4 lần
# Từ 'act' xuất hiện 4 lần
# Từ 'meetin' xuất hiện 4 lần
# Từ 'appar' xuất hiện 4 lần
# Từ 'row' xuất hiện 4 lần
# Từ 'appt' xuất hiện 4 lần
# Từ '3d' xuất hiện 4 lần
# Từ 'ai' xuất hiện 4 lần
# Từ 'hunni' xuất hiện 4 lần
# Từ 'ach' xuất hiện 4 lần
# Từ 'green' xuất hiện 4 lần
# Từ 'meanwhil' xuất hiện 4 lần
# Từ 'impress' xuất hiện 4 lần
# Từ 'version' xuất hiện 4 lần
# Từ 'spk' xuất hiện 4 lần
# Từ 'wall' xuất hiện 4 lần
# Từ 'fail' xuất hiện 4 lần
# Từ 'due' xuất hiện 4 lần
# Từ 'store' xuất hiện 4 lần
# Từ 'pig' xuất hiện 4 lần
# Từ 'iam' xuất hiện 4 lần
# Từ 'term' xuất hiện 4 lần
# Từ 'fever' xuất hiện 4 lần
# Từ 'score' xuất hiện 4 lần
# Từ 'appli' xuất hiện 4 lần
# Từ 'chicken' xuất hiện 4 lần
# Từ 'salari' xuất hiện 4 lần
# Từ 'sore' xuất hiện 4 lần
# Từ 'jesu' xuất hiện 4 lần
# Từ 'aunt' xuất hiện 4 lần
# Từ 'throat' xuất hiện 4 lần
# Từ 'flirt' xuất hiện 4 lần
# Từ 'technic' xuất hiện 4 lần
# Từ 'convey' xuất hiện 4 lần
# Từ 'math' xuất hiện 4 lần
# Từ 'aiyar' xuất hiện 4 lần
# Từ 'howz' xuất hiện 4 lần
# Từ 'shame' xuất hiện 4 lần
# Từ 'refer' xuất hiện 4 lần
# Từ 'strong' xuất hiện 4 lần
# Từ 'mite' xuất hiện 4 lần
# Từ 'easier' xuất hiện 4 lần
# Từ 'hun' xuất hiện 4 lần
# Từ 'servic' xuất hiện 4 lần
# Từ 'exact' xuất hiện 4 lần
# Từ 'februari' xuất hiện 4 lần
# Từ '6hr' xuất hiện 4 lần
# Từ 'blackberri' xuất hiện 4 lần
# Từ 'moji' xuất hiện 4 lần
# Từ 'welcom' xuất hiện 4 lần
# Từ 'reserv' xuất hiện 4 lần
# Từ 'moral' xuất hiện 4 lần
# Từ 'tuition' xuất hiện 4 lần
# Từ 'moon' xuất hiện 4 lần
# Từ 'aiya' xuất hiện 4 lần
# Từ 'bright' xuất hiện 4 lần
# Từ 'tablet' xuất hiện 4 lần
# Từ 'sha' xuất hiện 4 lần
# Từ 'centr' xuất hiện 4 lần
# Từ 'forum' xuất hiện 4 lần
# Từ 'ron' xuất hiện 4 lần
# Từ 'airport' xuất hiện 4 lần
# Từ 'bishan' xuất hiện 4 lần
# Từ '20' xuất hiện 4 lần
# Từ 'idk' xuất hiện 4 lần
# Từ 'chase' xuất hiện 4 lần
# Từ 'comedi' xuất hiện 4 lần
# Từ 'ran' xuất hiện 4 lần
# Từ 'queen' xuất hiện 4 lần
# Từ 'bin' xuất hiện 4 lần
# Từ 'bedroom' xuất hiện 4 lần
# Từ 'follow' xuất hiện 4 lần
# Từ 'takin' xuất hiện 4 lần
# Từ 'beer' xuất hiện 4 lần
# Từ 'jess' xuất hiện 4 lần
# Từ 'replac' xuất hiện 4 lần
# Từ 'team' xuất hiện 4 lần
# Từ 'push' xuất hiện 4 lần
# Từ 'pull' xuất hiện 4 lần
# Từ 'master' xuất hiện 4 lần
# Từ 'season' xuất hiện 4 lần
# Từ 'sim' xuất hiện 4 lần
# Từ 'unlimit' xuất hiện 4 lần
# Từ 'se' xuất hiện 4 lần
# Từ 'wud' xuất hiện 4 lần
# Từ 'cat' xuất hiện 4 lần
# Từ 'hip' xuất hiện 4 lần
# Từ 'nake' xuất hiện 4 lần
# Từ 'rule' xuất hiện 4 lần
# Từ 'respons' xuất hiện 4 lần
# Từ 'theatr' xuất hiện 4 lần
# Từ 'gari' xuất hiện 4 lần
# Từ 'infern' xuất hiện 4 lần
# Từ 'orang' xuất hiện 4 lần
# Từ 'feet' xuất hiện 4 lần
# Từ 'mad' xuất hiện 4 lần
# Từ 'password' xuất hiện 4 lần
# Từ 'requir' xuất hiện 4 lần
# Từ 'colleagu' xuất hiện 4 lần
# Từ 'leg' xuất hiện 4 lần
# Từ 'pix' xuất hiện 4 lần
# Từ 'notic' xuất hiện 4 lần
# Từ 'gn' xuất hiện 4 lần
# Từ 'sugar' xuất hiện 4 lần
# Từ 'limit' xuất hiện 4 lần
# Từ 'roger' xuất hiện 4 lần
# Từ 'solv' xuất hiện 4 lần
# Từ 'polic' xuất hiện 4 lần
# Từ 'rakhesh' xuất hiện 4 lần
# Từ 'er' xuất hiện 4 lần
# Từ 'ruin' xuất hiện 4 lần
# Từ 'bro' xuất hiện 4 lần
# Từ 'januari' xuất hiện 4 lần
# Từ 'dare' xuất hiện 4 lần
# Từ 'pin' xuất hiện 4 lần
# Từ 'teeth' xuất hiện 4 lần
# Từ 'note' xuất hiện 4 lần
# Từ 'bought' xuất hiện 4 lần
# Từ 'tm' xuất hiện 4 lần
# Từ 'abi' xuất hiện 4 lần
# Từ 'grl' xuất hiện 4 lần
# Từ 'asap' xuất hiện 4 lần
# Từ 'allow' xuất hiện 4 lần
# Từ 'outta' xuất hiện 4 lần
# Từ 'captain' xuất hiện 4 lần
# Từ 'mumtaz' xuất hiện 4 lần
# Từ 'taunton' xuất hiện 4 lần
# Từ 'caller' xuất hiện 3 lần
# Từ 'wet' xuất hiện 3 lần
# Từ 'str' xuất hiện 3 lần
# Từ 'forc' xuất hiện 3 lần
# Từ 'slice' xuất hiện 3 lần
# Từ 'child' xuất hiện 3 lần
# Từ 'caught' xuất hiện 3 lần
# Từ 'xuhui' xuất hiện 3 lần
# Từ 'yummi' xuất hiện 3 lần
# Từ 'fair' xuất hiện 3 lần
# Từ 'url' xuất hiện 3 lần
# Từ 'dresser' xuất hiện 3 lần
# Từ 'rpli' xuất hiện 3 lần
# Từ 'plane' xuất hiện 3 lần
# Từ 'perform' xuất hiện 3 lần
# Từ 'gentleman' xuất hiện 3 lần
# Từ 'digniti' xuất hiện 3 lần
# Từ 'earn' xuất hiện 3 lần
# Từ 'urgnt' xuất hiện 3 lần
# Từ 'nitro' xuất hiện 3 lần
# Từ 'becoz' xuất hiện 3 lần
# Từ 'lido' xuất hiện 3 lần
# Từ 'hol' xuất hiện 3 lần
# Từ 'ham' xuất hiện 3 lần
# Từ 'vava' xuất hiện 3 lần
# Từ 'loud' xuất hiện 3 lần
# Từ 'wa' xuất hiện 3 lần
# Từ 'anythin' xuất hiện 3 lần
# Từ 'apologis' xuất hiện 3 lần
# Từ 'activ' xuất hiện 3 lần
# Từ 'lovabl' xuất hiện 3 lần
# Từ 'occupi' xuất hiện 3 lần
# Từ 'birla' xuất hiện 3 lần
# Từ 'soft' xuất hiện 3 lần
# Từ 'flow' xuất hiện 3 lần
# Từ 'floor' xuất hiện 3 lần
# Từ 'excit' xuất hiện 3 lần
# Từ 'escap' xuất hiện 3 lần
# Từ 'mall' xuất hiện 3 lần
# Từ 'radio' xuất hiện 3 lần
# Từ 'balanc' xuất hiện 3 lần
# Từ 'transact' xuất hiện 3 lần
# Từ 'atm' xuất hiện 3 lần
# Từ 'instal' xuất hiện 3 lần
# Từ 'repair' xuất hiện 3 lần
# Từ 'po' xuất hiện 3 lần
# Từ 'argu' xuất hiện 3 lần
# Từ 'tomarrow' xuất hiện 3 lần
# Từ 'avent' xuất hiện 3 lần
# Từ 'slipper' xuất hiện 3 lần
# Từ 'bat' xuất hiện 3 lần
# Từ 'inning' xuất hiện 3 lần
# Từ 'dearli' xuất hiện 3 lần
# Từ 'flash' xuất hiện 3 lần
# Từ 'jealou' xuất hiện 3 lần
# Từ 'ray' xuất hiện 3 lần
# Từ 'gautham' xuất hiện 3 lần
# Từ 'shock' xuất hiện 3 lần
# Từ 'scari' xuất hiện 3 lần
# Từ 'jo' xuất hiện 3 lần
# Từ 'garag' xuất hiện 3 lần
# Từ 'enemi' xuất hiện 3 lần
# Từ 'afraid' xuất hiện 3 lần
# Từ 'gona' xuất hiện 3 lần
# Từ 'immedi' xuất hiện 3 lần
# Từ 'supervisor' xuất hiện 3 lần
# Từ 'favourit' xuất hiện 3 lần
# Từ 'hide' xuất hiện 3 lần
# Từ 'stranger' xuất hiện 3 lần
# Từ 'alcohol' xuất hiện 3 lần
# Từ 'spoil' xuất hiện 3 lần
# Từ 'recognis' xuất hiện 3 lần
# Từ 'ptbo' xuất hiện 3 lần
# Từ 'shut' xuất hiện 3 lần
# Từ 'calcul' xuất hiện 3 lần
# Từ 'period' xuất hiện 3 lần
# Từ 'quickli' xuất hiện 3 lần
# Từ 'chechi' xuất hiện 3 lần
# Từ 'tree' xuất hiện 3 lần
# Từ 'blah' xuất hiện 3 lần
# Từ 'wnt' xuất hiện 3 lần
# Từ 'vri' xuất hiện 3 lần
# Từ 'iouri' xuất hiện 3 lần
# Từ 'oic' xuất hiện 3 lần
# Từ 'oreo' xuất hiện 3 lần
# Từ 'ear' xuất hiện 3 lần
# Từ 'railway' xuất hiện 3 lần
# Từ 'doggi' xuất hiện 3 lần
# Từ 'fave' xuất hiện 3 lần
# Từ 'rate' xuất hiện 3 lần
# Từ '9ja' xuất hiện 3 lần
# Từ 'tast' xuất hiện 3 lần
# Từ 'fish' xuất hiện 3 lần
# Từ 'villag' xuất hiện 3 lần
# Từ 'fee' xuất hiện 3 lần
# Từ 'latest' xuất hiện 3 lần
# Từ 'prabha' xuất hiện 3 lần
# Từ 'children' xuất hiện 3 lần
# Từ 'behav' xuất hiện 3 lần
# Từ 'elsewher' xuất hiện 3 lần
# Từ 'tirupur' xuất hiện 3 lần
# Từ 'quot' xuất hiện 3 lần
# Từ 'confid' xuất hiện 3 lần
# Từ 'bloke' xuất hiện 3 lần
# Từ 'own' xuất hiện 3 lần
# Từ 'cup' xuất hiện 3 lần
# Từ 'milk' xuất hiện 3 lần
# Từ 'magic' xuất hiện 3 lần
# Từ 'loos' xuất hiện 3 lần
# Từ 'essenti' xuất hiện 3 lần
# Từ 'american' xuất hiện 3 lần
# Từ 'callin' xuất hiện 3 lần
# Từ 'snake' xuất hiện 3 lần
# Từ 'headach' xuất hiện 3 lần
# Từ 'swim' xuất hiện 3 lần
# Từ 'offici' xuất hiện 3 lần
# Từ 'market' xuất hiện 3 lần
# Từ 'seven' xuất hiện 3 lần
# Từ 'thanksgiv' xuất hiện 3 lần
# Từ 'lay' xuất hiện 3 lần
# Từ 'lone' xuất hiện 3 lần
# Từ 'farm' xuất hiện 3 lần
# Từ 'height' xuất hiện 3 lần
# Từ 'wer' xuất hiện 3 lần
# Từ 'menu' xuất hiện 3 lần
# Từ 'spring' xuất hiện 3 lần
# Từ 'faster' xuất hiện 3 lần
# Từ 'attach' xuất hiện 3 lần
# Từ 'shout' xuất hiện 3 lần
# Từ 'shorter' xuất hiện 3 lần
# Từ 'gim' xuất hiện 3 lần
# Từ 'lip' xuất hiện 3 lần
# Từ 'spare' xuất hiện 3 lần
# Từ 'ti' xuất hiện 3 lần
# Từ 'anywher' xuất hiện 3 lần
# Từ 'beg' xuất hiện 3 lần
# Từ 'diff' xuất hiện 3 lần
# Từ 'bein' xuất hiện 3 lần
# Từ 'jan' xuất hiện 3 lần
# Từ 'weigh' xuất hiện 3 lần
# Từ 'hint' xuất hiện 3 lần
# Từ '2morrow' xuất hiện 3 lần
# Từ 'xavier' xuất hiện 3 lần
# Từ 'warn' xuất hiện 3 lần
# Từ 'stomach' xuất hiện 3 lần
# Từ 'nap' xuất hiện 3 lần
# Từ 'shesil' xuất hiện 3 lần
# Từ 'mac' xuất hiện 3 lần
# Từ 'opportun' xuất hiện 3 lần
# Từ 'outstand' xuất hiện 3 lần
# Từ 'taylor' xuất hiện 3 lần
# Từ 'welp' xuất hiện 3 lần
# Từ 'hesit' xuất hiện 3 lần
# Từ 'talent' xuất hiện 3 lần
# Từ 'fuckin' xuất hiện 3 lần
# Từ 'ubi' xuất hiện 3 lần
# Từ 'butt' xuất hiện 3 lần
# Từ 'miracl' xuất hiện 3 lần
# Từ 'terribl' xuất hiện 3 lần
# Từ 'exe' xuất hiện 3 lần
# Từ 'prey' xuất hiện 3 lần
# Từ 'foreign' xuất hiện 3 lần
# Từ 'stamp' xuất hiện 3 lần
# Từ 'countri' xuất hiện 3 lần
# Từ 'roast' xuất hiện 3 lần
# Từ 'june' xuất hiện 3 lần
# Từ 'drunk' xuất hiện 3 lần
# Từ 'juici' xuất hiện 3 lần
# Từ 'vijay' xuất hiện 3 lần
# Từ 'ne' xuất hiện 3 lần
# Từ 'depress' xuất hiện 3 lần
# Từ 'wind' xuất hiện 3 lần
# Từ 'who' xuất hiện 3 lần
# Từ 'gay' xuất hiện 3 lần
# Từ 'fantast' xuất hiện 3 lần
# Từ 'bigger' xuất hiện 3 lần
# Từ 'island' xuất hiện 3 lần
# Từ 'p' xuất hiện 3 lần
# Từ 'walmart' xuất hiện 3 lần
# Từ 'rofl' xuất hiện 3 lần
# Từ 'anti' xuất hiện 3 lần
# Từ 'delay' xuất hiện 3 lần
# Từ 'tour' xuất hiện 3 lần
# Từ 'ipad' xuất hiện 3 lần
# Từ 'fran' xuất hiện 3 lần
# Từ 'knacker' xuất hiện 3 lần
# Từ 'softwar' xuất hiện 3 lần
# Từ 'whenevr' xuất hiện 3 lần
# Từ 'remembr' xuất hiện 3 lần
# Từ '4u' xuất hiện 3 lần
# Từ 'chill' xuất hiện 3 lần
# Từ 'chillin' xuất hiện 3 lần
# Từ 'super' xuất hiện 3 lần
# Từ 'chain' xuất hiện 3 lần
# Từ 'suffer' xuất hiện 3 lần
# Từ 'arrest' xuất hiện 3 lần
# Từ 'suntec' xuất hiện 3 lần
# Từ 'messeng' xuất hiện 3 lần
# Từ 'unsold' xuất hiện 3 lần
# Từ 'recharg' xuất hiện 3 lần
# Từ 'shld' xuất hiện 3 lần
# Từ 'option' xuất hiện 3 lần
# Từ 'missin' xuất hiện 3 lần
# Từ 'guilti' xuất hiện 3 lần
# Từ 'cardiff' xuất hiện 3 lần
# Từ 'addi' xuất hiện 3 lần
# Từ 'tue' xuất hiện 3 lần
# Từ 'flower' xuất hiện 3 lần
# Từ 'monkey' xuất hiện 3 lần
# Từ 'certainli' xuất hiện 3 lần
# Từ 'program' xuất hiện 3 lần
# Từ 'aah' xuất hiện 3 lần
# Từ '4th' xuất hiện 3 lần
# Từ 'blake' xuất hiện 3 lần
# Từ 'eight' xuất hiện 3 lần
# Từ 'receipt' xuất hiện 3 lần
# Từ 'prospect' xuất hiện 3 lần
# Từ 'buff' xuất hiện 3 lần
# Từ 'gang' xuất hiện 3 lần
# Từ 'adventur' xuất hiện 3 lần
# Từ 'cloth' xuất hiện 3 lần
# Từ 'sub' xuất hiện 3 lần
# Từ 'brotha' xuất hiện 3 lần
# Từ 'fire' xuất hiện 3 lần
# Từ 'perfect' xuất hiện 3 lần
# Từ 'freez' xuất hiện 3 lần
# Từ 'fring' xuất hiện 3 lần
# Từ '6pm' xuất hiện 3 lần
# Từ 'event' xuất hiện 3 lần
# Từ 'maintain' xuất hiện 3 lần
# Từ 'cramp' xuất hiện 3 lần
# Từ 'nan' xuất hiện 3 lần
# Từ 'dislik' xuất hiện 3 lần
# Từ 'despar' xuất hiện 3 lần
# Từ 'mi' xuất hiện 3 lần
# Từ 'tb' xuất hiện 3 lần
# Từ 'iåõm' xuất hiện 3 lần
# Từ 'stuck' xuất hiện 3 lần
# Từ 'creat' xuất hiện 3 lần
# Từ 'philosophi' xuất hiện 3 lần
# Từ 'combin' xuất hiện 3 lần
# Từ 'dirti' xuất hiện 3 lần
# Từ 'packag' xuất hiện 3 lần
# Từ 'husband' xuất hiện 3 lần
# Từ 'five' xuất hiện 3 lần
# Từ 'toa' xuất hiện 3 lần
# Từ 'payoh' xuất hiện 3 lần
# Từ 'payment' xuất hiện 3 lần
# Từ 'fathima' xuất hiện 3 lần
# Từ 'mmmm' xuất hiện 3 lần
# Từ 'beyond' xuất hiện 3 lần
# Từ 'jog' xuất hiện 3 lần
# Từ 'tabl' xuất hiện 3 lần
# Từ 'ikea' xuất hiện 3 lần
# Từ 'kadeem' xuất hiện 3 lần
# Từ 'carri' xuất hiện 3 lần
# Từ 'avatar' xuất hiện 3 lần
# Từ 'upset' xuất hiện 3 lần
# Từ 'constantli' xuất hiện 3 lần
# Từ 'lousi' xuất hiện 3 lần
# Từ 'ic' xuất hiện 3 lần
# Từ 'wrk' xuất hiện 3 lần
# Từ 'boat' xuất hiện 3 lần
# Từ 'proof' xuất hiện 3 lần
# Từ 'major' xuất hiện 3 lần
# Từ 'birth' xuất hiện 3 lần
# Từ 'choic' xuất hiện 3 lần
# Từ 'onward' xuất hiện 3 lần
# Từ 'energi' xuất hiện 3 lần
# Từ 'simpli' xuất hiện 3 lần
# Từ 'calicut' xuất hiện 3 lần
# Từ 'giv' xuất hiện 3 lần
# Từ 'rich' xuất hiện 3 lần
# Từ 'yor' xuất hiện 3 lần
# Từ 'jason' xuất hiện 3 lần
# Từ 'argh' xuất hiện 3 lần
# Từ 'diamond' xuất hiện 3 lần
# Từ 'china' xuất hiện 3 lần
# Từ 'morphin' xuất hiện 3 lần
# Từ 'mile' xuất hiện 3 lần
# Từ 'speed' xuất hiện 3 lần
# Từ 'distanc' xuất hiện 3 lần
# Từ 'display' xuất hiện 3 lần
# Từ 'soup' xuất hiện 3 lần
# Từ '900' xuất hiện 3 lần
# Từ 'unabl' xuất hiện 3 lần
# Từ 'wkend' xuất hiện 3 lần
# Từ 'journey' xuất hiện 3 lần
# Từ 'measur' xuất hiện 3 lần
# Từ 'imposs' xuất hiện 3 lần
# Từ 'gain' xuất hiện 3 lần
# Từ 'thangam' xuất hiện 3 lần
# Từ 'okey' xuất hiện 3 lần
# Từ 'brilliant' xuất hiện 3 lần
# Từ 'madam' xuất hiện 3 lần
# Từ 'bloo' xuất hiện 3 lần
# Từ 'citizen' xuất hiện 3 lần
# Từ 'star' xuất hiện 3 lần
# Từ 'sri' xuất hiện 3 lần
# Từ 'lock' xuất hiện 3 lần
# Từ 'shove' xuất hiện 3 lần
# Từ 'releas' xuất hiện 3 lần
# Từ 'dai' xuất hiện 3 lần
# Từ 'resum' xuất hiện 3 lần
# Từ 'maga' xuất hiện 3 lần
# Từ 'arriv' xuất hiện 3 lần
# Từ 'medicin' xuất hiện 3 lần
# Từ 'incid' xuất hiện 3 lần
# Từ 'violenc' xuất hiện 3 lần
# Từ 'motiv' xuất hiện 3 lần
# Từ 'erm' xuất hiện 3 lần
# Từ 'death' xuất hiện 3 lần
# Từ 'challeng' xuất hiện 3 lần
# Từ 'booti' xuất hiện 3 lần
# Từ 'lil' xuất hiện 3 lần
# Từ 'pout' xuất hiện 3 lần
# Từ 'stomp' xuất hiện 3 lần
# Từ 'serv' xuất hiện 3 lần
# Từ 'feb' xuất hiện 3 lần
# Từ 'middl' xuất hiện 3 lần
# Từ 'enuff' xuất hiện 3 lần
# Từ 'pg' xuất hiện 3 lần
# Từ 'iz' xuất hiện 3 lần
# Từ 'handl' xuất hiện 3 lần
# Từ 'seat' xuất hiện 3 lần
# Từ 'low' xuất hiện 3 lần
# Từ 'flake' xuất hiện 3 lần
# Từ 'cheaper' xuất hiện 3 lần
# Từ 'histori' xuất hiện 3 lần
# Từ 'bell' xuất hiện 3 lần
# Từ 'reboot' xuất hiện 3 lần
# Từ 'understood' xuất hiện 3 lần
# Từ 'bottom' xuất hiện 3 lần
# Từ 'crab' xuất hiện 3 lần
# Từ 'footprint' xuất hiện 3 lần
# Từ 'thur' xuất hiện 3 lần
# Từ 'mess' xuất hiện 3 lần
# Từ 'count' xuất hiện 3 lần
# Từ 'tape' xuất hiện 3 lần
# Từ 'size' xuất hiện 3 lần
# Từ 'auto' xuất hiện 3 lần
# Từ 'cheat' xuất hiện 3 lần
# Từ 'amaz' xuất hiện 3 lần
# Từ 'princ' xuất hiện 3 lần
# Từ 'camera' xuất hiện 3 lần
# Từ 'prolli' xuất hiện 3 lần
# Từ 'åð' xuất hiện 3 lần
# Từ 'dubsack' xuất hiện 3 lần
# Từ 'macho' xuất hiện 3 lần
# Từ 'audit' xuất hiện 3 lần
# Từ 'dark' xuất hiện 3 lần
# Từ 'fell' xuất hiện 3 lần
# Từ 'eaten' xuất hiện 3 lần
# Từ 'stone' xuất hiện 3 lần
# Từ 'born' xuất hiện 3 lần
# Từ 'along' xuất hiện 3 lần
# Từ 'univers' xuất hiện 3 lần
# Từ 'california' xuất hiện 3 lần
# Từ 'tog' xuất hiện 3 lần
# Từ 'wyli' xuất hiện 3 lần
# Từ 'haiz' xuất hiện 3 lần
# Từ 'loss' xuất hiện 3 lần
# Từ 'ds' xuất hiện 3 lần
# Từ 'deni' xuất hiện 3 lần
# Từ 'bottl' xuất hiện 3 lần
# Từ 'buffet' xuất hiện 2 lần
# Từ 'hor' xuất hiện 2 lần
# Từ 'aid' xuất hiện 2 lần
# Từ 'oru' xuất hiện 2 lần
# Từ 'vagu' xuất hiện 2 lần
# Từ 'sarcast' xuất hiện 2 lần
# Từ 'fear' xuất hiện 2 lần
# Từ '8am' xuất hiện 2 lần
# Từ 'mmmmmm' xuất hiện 2 lần
# Từ 'sucker' xuất hiện 2 lần
# Từ 'eighth' xuất hiện 2 lần
# Từ 'accomod' xuất hiện 2 lần
# Từ 'odi' xuất hiện 2 lần
# Từ 'iq' xuất hiện 2 lần
# Từ 'dedic' xuất hiện 2 lần
# Từ 'valuabl' xuất hiện 2 lần
# Từ 'jacket' xuất hiện 2 lần
# Từ 'ela' xuất hiện 2 lần
# Từ 'pour' xuất hiện 2 lần
# Từ 'sum1' xuất hiện 2 lần
# Từ 'telugu' xuất hiện 2 lần
# Từ 'four' xuất hiện 2 lần
# Từ 'locat' xuất hiện 2 lần
# Từ 'truli' xuất hiện 2 lần
# Từ 'noun' xuất hiện 2 lần
# Từ 'sentenc' xuất hiện 2 lần
# Từ 'puttin' xuất hiện 2 lần
# Từ 'cabin' xuất hiện 2 lần
# Từ 'goodo' xuất hiện 2 lần
# Từ 'tortilla' xuất hiện 2 lần
# Từ 'involv' xuất hiện 2 lần
# Từ 'sum' xuất hiện 2 lần
# Từ 'msn' xuất hiện 2 lần
# Từ 'befor' xuất hiện 2 lần
# ...
# Từ 'lavend' xuất hiện 1 lần
# Từ 'manki' xuất hiện 1 lần
# Từ 'scous' xuất hiện 1 lần
# Từ 'inmind' xuất hiện 1 lần
# Từ 'recreat' xuất hiện 1 lần
# Từ 'mesag' xuất hiện 1 lần
# Từ 'judgement' xuất hiện 1 lần
# Từ 'waheeda' xuất hiện 1 lần
# Từ 'bot' xuất hiện 1 lần
# Từ 'eventu' xuất hiện 1 lần
# Từ 'toler' xuất hiện 1 lần
# Từ 'hellogorg' xuất hiện 1 lần
# Từ 'nitw' xuất hiện 1 lần
# Từ 'texd' xuất hiện 1 lần
# Từ 'hopeu' xuất hiện 1 lần
# Từ '4ward' xuất hiện 1 lần
# Từ 'jaz' xuất hiện 1 lần
# Từ 'exorc' xuất hiện 1 lần
# Từ 'emili' xuất hiện 1 lần
# Từ 'evri' xuất hiện 1 lần
# Từ 'emot' xuất hiện 1 lần
# Từ 'prayr' xuất hiện 1 lần
# Từ 'ujhhhhhhh' xuất hiện 1 lần
# Từ 'sandiago' xuất hiện 1 lần
# Từ 'parantella' xuất hiện 1 lần
# Từ 'sweater' xuất hiện 1 lần
# Từ 'mango' xuất hiện 1 lần
# Từ 'absolutli' xuất hiện 1 lần
# Từ 'consent' xuất hiện 1 lần
# Từ 'mathew' xuất hiện 1 lần
# Từ 'tait' xuất hiện 1 lần
# Từ 'anderson' xuất hiện 1 lần
# Từ 'haunt' xuất hiện 1 lần
# Từ 'promot' xuất hiện 1 lần
# Từ 'hex' xuất hiện 1 lần
# Từ 'crowd' xuất hiện 1 lần
# Từ 'snowboard' xuất hiện 1 lần
# Từ 'christmassi' xuất hiện 1 lần
# Từ 'baaaaaaaab' xuất hiện 1 lần
# Từ 'shola' xuất hiện 1 lần
# Từ 'sagamu' xuất hiện 1 lần
# Từ 'lautech' xuất hiện 1 lần
# Từ 'vital' xuất hiện 1 lần
# Từ 'zealand' xuất hiện 1 lần
# Từ 'qet' xuất hiện 1 lần
# Từ 'dial' xuất hiện 1 lần
# Từ 'browser' xuất hiện 1 lần
# Từ 'convers' xuất hiện 1 lần
# Từ 'intern' xuất hiện 1 lần
# Từ 'extract' xuất hiện 1 lần
# Từ 'skint' xuất hiện 1 lần
# Từ 'othr' xuất hiện 1 lần
# Từ 'watchng' xuất hiện 1 lần
# Từ 'planet' xuất hiện 1 lần
# Từ 'comfey' xuất hiện 1 lần
# Từ 'least5tim' xuất hiện 1 lần
# Từ 'frequent' xuất hiện 1 lần
# Từ 'cupboard' xuất hiện 1 lần
# Từ 'rout' xuất hiện 1 lần
# Từ '2mro' xuất hiện 1 lần
# Từ 'uk' xuất hiện 1 lần
# Từ 'grasp' xuất hiện 1 lần
# Từ 'flavour' xuất hiện 1 lần
# Từ 'lareadi' xuất hiện 1 lần
# Từ 'dom' xuất hiện 1 lần
# Từ 'ffffuuuuuuu' xuất hiện 1 lần
# Từ 'oblivi' xuất hiện 1 lần
# Từ 'mapquest' xuất hiện 1 lần
# Từ 'dogwood' xuất hiện 1 lần
# Từ 'archiv' xuất hiện 1 lần
# Từ 'behalf' xuất hiện 1 lần
# Từ 'stun' xuất hiện 1 lần
# Từ 'visa' xuất hiện 1 lần
# Từ 'gucci' xuất hiện 1 lần
# Từ 'culdnt' xuất hiện 1 lần
# Từ 'talkbut' xuất hiện 1 lần
# Từ 'wannatel' xuất hiện 1 lần
# Từ 'wenwecan' xuất hiện 1 lần
# Từ 'smsing' xuất hiện 1 lần
# Từ 'effici' xuất hiện 1 lần
# Từ 'erutupalam' xuất hiện 1 lần
# Từ 'thandiyachu' xuất hiện 1 lần
# Từ 'invent' xuất hiện 1 lần
# Từ 'lyric' xuất hiện 1 lần
# Từ 'nevr' xuất hiện 1 lần
# Từ 'unrecogn' xuất hiện 1 lần
# Từ 'somon' xuất hiện 1 lần
# Từ 'definitli' xuất hiện 1 lần
# Từ 'undrstnd' xuất hiện 1 lần
# Từ 'ger' xuất hiện 1 lần
# Từ 'toke' xuất hiện 1 lần
# Từ 'syd' xuất hiện 1 lần
# Từ 'khelat' xuất hiện 1 lần
# Từ 'kintu' xuất hiện 1 lần
# Từ 'opponent' xuất hiện 1 lần
# Từ 'dhort' xuất hiện 1 lần
# Từ 'lage' xuất hiện 1 lần
# Từ 'looovvv' xuất hiện 1 lần
# Từ 'warwick' xuất hiện 1 lần
# Từ 'tmw' xuất hiện 1 lần
# Từ 'parad' xuất hiện 1 lần
# Từ 'grumbl' xuất hiện 1 lần
# Từ 'linear' xuất hiện 1 lần
# Từ 'algebra' xuất hiện 1 lần
# Từ 'decor' xuất hiện 1 lần
# Từ 'roomat' xuất hiện 1 lần
# Từ 'graduat' xuất hiện 1 lần
# Từ 'adjust' xuất hiện 1 lần
# Từ 'cooper' xuất hiện 1 lần
# Từ 'nottingham' xuất hiện 1 lần
# Từ '63mile' xuất hiện 1 lần
# Từ '40mph' xuất hiện 1 lần
# Từ 'mornin' xuất hiện 1 lần
# Từ 'thanku' xuất hiện 1 lần
# Từ '2morro' xuất hiện 1 lần
# Từ 'besid' xuất hiện 1 lần
# Từ 'brisk' xuất hiện 1 lần
# Từ 'tellmiss' xuất hiện 1 lần
# Từ 'contribut' xuất hiện 1 lần
# Từ 'greatli' xuất hiện 1 lần
# Từ 'urgh' xuất hiện 1 lần
# Từ 'coach' xuất hiện 1 lần
# Từ 'duvet' xuất hiện 1 lần
# Từ '24th' xuất hiện 1 lần
# Từ 'cha' xuất hiện 1 lần
# Từ 'beverag' xuất hiện 1 lần
# Từ 'surrend' xuất hiện 1 lần
# Từ 'rdi' xuất hiện 1 lần
# Từ 'comp' xuất hiện 1 lần
# Từ 'backward' xuất hiện 1 lần
# Từ 'abstract' xuất hiện 1 lần
# Từ 'africa' xuất hiện 1 lần
# Từ 'avin' xuất hiện 1 lần
# Từ 'quiteamuz' xuất hiện 1 lần
# Từ 'thatåõscool' xuất hiện 1 lần
# Từ 'fixd' xuất hiện 1 lần
# Từ 'njan' xuất hiện 1 lần
# Từ 'vilikkam' xuất hiện 1 lần
# Từ 'sudn' xuất hiện 1 lần
# Từ 'chapter' xuất hiện 1 lần
# Từ 'chop' xuất hiện 1 lần
# Từ 'noooooooo' xuất hiện 1 lần
# Từ 'firsg' xuất hiện 1 lần
# Từ 'split' xuất hiện 1 lần
# Từ 'wasnt' xuất hiện 1 lần
# Từ 'heat' xuất hiện 1 lần
# Từ 'laid' xuất hiện 1 lần
# Từ 'voucher' xuất hiện 1 lần
# Từ 'virgin' xuất hiện 1 lần
# Từ 'sumf' xuất hiện 1 lần
# Từ 'hiphop' xuất hiện 1 lần
# Từ 'oxygen' xuất hiện 1 lần
# Từ 'resort' xuất hiện 1 lần
# Từ 'roller' xuất hiện 1 lần
# Từ 'showr' xuất hiện 1 lần
# Từ 'upon' xuất hiện 1 lần
# Từ 'ceil' xuất hiện 1 lần
# Từ 'presnt' xuất hiện 1 lần
# Từ 'bcz' xuất hiện 1 lần
# Từ 'irulina' xuất hiện 1 lần
# Từ 'neekunna' xuất hiện 1 lần
# Từ 'prakasamanu' xuất hiện 1 lần
# Từ 'prakasam' xuất hiện 1 lần
# Từ 'ennal' xuất hiện 1 lần
# Từ 'mn' xuất hiện 1 lần
# Từ 'firmwar' xuất hiện 1 lần
# Từ 'vijaykanth' xuất hiện 1 lần
# Từ 'anythi' xuất hiện 1 lần
# Từ 'keypad' xuất hiện 1 lần
# Từ 'btwn' xuất hiện 1 lần
# Từ 'decad' xuất hiện 1 lần
# Từ 'gover' xuất hiện 1 lần
# Từ 'spice' xuất hiện 1 lần
# Từ 'prasanth' xuất hiện 1 lần
# Từ 'ettan' xuất hiện 1 lần
# Từ 'appi' xuất hiện 1 lần
# Từ 'fizz' xuất hiện 1 lần
# Từ 'contain' xuất hiện 1 lần
# Từ 'genu' xuất hiện 1 lần
# Từ 'robinson' xuất hiện 1 lần
# Từ 'out' xuất hiện 1 lần
# Từ 'soz' xuất hiện 1 lần
# Từ 'imat' xuất hiện 1 lần
# Từ 'sometext' xuất hiện 1 lần
# Từ 'wewa' xuất hiện 1 lần
# Từ 'iriv' xuất hiện 1 lần
# Từ '128' xuất hiện 1 lần
# Từ 'bw' xuất hiện 1 lần
# Từ 'surli' xuất hiện 1 lần
# Từ 'capit' xuất hiện 1 lần
# Từ 'mmmmmmm' xuất hiện 1 lần
# Từ 'snuggl' xuất hiện 1 lần
# Từ 'whisper' xuất hiện 1 lần
# Từ 'healthi' xuất hiện 1 lần
# Từ '2bold' xuất hiện 1 lần
# Từ 'sticki' xuất hiện 1 lần
# Từ 'scrape' xuất hiện 1 lần
# Từ 'barrel' xuất hiện 1 lần
# Từ 'misfit' xuất hiện 1 lần
# Từ 'clearer' xuất hiện 1 lần
# Từ 'peach' xuất hiện 1 lần
# Từ 'shindig' xuất hiện 1 lần
# Từ 'phonebook' xuất hiện 1 lần
# Từ 'eng' xuất hiện 1 lần
# Từ 'ash' xuất hiện 1 lần
# Từ 'shijutta' xuất hiện 1 lần
# Từ 'offens' xuất hiện 1 lần
# Từ 'dvg' xuất hiện 1 lần
# Từ 'vinobanagar' xuất hiện 1 lần
# Từ '3wk' xuất hiện 1 lần
# Từ 'orh' xuất hiện 1 lần
# Từ 'thousand' xuất hiện 1 lần
# Từ 'n8' xuất hiện 1 lần
# Từ 'canteen' xuất hiện 1 lần
# Từ 'stressful' xuất hiện 1 lần
# Từ '140' xuất hiện 1 lần
# Từ 'ìä' xuất hiện 1 lần
# Từ '180' xuất hiện 1 lần
# Từ 'bedrm' xuất hiện 1 lần
# Từ 'assist' xuất hiện 1 lần
# Từ 'when' xuất hiện 1 lần
# Từ 'watev' xuất hiện 1 lần
# Từ 'built' xuất hiện 1 lần
# Từ 'lonlin' xuất hiện 1 lần
# Từ 'lotz' xuất hiện 1 lần
# Từ 'gailxx' xuất hiện 1 lần
# Từ 'instruct' xuất hiện 1 lần
# Từ 'complac' xuất hiện 1 lần
# Từ 'mina' xuất hiện 1 lần
# Từ 'miwa' xuất hiện 1 lần
# Từ 'hsbc' xuất hiện 1 lần
# Từ 'opposit' xuất hiện 1 lần
# Từ 'heavili' xuất hiện 1 lần
# Từ 'patrick' xuất hiện 1 lần
# Từ 'swayz' xuất hiện 1 lần
# Từ 'quarter' xuất hiện 1 lần
# Từ 'nervou' xuất hiện 1 lần
# Từ 'limp' xuất hiện 1 lần
# Từ 'aa' xuất hiện 1 lần
# Từ 'oga' xuất hiện 1 lần
# Từ 'poorli' xuất hiện 1 lần
# Từ 'brb' xuất hiện 1 lần
# Từ 'smaller' xuất hiện 1 lần
# Từ 'capac' xuất hiện 1 lần
# Từ 'defer' xuất hiện 1 lần
# Từ 'admiss' xuất hiện 1 lần
# Từ 'chess' xuất hiện 1 lần
# Từ 'persian' xuất hiện 1 lần
# Từ 'phrase' xuất hiện 1 lần
# Từ 'shah' xuất hiện 1 lần
# Từ 'rat' xuất hiện 1 lần
# Từ 'pee' xuất hiện 1 lần
# Từ 'photoshop' xuất hiện 1 lần
# Từ 'inshah' xuất hiện 1 lần
# Từ 'increas' xuất hiện 1 lần
# Từ 'north' xuất hiện 1 lần
# Từ 'carolina' xuất hiện 1 lần
# Từ 'texa' xuất hiện 1 lần
# Từ 'gre' xuất hiện 1 lần
# Từ 'bomb' xuất hiện 1 lần
# Từ 'weapon' xuất hiện 1 lần
# Từ 'lovli' xuất hiện 1 lần
# Từ 'cla' xuất hiện 1 lần
# Từ 'lit' xuất hiện 1 lần
# Từ 'loooooool' xuất hiện 1 lần
# Từ 'swashbuckl' xuất hiện 1 lần
# Từ 'dip' xuất hiện 1 lần
# Từ 'gek1510' xuất hiện 1 lần
# Từ 'cruis' xuất hiện 1 lần
# Từ 'feelin' xuất hiện 1 lần
# Từ 'happiest' xuất hiện 1 lần
# Từ 'antibiot' xuất hiện 1 lần
# Từ 'abdomen' xuất hiện 1 lần
# Từ 'gyna' xuất hiện 1 lần
# Từ '6time' xuất hiện 1 lần
# Từ 'chastiti' xuất hiện 1 lần
# Từ 'devic' xuất hiện 1 lần
# Từ 'beat' xuất hiện 1 lần
# Từ 'gut' xuất hiện 1 lần
# Từ 'tallahasse' xuất hiện 1 lần
# Từ 'taka' xuất hiện 1 lần
# Từ 'wrote' xuất hiện 1 lần
# Từ 'ritten' xuất hiện 1 lần
# Từ 'fold' xuất hiện 1 lần
# Từ 'solihul' xuất hiện 1 lần
# Từ 'nh' xuất hiện 1 lần
# Từ 'local' xuất hiện 1 lần
# Từ '2b' xuất hiện 1 lần
# Từ 'nonetheless' xuất hiện 1 lần
# Từ 'hooch' xuất hiện 1 lần
# Từ 'toaday' xuất hiện 1 lần
# Từ 'splat' xuất hiện 1 lần
# Từ 'graze' xuất hiện 1 lần
# Từ 'hearin' xuất hiện 1 lần
# Từ 'yah' xuất hiện 1 lần
# Từ 'tortur' xuất hiện 1 lần
# Từ 'england' xuất hiện 1 lần
# Từ 'court' xuất hiện 1 lần
# Từ 'chapel' xuất hiện 1 lần
# Từ 'frontiervil' xuất hiện 1 lần
# Từ 'deer' xuất hiện 1 lần
# Từ 'varma' xuất hiện 1 lần
# Từ 'secur' xuất hiện 1 lần
# Từ 'fart' xuất hiện 1 lần
# Từ 'ortxt' xuất hiện 1 lần
# Từ 'ahhhh' xuất hiện 1 lần
# Từ 'kaila' xuất hiện 1 lần
# Từ 'collaps' xuất hiện 1 lần
# Từ 'jade' xuất hiện 1 lần
# Từ 'paul' xuất hiện 1 lần
# Từ 'barm' xuất hiện 1 lần
# Từ 'thinkthi' xuất hiện 1 lần
# Từ 'channel' xuất hiện 1 lần
# Từ 'coulda' xuất hiện 1 lần
# Từ 'okday' xuất hiện 1 lần
# Từ 'hmph' xuất hiện 1 lần
# Từ 'baller' xuất hiện 1 lần
# Từ 'punto' xuất hiện 1 lần
# Từ 'ayo' xuất hiện 1 lần
# Từ 'toyota' xuất hiện 1 lần
# Từ 'camri' xuất hiện 1 lần
# Từ 'olayiwola' xuất hiện 1 lần
# Từ 'mileag' xuất hiện 1 lần
# Từ 'clover' xuất hiện 1 lần
# Từ 'achan' xuất hiện 1 lần
# Từ 'nìâte' xuất hiện 1 lần
# Từ 'puppi' xuất hiện 1 lần
# Từ 'nois' xuất hiện 1 lần
# Từ 'adsens' xuất hiện 1 lần
# Từ 'dudett' xuất hiện 1 lần
# Từ 'perumbavoor' xuất hiện 1 lần
# Từ 'stage' xuất hiện 1 lần
# Từ 'clarifi' xuất hiện 1 lần
# Từ 'prepon' xuất hiện 1 lần
# Từ 'younger' xuất hiện 1 lần
# Từ 'liver' xuất hiện 1 lần
# Từ 'loneli' xuất hiện 1 lần
# Từ 'skyve' xuất hiện 1 lần
# Từ 'club' xuất hiện 1 lần
# Từ 'onword' xuất hiện 1 lần
# Từ 'mtnl' xuất hiện 1 lần
# Từ 'mumbai' xuất hiện 1 lần
# Từ 'rajitha' xuất hiện 1 lần
# Từ 'ranju' xuất hiện 1 lần
# Từ 'slp' xuất hiện 1 lần
# Từ 'muah' xuất hiện 1 lần
# Từ 'disagre' xuất hiện 1 lần
# Từ 'afterward' xuất hiện 1 lần
# Từ 'uawak' xuất hiện 1 lần
# Từ 'feellikw' xuất hiện 1 lần
# Từ 'alett' xuất hiện 1 lần
# Từ 'thatmum' xuất hiện 1 lần
# Từ 'gotmarri' xuất hiện 1 lần
# Từ 'ourback' xuất hiện 1 lần
# Từ 'fuckinnic' xuất hiện 1 lần
# Từ 'rearrang' xuất hiện 1 lần
# Từ 'dormitori' xuất hiện 1 lần
# Từ 'astronom' xuất hiện 1 lần
# Từ 'starer' xuất hiện 1 lần
# Từ 'recount' xuất hiện 1 lần
# Từ 'hitler' xuất hiện 1 lần
# Từ 'eleven' xuất hiện 1 lần
# Từ 'worm' xuất hiện 1 lần
# Từ 'dysentri' xuất hiện 1 lần
# Từ 'virgil' xuất hiện 1 lần
# Từ 'gokila' xuất hiện 1 lần
# Từ 'shanil' xuất hiện 1 lần
# Từ 'exchang' xuất hiện 1 lần
# Từ 'uncut' xuất hiện 1 lần
# Từ 'dino' xuất hiện 1 lần
# Từ 'prem' xuất hiện 1 lần
# Từ 'kote' xuất hiện 1 lần
# Từ 'hassl' xuất hiện 1 lần
# Từ 'haughaighgtujhyguj' xuất hiện 1 lần
# Từ 'fassyol' xuất hiện 1 lần
# Từ 'blacko' xuất hiện 1 lần
# Từ 'londn' xuất hiện 1 lần
# Từ 'aslamalaikkum' xuất hiện 1 lần
# Từ 'tohar' xuất hiện 1 lần
# Từ 'beeen' xuất hiện 1 lần
# Từ 'muht' xuất hiện 1 lần
# Từ 'albi' xuất hiện 1 lần
# Từ 'mufti' xuất hiện 1 lần
# Từ 'mahfuuz' xuất hiện 1 lần
# Từ 'enufcredeit' xuất hiện 1 lần
# Từ 'ileav' xuất hiện 1 lần
# Từ 'okor' xuất hiện 1 lần
# Từ 'ibor' xuất hiện 1 lần
# Từ 'zero' xuất hiện 1 lần
# Từ 'goigng' xuất hiện 1 lần
# Từ 'perfum' xuất hiện 1 lần
# Từ 'sday' xuất hiện 1 lần
# Từ 'grocer' xuất hiện 1 lần
# Từ 'franki' xuất hiện 1 lần
# Từ 'benni' xuất hiện 1 lần
# Từ 'warner' xuất hiện 1 lần
# Từ 'diaper' xuất hiện 1 lần
# Từ 'unlik' xuất hiện 1 lần
# Từ 'patient' xuất hiện 1 lần
# Từ 'turkey' xuất hiện 1 lần
# Từ 'wenev' xuất hiện 1 lần
# Từ 'stabil' xuất hiện 1 lần
# Từ 'tranquil' xuất hiện 1 lần
# Từ 'vibrant' xuất hiện 1 lần
# Từ 'renew' xuất hiện 1 lần
# Từ 'bawl' xuất hiện 1 lần
# Từ 'failur' xuất hiện 1 lần
# Từ 'velusami' xuất hiện 1 lần
# Từ 'facil' xuất hiện 1 lần
# Từ 'karnan' xuất hiện 1 lần
# Từ 'bluray' xuất hiện 1 lần
# Từ 'salt' xuất hiện 1 lần
# Từ 'wound' xuất hiện 1 lần
# Từ 'geoenvironment' xuất hiện 1 lần
# Từ 'implic' xuất hiện 1 lần
# Từ 'fuuuuck' xuất hiện 1 lần
# Từ 'salmon' xuất hiện 1 lần
# Từ 'wrkin' xuất hiện 1 lần
# Từ 'awkward' xuất hiện 1 lần
# Từ 'splash' xuất hiện 1 lần
# Từ 'musta' xuất hiện 1 lần
# Từ 'overdid' xuất hiện 1 lần
# Từ 'gastroenter' xuất hiện 1 lần
# Từ 'reduc' xuất hiện 1 lần
# Từ 'chuck' xuất hiện 1 lần
# Từ 'port' xuất hiện 1 lần
# Từ 'juswok' xuất hiện 1 lần
# Từ 'boatin' xuất hiện 1 lần
# Từ 'spinout' xuất hiện 1 lần
# Từ 'uworld' xuất hiện 1 lần
# Từ 'qbank' xuất hiện 1 lần
# Từ 'assess' xuất hiện 1 lần
# Từ 'tke' xuất hiện 1 lần
# Từ 'temal' xuất hiện 1 lần
# Từ 'vid' xuất hiện 1 lần
# Từ 'finishd' xuất hiện 1 lần
# Từ 'dull' xuất hiện 1 lần
# Từ 'treadmil' xuất hiện 1 lần
# Từ 'craigslist' xuất hiện 1 lần
# Từ 'absolut' xuất hiện 1 lần
# Từ 'swan' xuất hiện 1 lần
# Từ 'lamp' xuất hiện 1 lần
# Từ 'foward' xuất hiện 1 lần
# Từ 'misundrstud' xuất hiện 1 lần
# Từ '2u2' xuất hiện 1 lần
# Từ 'gene' xuất hiện 1 lần
# Từ 'reappli' xuất hiện 1 lần
# Từ 'treatin' xuất hiện 1 lần
# Từ 'treacl' xuất hiện 1 lần
# Từ 'mumha' xuất hiện 1 lần
# Từ 'beendrop' xuất hiện 1 lần
# Từ 'theplac' xuất hiện 1 lần
# Từ 'adress' xuất hiện 1 lần
# Từ 'oyster' xuất hiện 1 lần
# Từ 'sashimi' xuất hiện 1 lần
# Từ 'rumbl' xuất hiện 1 lần
# Từ 'marandratha' xuất hiện 1 lần
# Từ 'correctli' xuất hiện 1 lần
# Từ 'heaven' xuất hiện 1 lần
# Từ 'pisc' xuất hiện 1 lần
# Từ 'aquariu' xuất hiện 1 lần
# Từ '2yr' xuất hiện 1 lần
# Từ 'steyn' xuất hiện 1 lần
# Từ 'wicket' xuất hiện 1 lần
# Từ 'sterm' xuất hiện 1 lần
# Từ 'resolv' xuất hiện 1 lần
# Từ 'jam' xuất hiện 1 lần
# Từ 'hannaford' xuất hiện 1 lần
# Từ 'wheat' xuất hiện 1 lần
# Từ 'chex' xuất hiện 1 lần
# Từ 'pride' xuất hiện 1 lần
# Từ 'grownup' xuất hiện 1 lần
# Từ 'jerk' xuất hiện 1 lần
# Từ 'stink' xuất hiện 1 lần
# Từ 'upcharg' xuất hiện 1 lần
# Từ 'guai' xuất hiện 1 lần
# Từ 'astrolog' xuất hiện 1 lần
# Từ 'slack' xuất hiện 1 lần
# Từ 'mentor' xuất hiện 1 lần
# Từ '100' xuất hiện 1 lần
# Từ 'percent' xuất hiện 1 lần
# Từ 'sane' xuất hiện 1 lần
# Từ 'spacebuck' xuất hiện 1 lần
# Từ 'squeez' xuất hiện 1 lần
# Từ 'dread' xuất hiện 1 lần
# Từ 'thou' xuất hiện 1 lần
# Từ 'forgt' xuất hiện 1 lần
# Từ 'ajith' xuất hiện 1 lần
# Từ 'ooooooh' xuất hiện 1 lần
# Từ 'yovil' xuất hiện 1 lần
# Từ 'mega' xuất hiện 1 lần
# Từ 'asda' xuất hiện 1 lần
# Từ 'bff' xuất hiện 1 lần
# Từ 'carli' xuất hiện 1 lần
# Từ 'seper' xuất hiện 1 lần
# Từ 'brolli' xuất hiện 1 lần
# Từ 'franxx' xuất hiện 1 lần
# Từ 'prometazin' xuất hiện 1 lần
# Từ 'syrup' xuất hiện 1 lần
# Từ '5ml' xuất hiện 1 lần
# Từ 'feed' xuất hiện 1 lần
# Từ 'singapor' xuất hiện 1 lần
# Từ 'victoria' xuất hiện 1 lần
# Từ 'pocay' xuất hiện 1 lần
# Từ 'wocay' xuất hiện 1 lần
# Từ '2morrowxxxx' xuất hiện 1 lần
# Từ 'broth' xuất hiện 1 lần
# Từ 'ramen' xuất hiện 1 lần
# Từ 'fowler' xuất hiện 1 lần
# Từ 'flew' xuất hiện 1 lần
# Từ 'attent' xuất hiện 1 lần
# Từ 'tix' xuất hiện 1 lần
# Từ 'fne' xuất hiện 1 lần
# Từ 'youdo' xuất hiện 1 lần
# Từ 'worc' xuất hiện 1 lần
# Từ 'foreg' xuất hiện 1 lần
# Từ 'shrub' xuất hiện 1 lần
# Từ 'get4an18th' xuất hiện 1 lần
# Từ 'pendent' xuất hiện 1 lần
# Từ 'hu' xuất hiện 1 lần
# Từ 'navig' xuất hiện 1 lần
# Từ 'guidanc' xuất hiện 1 lần
# Từ 'chick' xuất hiện 1 lần
# Từ 'boob' xuất hiện 1 lần
# Từ 'reveal' xuất hiện 1 lần
# Từ 'gyno' xuất hiện 1 lần
# Từ 'treasur' xuất hiện 1 lần
# Từ 'neg' xuất hiện 1 lần
# Từ 'hmmmm' xuất hiện 1 lần
# Từ 'command' xuất hiện 1 lần
# Từ 'holbi' xuất hiện 1 lần
# Từ 'li' xuất hiện 1 lần
# Từ 'yeovil' xuất hiện 1 lần
# Từ 'motor' xuất hiện 1 lần
# Từ 'max' xuất hiện 1 lần
# Từ 'rhode' xuất hiện 1 lần
# Từ 'bong' xuất hiện 1 lần
# Từ 'ofcours' xuất hiện 1 lần
# Từ 'tamilnadu' xuất hiện 1 lần
# Từ 'tip' xuất hiện 1 lần
# Từ 'identif' xuất hiện 1 lần
# Từ 'boundari' xuất hiện 1 lần
# Từ 'endless' xuất hiện 1 lần
# Từ 'young' xuất hiện 1 lần
# Từ 'referin' xuất hiện 1 lần
# Từ 'saibaba' xuất hiện 1 lần
# Từ 'colani' xuất hiện 1 lần
# Từ 'chic' xuất hiện 1 lần
# Từ 'declar' xuất hiện 1 lần
# Từ 'disappoint' xuất hiện 1 lần
# Từ 'tantrum' xuất hiện 1 lần
# Từ 'compliment' xuất hiện 1 lần
# Từ 'chief' xuất hiện 1 lần
# Từ 'mous' xuất hiện 1 lần
# Từ 'desk' xuất hiện 1 lần
# Từ 'childporn' xuất hiện 1 lần
# Từ 'jumper' xuất hiện 1 lần
# Từ 'hat' xuất hiện 1 lần
# Từ 'belt' xuất hiện 1 lần
# Từ 'cribb' xuất hiện 1 lần
# Từ 'spiritu' xuất hiện 1 lần
# Từ 'sudden' xuất hiện 1 lần
# Từ 'influx' xuất hiện 1 lần
# Từ 'yeh' xuất hiện 1 lần
# Từ 'kane' xuất hiện 1 lần
# Từ 'shud' xuất hiện 1 lần
# Từ 'pshew' xuất hiện 1 lần
# Từ 'unit' xuất hiện 1 lần
# Từ 'accent' xuất hiện 1 lần
# Từ '4year' xuất hiện 1 lần
# Từ 'dental' xuất hiện 1 lần
# Từ 'nmde' xuất hiện 1 lần
# Từ 'dump' xuất hiện 1 lần
# Từ 'heap' xuất hiện 1 lần
# Từ 'salesman' xuất hiện 1 lần
# Từ 'piti' xuất hiện 1 lần

# %%
def split_sentence(text):
    word_list = nltk.word_tokenize(transform_text(text))
    return word_list

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
a = df['target'].value_counts()[0]

# %%
b = df['target'].value_counts()[1]

# %%
P_Spam = b/(a+b)
P_Ham = a/(a+b)
T = len(ham_words_dict.keys()) + len(spam_words_dict.keys())

# %%
def frequency_dict(list_input, words_dict):
    result_dict = {}
    total_frequency = 0
    
    for word in list_input:
        total_frequency = total_frequency + words_dict.get(word, 0)
    
    for word in list_input:
        frequency = words_dict.get(word, 0)
        result_dict[word] = (frequency + 1) / (total_frequency + T)
    
    return result_dict

# %%
def spam_detection(text):
    
    list_input = split_sentence(text)
    freq_ham = frequency_dict(list_input, ham_words_dict)
    freq_spam = frequency_dict(list_input, spam_words_dict)
    
    P_input_spam = 1
    for word in freq_spam:
        P_input_spam = P_input_spam * freq_spam[word]
        
    P_input_ham = 1
    for word in freq_ham:
        P_input_ham = P_input_ham * freq_ham[word]
        
    c_spam = P_input_spam * P_Spam
    print(c_spam)
    c_ham = P_input_ham * P_Ham
    print(c_ham)
    if (c_spam > c_ham):
        print("SPAM")
    else:
        print("HAM")

# %%
spam_detection("Congratulation! You've just won a lottery prize for 30000$. Please contact us via 12345")
# Out:
# SPAM

# %%
spam_detection("Are u at home right now? I'm heading to your house?")
# Out:
# HAM

# %%
spam_detection("Do you want to be a millionare? Click here to join us and have a chance to claim 10000000$ prize")
# Out:
# 5.9818776585939846e-27
# 5.220490797728317e-29
# SPAM

# %%
print(split_sentence("Do you want to be a millionare? Click here to join us and have a chance to take 10000000$ prize"))
# Out:
# ['want', 'millionar', 'click', 'join', 'us', 'chanc', 'take', '10000000', 'prize']
